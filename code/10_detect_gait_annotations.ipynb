# %%
import pandas as pd
import os

# %%
def add_gait_count(folder_path):
    print("Workinig on", folder_path)   
    df = pd.read_csv(os.path.join(folder_path, "merged.csv"))


    # Initialize the step count and a list to hold the values
    step_count = 0
    step_counts = []

    # Loop through each row and update the step count
    for is_step in df['insoles_LeftFoot_is_step']:
        if is_step:  # Increment the step count at each TRUE
            step_count += 1
        step_counts.append(step_count)

    # Add the stepcount column to the DataFrame
    df['stepcount'] = step_counts

    # Group by 'step' and filter out groups with more than one unique 'walk_mode' label
    filtered_df = (
        df.groupby('stepcount')
        .filter(lambda x: x['walk_mode'].nunique() == 1)
    )

    # Reassign the `stepcount` column to be continuous and start from 1
    filtered_df['stepcount'] = pd.factorize(filtered_df['stepcount'])[0] + 1

    filtered_df.to_csv(os.path.join(folder_path, "merged_gait_count_annotations.csv"), index=False)

# %%
dataset_path = "data_set"

print("Adding gait count according to the provided annotations...")
# Iterate through the directory structure
for course_folder in os.listdir(dataset_path):
    course_folder_path = os.path.join(dataset_path, course_folder)
    if os.path.isdir(course_folder_path):
        for subfolder in os.listdir(course_folder_path):
            subfolder_path = os.path.join(course_folder_path, subfolder)
            if os.path.isdir(subfolder_path):
                add_gait_count(subfolder_path)
print("Gait count added successfully")
# Out:
# Adding gait count according to the provided annotations...
# Workinig on data_set\courseA\id01
# Workinig on data_set\courseA\id02
# Workinig on data_set\courseA\id03
# Workinig on data_set\courseA\id04
# Workinig on data_set\courseA\id05
# Workinig on data_set\courseA\id07
# Workinig on data_set\courseA\id08
# Workinig on data_set\courseA\id10
# Workinig on data_set\courseA\id12
# Workinig on data_set\courseA\id13
# Workinig on data_set\courseA\id14
# Workinig on data_set\courseA\id15
# Workinig on data_set\courseA\id16
# Workinig on data_set\courseA\id17
# Workinig on data_set\courseA\id18
# Workinig on data_set\courseA\id19
# Workinig on data_set\courseA\id22
# Workinig on data_set\courseA\id23
# Workinig on data_set\courseA\id24
# Workinig on data_set\courseA\id25
# Workinig on data_set\courseB\id01
# Workinig on data_set\courseB\id02
# Workinig on data_set\courseB\id03
# Workinig on data_set\courseB\id04
# Workinig on data_set\courseB\id05
# Workinig on data_set\courseB\id07
# Workinig on data_set\courseB\id08
# Workinig on data_set\courseB\id10
# Workinig on data_set\courseB\id12
# Workinig on data_set\courseB\id13
# Workinig on data_set\courseB\id14
# Workinig on data_set\courseB\id15
# Workinig on data_set\courseB\id16
# Workinig on data_set\courseB\id17
# Workinig on data_set\courseB\id18
# Workinig on data_set\courseB\id19
# Workinig on data_set\courseB\id22
# Workinig on data_set\courseB\id23
# Workinig on data_set\courseB\id24
# Workinig on data_set\courseB\id25
# Workinig on data_set\courseC\id01
# Workinig on data_set\courseC\id02
# Workinig on data_set\courseC\id03
# Workinig on data_set\courseC\id04
# Workinig on data_set\courseC\id05
# Workinig on data_set\courseC\id07
# Workinig on data_set\courseC\id08
# Workinig on data_set\courseC\id10
# Workinig on data_set\courseC\id12
# Workinig on data_set\courseC\id13
# Workinig on data_set\courseC\id14
# Workinig on data_set\courseC\id15
# Workinig on data_set\courseC\id16
# Workinig on data_set\courseC\id17
# Workinig on data_set\courseC\id18
# Workinig on data_set\courseC\id19
# Workinig on data_set\courseC\id22
# Workinig on data_set\courseC\id23
# Workinig on data_set\courseC\id24
# Workinig on data_set\courseC\id25
# Gait count added successfully
