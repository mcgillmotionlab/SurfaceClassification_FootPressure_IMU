# %%
# !pip install ijson==3.2.1
# Out:
# Collecting ijson==3.2.1
#   Downloading ijson-3.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Downloading ijson-3.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: ijson
# Successfully installed ijson-3.2.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import ijson
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

# %%
def load_files_to_dfs(folder_path):
    # List to store the dataframes
    honda_dfs = []

    # Get all folders (assuming they are numbered and in the folder_path)
    for folder in os.listdir(folder_path):
        folder_num = folder  # Folder name (assuming it is the number)
        folder_full_path = os.path.join(folder_path, folder)

        if os.path.isdir(folder_full_path):
            # Look specifically for the 'xsens.csv' and 'labels.csv' file in each folder
            file_path_xsens = os.path.join(folder_full_path, 'xsens.csv')
            file_path_labels = os.path.join(folder_full_path, 'labels.csv')

            # making sure both paths exist prior to uploading df
            if os.path.exists(file_path_xsens):
                if os.path.exists(file_path_labels):
                    # Load the files into a DataFrames (assuming csv format)
                    df_xsens = pd.read_csv(file_path_xsens)
                    df_labels = pd.read_csv(file_path_labels)

                    # Merge the two DataFrames on the 'time', 'participant_id', 'task' column
                    df = pd.merge(df_xsens, df_labels, on=['time', 'participant_id', 'task'])

                    # Add participant_num column
                    df['participant_num'] = folder_num
                    print(folder_num)

                    # Add the DataFrame to the list
                    honda_dfs.append(df)

    return honda_dfs

# Usage example
folder_path = '/content/drive/MyDrive/Next_Step/Honda: multi_modal_gait_database/data_set/courseA'  # Replace with the path to the main directory containing folders
dataframes = load_files_to_dfs(folder_path)

# # Print the dataframes list
# for idx, df in enumerate(dataframes):
#     print(f"DataFrame from folder {idx + 1}:\n", df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-6ab5ed81cad3> in <cell line: 36>()
#      34 # Usage example
#      35 folder_path = '/content/drive/MyDrive/Next_Step/Honda: multi_modal_gait_database/data_set/CourseB'  # Replace with the path to the main directory containing folders
# ---> 36 dataframes = load_files_to_dfs(folder_path)
#      37
#      38 # # Print the dataframes list
#
# <ipython-input-26-6ab5ed81cad3> in load_files_to_dfs(folder_path)
#       4
#       5     # Get all folders (assuming they are numbered and in the folder_path)
# ----> 6     for folder in os.listdir(folder_path):
#       7         folder_num = folder  # Folder name (assuming it is the number)
#       8         folder_full_path = os.path.join(folder_path, folder)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Next_Step/Honda: multi_modal_gait_database/data_set/CourseB'

# %%
len(dataframes)
# Out:
# 20

# %%
dataframes_copy = dataframes

# %%
# list(dataframes_copy[0].columns)

# %%
dataframes[0]['walk_mode'].unique()
# Out:
# array(['walk', 'slope_down', 'slope_up', 'stairs_up'], dtype=object)

# %%
sensor_types = ['orientation','position','velocity','acceleration','angularVelocity','angularAcceleration','sensorFreeAcceleration','sensorMagneticField','sensorOrientation','jointAngle','jointAngleXZY']

sensor_locations = ['Pelvis', 'L5', 'L3', 'T12', 'T8', 'Neck', 'Head', 'RightShoulder', 'RightUpperArm', 'RightForeArm', 'RightHand', 'LeftShoulder', 'LeftUpperArm', 'LeftForeArm', 'LeftHand', 'RightUpperLeg', 'RightLowerLeg',
                    'RightFoot', 'RightToe', 'LeftUpperLeg', 'LeftLowerLeg', 'LeftFoot', 'LeftToe']

axes = ['x', 'y', 'z', 'ql', 'qi', 'qj', 'qk']

columns = ['walk_mode', 'time', 'participant_id', 'task', 'sensor_location', 'orientation_q1', 'orientation_qi', 'orientation_qj', 'orientation_qk',
           'position_x', 'position_y', 'position_z', 'velocity_x', 'velocity_y', 'velocity_z', 'acceleration_x', 'acceleration_y', 'acceleration_z',
           'angularVelocity_x', 'angularVelocity_y', 'angularVelocity_z', 'angularAcceleration_x', 'angularAcceleration_y', 'angularAcceleration_z',
           'sensorFreeAcceleration_x', 'sensorFreeAcceleration_y', 'sensorFreeAcceleration_z', 'sensorMagneticField_x', 'sensorMagneticField_y',
           'sensorMagneticField_z', 'sensorOrientation_q1', 'sensorOrientation_qi', 'sensorOrientation_qj', 'sensorOrientation_qk', 'jointAngle_x',
           'jointAngle_y', 'jointAngle_z', 'jointAngleXZY_x', 'jointAngleXZY_y', 'jointAngleXZY_z']

# %%
new_column_names = {
    'index': 'index',
    'orientation_q1': 'OriInc_q0',                      # omit in future
    'orientation_qi': 'OriInc_q1',                      # omit in future
    'orientation_qj': 'OriInc_q2',                      # omit in future
    'orientation_qk': 'OriInc_q3',                      # omit in future
    'sensor_location': 'sensor_location',
    'position_x': 'Position_X',                         # omit in future
    'position_y': 'Position_Y',                         # omit in future
    'position_z': 'Position_Z',                         # omit in future
    'velocity_x': 'VelInc_X',                           # omit in future
    'velocity_y': 'VelInc_Y',                           # omit in future
    'velocity_z': 'VelInc_Z',                           # omit in future
    'acceleration_x': 'Acc_X',
    'acceleration_y': 'Acc_Y',
    'acceleration_z': 'Acc_Z',
    'angularVelocity_x': 'Gyr_X',
    'angularVelocity_y': 'Gyr_Y',
    'angularVelocity_z': 'Gyr_Z',
    'angularAcceleration_x': 'AngularAcceleration_X',   # omit in future
    'angularAcceleration_y': 'AngularAcceleration_Y',   # omit in future
    'angularAcceleration_z': 'AngularAcceleration_Z',   # omit in future
    'sensorFreeAcceleration_x': 'FreeAcc_X',
    'sensorFreeAcceleration_y': 'FreeAcc_Y',
    'sensorFreeAcceleration_z': 'FreeAcc_Z',
    'sensorMagneticField_x': 'Mag_X',
    'sensorMagneticField_y': 'Mag_Y',
    'sensorMagneticField_z': 'Mag_Z',
    'sensorOrientation_q1': 'sensorOrientation_q1',     # omit in future
    'sensorOrientation_qi': 'sensorOrientation_qi',     # omit in future
    'sensorOrientation_qj': 'sensorOrientation_qj',     # omit in future
    'sensorOrientation_qk': 'sensorOrientation_qk',     # omit in future
    'jointAngle_x': 'JointAngle_X',                     # omit in future
    'jointAngle_y': 'JointAngle_Y',                     # omit in future
    'jointAngle_z': 'JointAngle_Z',                     # omit in future
    'jointAngleXZY_x': 'Roll',                          # omit in future
    'jointAngleXZY_y': 'Pitch',                         # omit in future
    'jointAngleXZY_z': 'Yaw'                            # omit in future
}

# %%
# get the 5 types of surfaces/actions done in this dataset
walk_modes = dataframes_copy[0]['walk_mode'].unique()

# create a subset dataframe for each of the types
subset_dfs = {}
for walk_mode in walk_modes:
  for df in dataframes_copy:
      identifier = walk_mode + '_' + df['participant_num'].iloc[0]
      if identifier not in subset_dfs:
          subset_dfs[identifier] = df[df['walk_mode'] == walk_mode]

# %%
# subset_dfs.keys()

# %%
subset_dfs['slope_up_id12']
# Out:
#          time  participant_id task  orientation_Pelvis_q1  \
# 3369    56150              12    B              -0.997874
# 3370    56167              12    B              -0.997711
# 3371    56183              12    B              -0.997551
# 3372    56200              12    B              -0.997422
# 3373    56217              12    B              -0.997367
# ...       ...             ...  ...                    ...
# 30948  515800              12    B              -0.997126
# 30949  515817              12    B              -0.997331
# 30950  515833              12    B              -0.997635
# 30951  515850              12    B              -0.998140
# 30952  515867              12    B              -0.998608
#
#        orientation_Pelvis_qi  orientation_Pelvis_qj  orientation_Pelvis_qk  \
# 3369               -0.015332              -0.004589               0.063177
# 3370               -0.003879              -0.003003               0.067449
# 3371                0.007205              -0.001577               0.069558
# 3372                0.015958              -0.000924               0.069950
# 3373                0.021087               0.000059               0.069392
# ...                      ...                    ...                    ...
# 30948              -0.011914              -0.000285              -0.074821
# 30949              -0.014365              -0.000540              -0.071590
# 30950              -0.016925              -0.003531              -0.066519
# 30951              -0.019433              -0.004947              -0.057572
# 30952              -0.024025              -0.003185              -0.046841
#
#        orientation_L5_q1  orientation_L5_qi  orientation_L5_qj  ...  \
# 3369           -0.994699          -0.012586          -0.026812  ...
# 3370           -0.994729          -0.006569          -0.024187  ...
# 3371           -0.994843          -0.000658          -0.022280  ...
# 3372           -0.995018           0.004017          -0.021477  ...
# 3373           -0.995250           0.006587          -0.020977  ...
# ...                  ...                ...                ...  ...
# 30948          -0.993817          -0.009327          -0.035550  ...
# 30949          -0.994009          -0.011500          -0.035017  ...
# 30950          -0.994261          -0.013871          -0.035524  ...
# 30951          -0.994757          -0.016214          -0.034882  ...
# 30952          -0.995372          -0.019282          -0.032617  ...
#
#        insoles_RightFoot_time_to_lift  xsens_footContacts_LeftFoot_Heel  \
# 3369                            633.0                             False
# 3370                            616.0                             False
# 3371                            600.0                             False
# 3372                            583.0                             False
# 3373                            566.0                             False
# ...                               ...                               ...
# 30948                           217.0                             False
# 30949                           200.0                             False
# 30950                           184.0                              True
# 30951                           167.0                              True
# 30952                           150.0                              True
#
#        xsens_footContacts_LeftFoot_Toe  xsens_footContacts_RightFoot_Heel  \
# 3369                             False                               True
# 3370                             False                               True
# 3371                             False                               True
# 3372                             False                               True
# 3373                             False                               True
# ...                                ...                                ...
# 30948                            False                              False
# 30949                            False                              False
# 30950                            False                              False
# 30951                            False                              False
# 30952                            False                              False
#
#        xsens_footContacts_RightFoot_Toe       walk_orientation  \
# 3369                              False             curve_left
# 3370                              False             curve_left
# 3371                              False             curve_left
# 3372                              False             curve_left
# 3373                              False             curve_left
# ...                                 ...                    ...
# 30948                             False  turn_around_clockwise
# 30949                             False  turn_around_clockwise
# 30950                             False  turn_around_clockwise
# 30951                             False  turn_around_clockwise
# 30952                              True  turn_around_clockwise
#
#        walk_interaction  walk_mode_id  walk_orientation_id  participant_num
# 3369                 no             3                    6             id12
# 3370                 no             3                    6             id12
# 3371                 no             3                    6             id12
# 3372                 no             3                    6             id12
# 3373                 no             3                    6             id12
# ...                 ...           ...                  ...              ...
# 30948                no             3                    8             id12
# 30949                no             3                    8             id12
# 30950                no             3                    8             id12
# 30951                no             3                    8             id12
# 30952                no             3                    8             id12
#
# [5825 rows x 778 columns]

# %%
import pandas as pd

# Define your list of sensor locations
sensor_locations = ['Pelvis', 'L5', 'L3', 'T12', 'T8', 'Neck', 'Head', 'RightShoulder', 'RightUpperArm', 'RightForeArm', 'RightHand',
                    'LeftShoulder', 'LeftUpperArm', 'LeftForeArm', 'LeftHand', 'RightUpperLeg', 'RightLowerLeg', 'RightFoot',
                    'RightToe', 'LeftUpperLeg', 'LeftLowerLeg', 'LeftFoot', 'LeftToe']

# Function to extract the sensor location from a column name based on the sensor_locations list
def extract_sensor_location(column_name):
    for location in sensor_locations:
        if location in column_name:
            return location
    return None

# Function to remove the sensor location from a column name
def remove_sensor_location(column_name):
    for location in sensor_locations:
        if location in column_name:
            # Remove the sensor location from the column name
            return column_name.replace(location, '').strip('_')
    return column_name

# Loop over each DataFrame in subset_dfs (assuming it's a dictionary of trial DataFrames)
for key, trial_df in subset_dfs.items():
    df_list = []
    surface_type = key.split('_')
    if len(surface_type) > 2:
        surface_type = ' '.join(surface_type[:2])
    else:
        surface_type = surface_type[0]

    # For each sensor, collect relevant columns and create a new DataFrame
    for sensor_location in sensor_locations:
        # Find all columns related to this sensor location
        sensor_columns = [col for col in trial_df.columns if sensor_location in col]

        if sensor_columns:
            # Create a new DataFrame for this sensor
            df_by_sensor = pd.DataFrame({
                "time": trial_df["time"],
                "participant_id": trial_df["participant_id"],
                "task": trial_df["task"],
                "surface_type": surface_type,  # Use the derived surface type
                "sensor_location": sensor_location
            })

            # For each sensor-related column, add it to the new DataFrame
            for col in sensor_columns:
                # Remove sensor location from the column name for readability
                new_column_name = remove_sensor_location(col)
                df_by_sensor[new_column_name] = trial_df[col]

            # Append the sensor DataFrame to the list
            df_list.append(df_by_sensor)

    # Concatenate all DataFrames for this trial, if any were created
    if df_list:
        df = pd.concat(df_list)

        # Export df to CSV
        df.to_csv(f'/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/{key}.csv', index=False)

        # Clear the local memory
        # del df_list
        # del df

        print(f"Processed {key}")
    else:
        print(f"No valid sensor columns to process for {key}")
# Out:
# Processed walk_id15
# Processed walk_id01
# Processed walk_id12
# Processed walk_id14
# Processed walk_id24
# Processed walk_id23
# Processed walk_id08
# Processed walk_id07
# Processed walk_id25
# Processed walk_id22
# Processed walk_id19
# Processed walk_id02
# Processed walk_id04
# Processed walk_id10
# Processed walk_id16
# Processed walk_id18
# Processed walk_id17
# Processed walk_id05
# Processed walk_id13
# Processed walk_id03
# Processed slope_down_id15
# Processed slope_down_id01
# Processed slope_down_id12
# Processed slope_down_id14
# Processed slope_down_id24
# Processed slope_down_id23
# Processed slope_down_id08
# Processed slope_down_id07
# Processed slope_down_id25
# Processed slope_down_id22
# Processed slope_down_id19
# Processed slope_down_id02
# Processed slope_down_id04
# Processed slope_down_id10
# Processed slope_down_id16
# Processed slope_down_id18
# Processed slope_down_id17
# Processed slope_down_id05
# Processed slope_down_id13
# Processed slope_down_id03
# Processed slope_up_id15
# Processed slope_up_id01
# Processed slope_up_id12
# Processed slope_up_id14
# Processed slope_up_id24
# Processed slope_up_id23
# Processed slope_up_id08
# Processed slope_up_id07
# Processed slope_up_id25
# Processed slope_up_id22
# Processed slope_up_id19
# Processed slope_up_id02
# Processed slope_up_id04
# Processed slope_up_id10
# Processed slope_up_id16
# Processed slope_up_id18
# Processed slope_up_id17
# Processed slope_up_id05
# Processed slope_up_id13
# Processed slope_up_id03
# Processed stairs_up_id15
# Processed stairs_up_id01
# Processed stairs_up_id12
# Processed stairs_up_id14
# Processed stairs_up_id24
# Processed stairs_up_id23
# Processed stairs_up_id08
# Processed stairs_up_id07
# Processed stairs_up_id25
# Processed stairs_up_id22
# Processed stairs_up_id19
# Processed stairs_up_id02
# Processed stairs_up_id04
# Processed stairs_up_id10
# Processed stairs_up_id16
# Processed stairs_up_id18
# Processed stairs_up_id17
# Processed stairs_up_id05
# Processed stairs_up_id13
# Processed stairs_up_id03

# %%
# # this is all the data for participant 1 from course A
# ['slope_down_id01']
# ['walk_id01']
# ['slope_up_id01']
# ['stairs_down_id01']
# ['stairs_up_id01']

# %%
subset_dfs.keys()
# Out:
# dict_keys(['walk_id15', 'walk_id01', 'walk_id12', 'walk_id14', 'walk_id24', 'walk_id23', 'walk_id08', 'walk_id07', 'walk_id25', 'walk_id22', 'walk_id19', 'walk_id02', 'walk_id04', 'walk_id10', 'walk_id16', 'walk_id18', 'walk_id17', 'walk_id05', 'walk_id13', 'walk_id03', 'slope_down_id15', 'slope_down_id01', 'slope_down_id12', 'slope_down_id14', 'slope_down_id24', 'slope_down_id23', 'slope_down_id08', 'slope_down_id07', 'slope_down_id25', 'slope_down_id22', 'slope_down_id19', 'slope_down_id02', 'slope_down_id04', 'slope_down_id10', 'slope_down_id16', 'slope_down_id18', 'slope_down_id17', 'slope_down_id05', 'slope_down_id13', 'slope_down_id03', 'slope_up_id15', 'slope_up_id01', 'slope_up_id12', 'slope_up_id14', 'slope_up_id24', 'slope_up_id23', 'slope_up_id08', 'slope_up_id07', 'slope_up_id25', 'slope_up_id22', 'slope_up_id19', 'slope_up_id02', 'slope_up_id04', 'slope_up_id10', 'slope_up_id16', 'slope_up_id18', 'slope_up_id17', 'slope_up_id05', 'slope_up_id13', 'slope_up_id03', 'stairs_up_id15', 'stairs_up_id01', 'stairs_up_id12', 'stairs_up_id14', 'stairs_up_id24', 'stairs_up_id23', 'stairs_up_id08', 'stairs_up_id07', 'stairs_up_id25', 'stairs_up_id22', 'stairs_up_id19', 'stairs_up_id02', 'stairs_up_id04', 'stairs_up_id10', 'stairs_up_id16', 'stairs_up_id18', 'stairs_up_id17', 'stairs_up_id05', 'stairs_up_id13', 'stairs_up_id03'])

# %%
import os
import shutil

# Iterate over subset_dfs items
for key, value in subset_dfs.items():
    # Extract participant ID
    participant = key.split('_')[-1]
    participant_number = participant[-2:]

    # Define the directory for this participant
    participant_dir = f'/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/Participant_{participant_number}'

    # Create the participant folder if it doesn't exist
    os.makedirs(participant_dir, exist_ok=True)

    # Define the source CSV file path
    source_file = f'/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/{key}.csv'

    # Define the destination file path in the participant's folder
    destination_file = os.path.join(participant_dir, f'{key}.csv')

    # Move the file if it exists
    if os.path.exists(source_file):
        shutil.move(source_file, destination_file)
        print(f"Moved {source_file} to {destination_file}")
    else:
        print(f"{source_file} does not exist")
# Out:
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id15.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_15/walk_id15.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id01.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_01/walk_id01.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id12.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_12/walk_id12.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id14.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_14/walk_id14.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id24.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_24/walk_id24.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id23.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_23/walk_id23.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id08.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_08/walk_id08.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id07.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_07/walk_id07.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id25.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_25/walk_id25.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id22.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_22/walk_id22.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id19.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_19/walk_id19.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id02.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_02/walk_id02.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id04.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_04/walk_id04.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id10.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_10/walk_id10.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id16.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_16/walk_id16.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id18.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_18/walk_id18.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id17.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_17/walk_id17.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id05.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_05/walk_id05.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id13.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_13/walk_id13.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/walk_id03.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_03/walk_id03.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id15.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_15/slope_down_id15.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id01.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_01/slope_down_id01.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id12.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_12/slope_down_id12.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id14.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_14/slope_down_id14.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id24.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_24/slope_down_id24.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id23.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_23/slope_down_id23.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id08.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_08/slope_down_id08.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id07.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_07/slope_down_id07.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id25.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_25/slope_down_id25.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id22.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_22/slope_down_id22.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id19.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_19/slope_down_id19.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id02.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_02/slope_down_id02.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id04.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_04/slope_down_id04.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id10.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_10/slope_down_id10.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id16.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_16/slope_down_id16.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id18.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_18/slope_down_id18.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id17.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_17/slope_down_id17.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id05.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_05/slope_down_id05.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id13.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_13/slope_down_id13.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_down_id03.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_03/slope_down_id03.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id15.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_15/slope_up_id15.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id01.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_01/slope_up_id01.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id12.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_12/slope_up_id12.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id14.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_14/slope_up_id14.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id24.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_24/slope_up_id24.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id23.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_23/slope_up_id23.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id08.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_08/slope_up_id08.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id07.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_07/slope_up_id07.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id25.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_25/slope_up_id25.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id22.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_22/slope_up_id22.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id19.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_19/slope_up_id19.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id02.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_02/slope_up_id02.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id04.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_04/slope_up_id04.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id10.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_10/slope_up_id10.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id16.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_16/slope_up_id16.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id18.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_18/slope_up_id18.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id17.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_17/slope_up_id17.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id05.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_05/slope_up_id05.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id13.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_13/slope_up_id13.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/slope_up_id03.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_03/slope_up_id03.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id15.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_15/stairs_up_id15.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id01.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_01/stairs_up_id01.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id12.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_12/stairs_up_id12.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id14.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_14/stairs_up_id14.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id24.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_24/stairs_up_id24.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id23.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_23/stairs_up_id23.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id08.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_08/stairs_up_id08.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id07.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_07/stairs_up_id07.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id25.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_25/stairs_up_id25.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id22.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_22/stairs_up_id22.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id19.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_19/stairs_up_id19.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id02.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_02/stairs_up_id02.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id04.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_04/stairs_up_id04.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id10.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_10/stairs_up_id10.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id16.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_16/stairs_up_id16.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id18.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_18/stairs_up_id18.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id17.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_17/stairs_up_id17.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id05.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_05/stairs_up_id05.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id13.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_13/stairs_up_id13.csv
# Moved /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/stairs_up_id03.csv to /content/drive/MyDrive/Next_Step/Honda_Participants/CourseB/Participant_03/stairs_up_id03.csv

# %%
import os
import pandas as pd
from glob import glob

# Define the folder path containing your subfolders with CSV files
folder_path = '/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA'  # Replace with your actual folder path

# Create an empty dictionary to store the merged DataFrames
merged_df_dict = {}

# Get a list of all subdirectories within the main folder
subfolders = [f.path for f in os.scandir(folder_path) if f.is_dir()]

# Function to merge CSV files in a single subfolder
def merge_csv_files_in_folder(subfolder_path):
    # Get all CSV files in the subfolder
    csv_files = glob(os.path.join(subfolder_path, '*.csv'))

    # If there are CSV files in the folder, read and merge them
    if csv_files:
        # Read each CSV file and store them in a list
        df_list = [pd.read_csv(file, low_memory=False) for file in csv_files]

        # Merge the DataFrames
        merged_df = pd.concat(df_list, ignore_index=True)

        # Extract folder name to create a key for the merged DataFrame
        folder_name = os.path.basename(subfolder_path)

        # Return the merged DataFrame with folder name as the key
        print(f"Merged {len(csv_files)} CSV files in folder: {folder_name}")
        return folder_name, merged_df
    else:
        print(f"No CSV files found in {subfolder_path}")
        return None

for subfolder in subfolders:
    result = merge_csv_files_in_folder(subfolder)
    if result:
        key, merged_df = result
        merged_df_dict[key] = merged_df

for key, df in merged_df_dict.items():
    df.to_csv(f'/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/{key}_merged.csv', index=False)

print(f"Processed {len(merged_df_dict)} folders and merged their CSV files.")
# Out:
# Merged 4 CSV files in folder: Participant_15
# Merged 4 CSV files in folder: Participant_01
# Merged 4 CSV files in folder: Participant_12
# Merged 4 CSV files in folder: Participant_14
# Merged 4 CSV files in folder: Participant_24
# Merged 4 CSV files in folder: Participant_23
# Merged 4 CSV files in folder: Participant_08
# Merged 4 CSV files in folder: Participant_07
# Merged 4 CSV files in folder: Participant_25
# Merged 4 CSV files in folder: Participant_22
# Merged 4 CSV files in folder: Participant_19
# Merged 4 CSV files in folder: Participant_02
# Merged 4 CSV files in folder: Participant_04
# Merged 4 CSV files in folder: Participant_10
# Merged 4 CSV files in folder: Participant_16
# Merged 4 CSV files in folder: Participant_18
# Merged 4 CSV files in folder: Participant_17
# Merged 4 CSV files in folder: Participant_05
# Merged 4 CSV files in folder: Participant_13
# Merged 4 CSV files in folder: Participant_03

# %%
import ijson
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json

# %%
def load_files_to_dfs(folder_path):
    # List to store the dataframes
    honda_dfs = []

    # Get all folders (assuming they are numbered and in the folder_path)
    for folder in os.listdir(folder_path):
        folder_num = folder  # Folder name (assuming it is the number)
        folder_full_path = os.path.join(folder_path, folder)

        if os.path.isdir(folder_full_path):
            # Look specifically for the 'insoles.csv' and 'labels.csv' file in each folder
            file_path_insoles = os.path.join(folder_full_path, 'insoles.csv')
            file_path_labels = os.path.join(folder_full_path, 'labels.csv')

            # making sure both paths exist prior to uploading df
            if os.path.exists(file_path_insoles):
                if os.path.exists(file_path_labels):
                    # Load the files into a DataFrames (assuming csv format)
                    df_insoles = pd.read_csv(file_path_insoles)
                    df_labels = pd.read_csv(file_path_labels)

                    # Merge the two DataFrames on the 'time', 'participant_id', 'task' column
                    df = pd.merge(df_insoles, df_labels, on=['time', 'participant_id', 'task'])

                    # Add participant_num column
                    df['participant_num'] = folder_num
                    print(folder_num)

                    # Add the DataFrame to the list
                    honda_dfs.append(df)

    return honda_dfs

# Usage example
folder_path = '/content/drive/MyDrive/Next_Step/Honda: multi_modal_gait_database/data_set/courseA'  # Replace with the path to the main directory containing folders
dataframes = load_files_to_dfs(folder_path)

# # Print the dataframes list
# for idx, df in enumerate(dataframes):
#     print(f"DataFrame from folder {idx + 1}:\n", df.head())
# Out:
# id08
# id22
# id23
# id07
# id14
# id12
# id24
# id25
# id15
# id01
# id16
# id13
# id05
# id03
# id19
# id17
# id10
# id04
# id02
# id18

# %%
len(dataframes)
# Out:
# 20

# %%
dataframes_copy = dataframes

# %%
#list all the columns
# list(dataframes[0].columns)

# %%
dataframes[0]['walk_mode'].unique()
# Out:
# array(['walk', 'stairs_down', 'stairs_up', 'slope_down', 'slope_up'],
#       dtype=object)

# %%
dataframes[0]
# Out:
#        Unnamed: 0    time  participant_id task  Left_Hallux  Left_Toes  \
# 0               0       0               8    A        179.0        6.0
# 1               1      17               8    A        177.0        3.0
# 2               2      34               8    A        175.0        0.0
# 3               3      50               8    A        179.0        0.0
# 4               4      67               8    A        181.0        3.0
# ...           ...     ...             ...  ...          ...        ...
# 43356       43356  722600               8    A          2.0        0.0
# 43357       43357  722617               8    A          1.0        2.0
# 43358       43358  722634               8    A          3.0        1.0
# 43359       43359  722650               8    A          1.0        1.0
# 43360       43360  722667               8    A          0.0        0.0
#
#        Left_Met1  Left_Met3  Left_Met5  Left_Arch  ...  \
# 0            2.0      229.0      337.0      366.0  ...
# 1            4.0      231.0      341.0      359.0  ...
# 2            3.0      235.0      337.0      366.0  ...
# 3            1.0      234.0      338.0      360.0  ...
# 4            0.0      235.0      338.0      361.0  ...
# ...          ...        ...        ...        ...  ...
# 43356        0.0        1.0        1.0        2.0  ...
# 43357        4.0        1.0        0.0        1.0  ...
# 43358        0.0        0.0        3.0        1.0  ...
# 43359        3.0        1.0        4.0        1.0  ...
# 43360        0.0        1.0        3.0        3.0  ...
#
#        insoles_RightFoot_time_to_lift  xsens_footContacts_LeftFoot_Heel  \
# 0                               767.0                             False
# 1                               750.0                             False
# 2                               733.0                             False
# 3                               717.0                             False
# 4                               700.0                             False
# ...                               ...                               ...
# 43356                            -1.0                             False
# 43357                            -1.0                             False
# 43358                            -1.0                             False
# 43359                            -1.0                             False
# 43360                            -1.0                             False
#
#        xsens_footContacts_LeftFoot_Toe  xsens_footContacts_RightFoot_Heel  \
# 0                                False                               True
# 1                                False                               True
# 2                                 True                               True
# 3                                False                               True
# 4                                False                               True
# ...                                ...                                ...
# 43356                            False                              False
# 43357                            False                              False
# 43358                            False                              False
# 43359                            False                              False
# 43360                            False                               True
#
#        xsens_footContacts_RightFoot_Toe  walk_orientation  walk_interaction  \
# 0                                 False          straight                no
# 1                                 False          straight                no
# 2                                 False          straight                no
# 3                                 False          straight                no
# 4                                 False          straight                no
# ...                                 ...               ...               ...
# 43356                             False          straight                no
# 43357                             False          straight                no
# 43358                             False          straight                no
# 43359                             False          straight                no
# 43360                             False          straight                no
#
#        walk_mode_id  walk_orientation_id  participant_num
# 0                 1                    1             id08
# 1                 1                    1             id08
# 2                 1                    1             id08
# 3                 1                    1             id08
# 4                 1                    1             id08
# ...             ...                  ...              ...
# 43356            16                    5             id08
# 43357            16                    5             id08
# 43358            16                    5             id08
# 43359            16                    5             id08
# 43360            16                    5             id08
#
# [43361 rows x 112 columns]

# %%
sensor_types = ['Acc','Mag','Gyr']

leg = ['Left', 'Right']

sensor_locations = ['Hallux', 'Toes', 'Met1', 'Met3', 'Met5', 'Arch', 'Heel_R', 'Heel_L']

axes = ['x', 'y', 'z', 'raw', 'norm']

columns = ['Unnamed: 0', 'time', 'participant_id', 'task', 'Left_Hallux', 'Left_Toes', 'Left_Met1',
           'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R', 'Left_Heel_L', 'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z',
           'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x', 'Left_Mag_y', 'Left_Mag_z', 'Left_Temp', 'Right_Hallux',
           'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5', 'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'Right_Acc_x',
           'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x', 'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z',
           'Right_Temp', 'Right_Toes_raw', 'Right_Hallux_raw', 'Right_Met5_raw', 'Right_Met3_raw', 'Right_Met1_raw', 'Right_Arch_raw', 'Right_Heel_R_raw',
           'Right_Heel_L_raw', 'Left_Toes_raw', 'Left_Hallux_raw', 'Left_Met5_raw', 'Left_Met3_raw', 'Left_Met1_raw', 'Left_Arch_raw', 'Left_Heel_R_raw',
           'Left_Heel_L_raw', 'Right_Acc_x_raw', 'Right_Acc_y_raw', 'Right_Acc_z_raw', 'Right_Mag_x_raw', 'Right_Mag_y_raw', 'Right_Mag_z_raw', 'Right_Gyr_x_raw',
           'Right_Gyr_y_raw', 'Right_Gyr_z_raw', 'Left_Acc_x_raw', 'Left_Acc_y_raw', 'Left_Acc_z_raw', 'Left_Mag_x_raw', 'Left_Mag_z_raw', 'Left_Gyr_x_raw',
           'Left_Gyr_y_raw', 'Left_Gyr_z_raw', 'Left_Hallux_norm', 'Left_Toes_norm', 'Left_Met1_norm', 'Left_Met3_norm', 'Left_Met5_norm', 'Left_Arch_norm',
           'Left_Heel_R_norm', 'Left_Heel_L_norm', 'Right_Hallux_norm', 'Right_Toes_norm', 'Right_Met1_norm', 'Right_Met3_norm', 'Right_Met5_norm', 'Right_Arch_norm',
           'Right_Heel_L_norm', 'Right_Heel_R_norm', 'Left_Max_Pressure_norm', 'Right_Max_Pressure_norm', 'walk_mode', 'repetition', 'insoles_RightFoot_is_step',
           'insoles_LeftFoot_is_step', 'insoles_RightFoot_is_lifted', 'insoles_LeftFoot_is_lifted', 'insoles_LeftFoot_on_ground',
           'insoles_RightFoot_on_ground', 'insoles_LeftFoot_time_to_step', 'insoles_LeftFoot_time_to_lift', 'insoles_RightFoot_time_to_step',
           'insoles_RightFoot_time_to_lift', 'xsens_footContacts_LeftFoot_Heel', 'xsens_footContacts_LeftFoot_Toe', 'xsens_footContacts_RightFoot_Heel',
           'xsens_footContacts_RightFoot_Toe', 'walk_orientation', 'walk_interaction', 'walk_mode_id', 'walk_orientation_id', 'participant_num']

# %%
# get the 5 types of surfaces/actions done in this dataset
walk_modes = dataframes_copy[0]['walk_mode'].unique()

# create a subset dataframe for each of the types
subset_dfs = {}
for walk_mode in walk_modes:
  for df in dataframes_copy:
      identifier = walk_mode + '_' + df['participant_num'].iloc[0]
      if identifier not in subset_dfs:
          subset_dfs[identifier] = df[df['walk_mode'] == walk_mode]

# %%
# change the column names wiht no suffix to have

# %%
# subset_dfs['slope_up_id12']

# %%
extras_df = []

for key, df in subset_dfs.items():
    df.columns = columns
    # keep only listed columns
    df = df[['Unnamed: 0', 'time', 'participant_id', 'task','Left_Max_Pressure_norm', 'Right_Max_Pressure_norm', 'walk_mode', 'repetition', 'insoles_RightFoot_is_step',
           'insoles_LeftFoot_is_step', 'insoles_RightFoot_is_lifted', 'insoles_LeftFoot_is_lifted', 'insoles_LeftFoot_on_ground',
           'insoles_RightFoot_on_ground', 'insoles_LeftFoot_time_to_step', 'insoles_LeftFoot_time_to_lift', 'insoles_RightFoot_time_to_step',
           'insoles_RightFoot_time_to_lift', 'xsens_footContacts_LeftFoot_Heel', 'xsens_footContacts_LeftFoot_Toe', 'xsens_footContacts_RightFoot_Heel',
           'xsens_footContacts_RightFoot_Toe', 'walk_orientation', 'walk_interaction']]

    extras_df.append(df)

# Concatenate all trials into a single DataFrame
all_foot_sensor_extras_df = pd.concat(extras_df, ignore_index=True)

# %%
all_foot_sensor_extras_df
# Out:
#         Unnamed: 0    time  participant_id task  Left_Max_Pressure_norm  \
# 0                0       0               8    A                0.906009
# 1                1      17               8    A                0.911848
# 2                2      34               8    A                0.906569
# 3                3      50               8    A                0.934059
# 4                4      67               8    A                0.955711
# ...            ...     ...             ...  ...                     ...
# 846710       45502  758366              18    A                1.000000
# 846711       45503  758383              18    A                1.000000
# 846712       45504  758400              18    A                1.000000
# 846713       45505  758416              18    A                1.000000
# 846714       45506  758433              18    A                0.930026
#
#         Right_Max_Pressure_norm walk_mode  repetition  \
# 0                      0.380305      walk           1
# 1                      0.448660      walk           1
# 2                      0.473807      walk           1
# 3                      0.504003      walk           1
# 4                      0.516030      walk           1
# ...                         ...       ...         ...
# 846710                 0.002514  slope_up           3
# 846711                 0.001969  slope_up           3
# 846712                 0.001572  slope_up           3
# 846713                 0.003207  slope_up           3
# 846714                 0.011678  slope_up           3
#
#         insoles_RightFoot_is_step  insoles_LeftFoot_is_step  ...  \
# 0                            True                      True  ...
# 1                           False                     False  ...
# 2                           False                     False  ...
# 3                           False                     False  ...
# 4                           False                     False  ...
# ...                           ...                       ...  ...
# 846710                      False                     False  ...
# 846711                      False                     False  ...
# 846712                      False                     False  ...
# 846713                      False                     False  ...
# 846714                      False                     False  ...
#
#         insoles_LeftFoot_time_to_step  insoles_LeftFoot_time_to_lift  \
# 0                                 0.0                          217.0
# 1                               667.0                          200.0
# 2                               650.0                          183.0
# 3                               634.0                          167.0
# 4                               617.0                          150.0
# ...                               ...                            ...
# 846710                          600.0                          134.0
# 846711                          583.0                          117.0
# 846712                          566.0                          100.0
# 846713                          550.0                           84.0
# 846714                          533.0                           67.0
#
#         insoles_RightFoot_time_to_step  insoles_RightFoot_time_to_lift  \
# 0                                  0.0                           767.0
# 1                               1217.0                           750.0
# 2                               1200.0                           733.0
# 3                               1184.0                           717.0
# 4                               1167.0                           700.0
# ...                                ...                             ...
# 846710                            84.0                           750.0
# 846711                            67.0                           733.0
# 846712                            50.0                           716.0
# 846713                            34.0                           700.0
# 846714                            17.0                           683.0
#
#         xsens_footContacts_LeftFoot_Heel  xsens_footContacts_LeftFoot_Toe  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                             True
# 3                                  False                            False
# 4                                  False                            False
# ...                                  ...                              ...
# 846710                             False                            False
# 846711                             False                            False
# 846712                             False                            False
# 846713                             False                             True
# 846714                             False                            False
#
#         xsens_footContacts_RightFoot_Heel  xsens_footContacts_RightFoot_Toe  \
# 0                                    True                             False
# 1                                    True                             False
# 2                                    True                             False
# 3                                    True                             False
# 4                                    True                             False
# ...                                   ...                               ...
# 846710                              False                             False
# 846711                               True                             False
# 846712                               True                             False
# 846713                               True                             False
# 846714                               True                             False
#
#         walk_orientation  walk_interaction
# 0               straight                no
# 1               straight                no
# 2               straight                no
# 3               straight                no
# 4               straight                no
# ...                  ...               ...
# 846710          straight                no
# 846711          straight                no
# 846712          straight                no
# 846713          straight                no
# 846714          straight                no
#
# [846715 rows x 24 columns]

# %%
# Out:
# Processed walk_id08
# Processed walk_id22
# Processed walk_id23
# Processed walk_id07
# Processed walk_id14
# Processed walk_id12
# Processed walk_id24
# Processed walk_id25
# Processed walk_id15
# Processed walk_id01
# Processed walk_id16
# Processed walk_id13
# Processed walk_id05
# Processed walk_id03
# Processed walk_id19
# Processed walk_id17
# Processed walk_id10
# Processed walk_id04
# Processed walk_id02
# Processed walk_id18
# Processed stairs_down_id08
# Processed stairs_down_id22
# Processed stairs_down_id23
# Processed stairs_down_id07
# Processed stairs_down_id14
# Processed stairs_down_id12
# Processed stairs_down_id24
# Processed stairs_down_id25
# Processed stairs_down_id15
# Processed stairs_down_id01
# Processed stairs_down_id16
# Processed stairs_down_id13
# Processed stairs_down_id05
# Processed stairs_down_id03
# Processed stairs_down_id19
# Processed stairs_down_id17
# Processed stairs_down_id10
# Processed stairs_down_id04
# Processed stairs_down_id02
# Processed stairs_down_id18
# Processed stairs_up_id08
# Processed stairs_up_id22
# Processed stairs_up_id23
# Processed stairs_up_id07
# Processed stairs_up_id14
# Processed stairs_up_id12
# Processed stairs_up_id24
# Processed stairs_up_id25
# Processed stairs_up_id15
# Processed stairs_up_id01
# Processed stairs_up_id16
# Processed stairs_up_id13
# Processed stairs_up_id05
# Processed stairs_up_id03
# Processed stairs_up_id19
# Processed stairs_up_id17
# Processed stairs_up_id10
# Processed stairs_up_id04
# Processed stairs_up_id02
# Processed stairs_up_id18
# Processed slope_down_id08
# Processed slope_down_id22
# Processed slope_down_id23
# Processed slope_down_id07
# Processed slope_down_id14
# Processed slope_down_id12
# Processed slope_down_id24
# Processed slope_down_id25
# Processed slope_down_id15
# Processed slope_down_id01
# Processed slope_down_id16
# Processed slope_down_id13
# Processed slope_down_id05
# Processed slope_down_id03
# Processed slope_down_id19
# Processed slope_down_id17
# Processed slope_down_id10
# Processed slope_down_id04
# Processed slope_down_id02
# Processed slope_down_id18
# Processed slope_up_id08
# Processed slope_up_id22
# Processed slope_up_id23
# Processed slope_up_id07
# Processed slope_up_id14
# Processed slope_up_id12
# Processed slope_up_id24
# Processed slope_up_id25
# Processed slope_up_id15
# Processed slope_up_id01
# Processed slope_up_id16
# Processed slope_up_id13
# Processed slope_up_id05
# Processed slope_up_id03
# Processed slope_up_id19
# Processed slope_up_id17
# Processed slope_up_id10
# Processed slope_up_id04
# Processed slope_up_id02
# Processed slope_up_id18

# %%
import pandas as pd

# Define your list of sensor locations
sensor_locations = ['Hallux', 'Toes', 'Met1', 'Met3', 'Met5', 'Arch', 'Heel_R', 'Heel_L']

# Function to extract the sensor location from a column name based on the sensor_locations list
def extract_sensor_location(column_name):
    for location in sensor_locations:
        if location in column_name:
            return location
    return None

# Function to remove the sensor location from a column name
def remove_sensor_location(column_name):
    for location in sensor_locations:
        if location in column_name:
            return column_name.replace(location, '').strip('_')
    return column_name

# Initialize a list to hold DataFrames for all trials
all_trials_df_list = []

# Loop over each DataFrame in subset_dfs (assuming it's a dictionary of trial DataFrames)
for key, trial_df in subset_dfs.items():
    df_list = []
    surface_type = key.split('_')
    if len(surface_type) > 2:
        surface_type = ' '.join(surface_type[:2])
    else:
        surface_type = surface_type[0]

    # For each sensor, collect relevant columns and create a new DataFrame
    for sensor_location in sensor_locations:
        # Find all columns related to this sensor location
        sensor_columns = [col for col in trial_df.columns if sensor_location in col]

        if sensor_columns:
            # Create a new DataFrame for this sensor
            df_by_sensor = pd.DataFrame({
                "time": trial_df["time"],
                "participant_id": trial_df["participant_id"],
                "task": trial_df["task"],
                "surface_type": surface_type,
                "sensor_location": sensor_location
            })

            # For each sensor-related column, add it to the new DataFrame
            for col in sensor_columns:
                new_column_name = remove_sensor_location(col)
                df_by_sensor[new_column_name] = trial_df[col]

            # Append the sensor DataFrame to the list
            df_list.append(df_by_sensor)

    # Concatenate all DataFrames for this trial and add to the main list if any were created
    if df_list:
        trial_df_combined = pd.concat(df_list)
        all_trials_df_list.append(trial_df_combined)

        print(f"Processed {key}")
    else:
        print(f"No valid sensor columns to process for {key}")

# Concatenate all trials into a single DataFrame
all_foot_sensors_df = pd.concat(all_trials_df_list, ignore_index=True)

# Uncomment to export the final combined DataFrame to CSV
# final_combined_df.to_csv('/path/to/final_output.csv', index=False)
# Out:
# Processed walk_id08
# Processed walk_id22
# Processed walk_id23
# Processed walk_id07
# Processed walk_id14
# Processed walk_id12
# Processed walk_id24
# Processed walk_id25
# Processed walk_id15
# Processed walk_id01
# Processed walk_id16
# Processed walk_id13
# Processed walk_id05
# Processed walk_id03
# Processed walk_id19
# Processed walk_id17
# Processed walk_id10
# Processed walk_id04
# Processed walk_id02
# Processed walk_id18
# Processed stairs_down_id08
# Processed stairs_down_id22
# Processed stairs_down_id23
# Processed stairs_down_id07
# Processed stairs_down_id14
# Processed stairs_down_id12
# Processed stairs_down_id24
# Processed stairs_down_id25
# Processed stairs_down_id15
# Processed stairs_down_id01
# Processed stairs_down_id16
# Processed stairs_down_id13
# Processed stairs_down_id05
# Processed stairs_down_id03
# Processed stairs_down_id19
# Processed stairs_down_id17
# Processed stairs_down_id10
# Processed stairs_down_id04
# Processed stairs_down_id02
# Processed stairs_down_id18
# Processed stairs_up_id08
# Processed stairs_up_id22
# Processed stairs_up_id23
# Processed stairs_up_id07
# Processed stairs_up_id14
# Processed stairs_up_id12
# Processed stairs_up_id24
# Processed stairs_up_id25
# Processed stairs_up_id15
# Processed stairs_up_id01
# Processed stairs_up_id16
# Processed stairs_up_id13
# Processed stairs_up_id05
# Processed stairs_up_id03
# Processed stairs_up_id19
# Processed stairs_up_id17
# Processed stairs_up_id10
# Processed stairs_up_id04
# Processed stairs_up_id02
# Processed stairs_up_id18
# Processed slope_down_id08
# Processed slope_down_id22
# Processed slope_down_id23
# Processed slope_down_id07
# Processed slope_down_id14
# Processed slope_down_id12
# Processed slope_down_id24
# Processed slope_down_id25
# Processed slope_down_id15
# Processed slope_down_id01
# Processed slope_down_id16
# Processed slope_down_id13
# Processed slope_down_id05
# Processed slope_down_id03
# Processed slope_down_id19
# Processed slope_down_id17
# Processed slope_down_id10
# Processed slope_down_id04
# Processed slope_down_id02
# Processed slope_down_id18
# Processed slope_up_id08
# Processed slope_up_id22
# Processed slope_up_id23
# Processed slope_up_id07
# Processed slope_up_id14
# Processed slope_up_id12
# Processed slope_up_id24
# Processed slope_up_id25
# Processed slope_up_id15
# Processed slope_up_id01
# Processed slope_up_id16
# Processed slope_up_id13
# Processed slope_up_id05
# Processed slope_up_id03
# Processed slope_up_id19
# Processed slope_up_id17
# Processed slope_up_id10
# Processed slope_up_id04
# Processed slope_up_id02
# Processed slope_up_id18

# %%
foot_sensors_df = all_foot_sensors_df
foot_sensors_extras_df = all_foot_sensor_extras_df

# %%
foot_stepped = foot_sensors_extras_df[(foot_sensors_extras_df['insoles_RightFoot_is_step'] == True) | (foot_sensors_extras_df['insoles_LeftFoot_is_step'] == True)]

# %%
pressure_insole_heelstrikes = foot_stepped['Unnamed: 0']

# %%
# Function to group sequential items
def group_sequential(items):
    grouped = []

    # Check if items is empty
    if not items:
        return grouped  # Return empty list if items is empty

    start = items[0]
    end = items[0]

    for i in range(1, len(items)):
        if items[i] == end + 1:
            end = items[i]
        else:
            grouped.append([start, end])
            start = items[i]
            end = items[i]

    grouped.append([start, end])  # Append the last range
    return grouped

# %%
# foot_sensors_extras_df.head()

# %%
foot_sensors_extras_df['participant_id'].unique()
# Out:
# array([ 8, 22, 23,  7, 14, 12, 24, 25, 15,  1, 16, 13,  5,  3, 19, 17, 10,
#         4,  2, 18])

# %%
heel_strike_insole_segments = []
heel_strike_insole_segments_left = []
heel_strike_xsens_segments = []
heel_strike_xsens_segments_left = []

for p in foot_sensors_extras_df['participant_id'].unique():
    current_ppant_df = foot_sensors_extras_df.loc[foot_sensors_extras_df['participant_id'] == p]

    foot_stepped = current_ppant_df[(current_ppant_df['insoles_RightFoot_is_step'] == True)]
    actual_segments_heel_strike = list(foot_stepped['Unnamed: 0'])
    pairs = np.array([[actual_segments_heel_strike[i], actual_segments_heel_strike[i + 1]] for i in range(len(actual_segments_heel_strike) - 1)])
    heel_strike_insole_segments.append(pairs)

    foot_stepped_left = current_ppant_df[(current_ppant_df['insoles_LeftFoot_is_step'] == True)]
    actual_segments_heel_strike_left = list(foot_stepped_left['Unnamed: 0'])
    pairs_left = np.array([[actual_segments_heel_strike_left[i], actual_segments_heel_strike_left[i + 1]] for i in range(len(actual_segments_heel_strike_left) - 1)])
    heel_strike_insole_segments_left.append(pairs_left)

    xsens_stepped = current_ppant_df[(current_ppant_df['xsens_footContacts_RightFoot_Heel'] == True)]
    xsens_segments_heel_strike = list(xsens_stepped['Unnamed: 0'])
    xsens_grouped_items = np.array(group_sequential(xsens_segments_heel_strike))
    heel_strike_xsens_segments.append(xsens_grouped_items)

    xsens_stepped_left = current_ppant_df[(current_ppant_df['xsens_footContacts_LeftFoot_Heel'] == True)]
    xsens_segments_heel_strike_left = list(xsens_stepped_left['Unnamed: 0'])
    xsens_grouped_items_left = np.array(group_sequential(xsens_segments_heel_strike_left))
    heel_strike_xsens_segments_left.append(xsens_grouped_items_left)

# %%
heel_strike_insole_segments[0]
# Out:
# array([[    0,    74],
#        [   74,   144],
#        [  144,  1110],
#        ...,
#        [41938, 42244],
#        [42244, 42305],
#        [42305, 42372]])

# %%
heel_strike_insole_segments_left[0]
# Out:
# array([[    0,    41],
#        [   41,   109],
#        [  109,   181],
#        ...,
#        [41908, 41970],
#        [41970, 42277],
#        [42277, 42338]])

# %%
all_heel_strike_insole_segments_list = []

for p in range(len(heel_strike_insole_segments)):
    # Combine and sort segments from both sides, then get unique values
    all_heel_strike_insole_segments = np.concatenate((heel_strike_insole_segments[p][:, 0], heel_strike_insole_segments_left[p][:, 0]), axis=0)
    all_heel_strike_insole_segments = np.sort(all_heel_strike_insole_segments)
    all_heel_strike_insole_segments = np.unique(all_heel_strike_insole_segments)

    # # Pair up the steps
    # pairs = np.array([[all_heel_strike_insole_segments[i], all_heel_strike_insole_segments[i + 1]]
    #                   for i in range(len(all_heel_strike_insole_segments) - 1)])
    all_heel_strike_insole_segments_list.append(all_heel_strike_insole_segments)

# %%
foot_sensors_df = foot_sensors_df.sort_values(by=["participant_id", "time", "sensor_location"])

# %%
all_foot_sensors_df
# Out:
#            time  participant_id task surface_type sensor_location   Left  \
# 0             0               8    A         walk          Hallux  179.0
# 1            17               8    A         walk          Hallux  177.0
# 2            34               8    A         walk          Hallux  175.0
# 3            50               8    A         walk          Hallux  179.0
# 4            67               8    A         walk          Hallux  181.0
# ...         ...             ...  ...          ...             ...    ...
# 6773715  758366              18    A     slope up          Heel_L  482.0
# 6773716  758383              18    A     slope up          Heel_L  464.0
# 6773717  758400              18    A     slope up          Heel_L  453.0
# 6773718  758416              18    A     slope up          Heel_L  448.0
# 6773719  758433              18    A     slope up          Heel_L  424.0
#
#          Right   Right__raw    Left__raw  Left__norm  Right__norm
# 0          3.0  4092.199622  3081.392632    0.720356     0.001446
# 1          3.0  4091.532746  2978.724811    0.830405     0.001982
# 2          6.0  4094.932935  2911.396411    0.906569     0.000054
# 3          1.0  4091.599496  2887.599496    0.934059     0.001928
# 4          0.0  4090.733942  2869.201826    0.955711     0.002623
# ...        ...          ...          ...         ...          ...
# 6773715    0.0  4093.506162  4095.000000    0.000000     0.000811
# 6773716    3.0  4094.839305  4095.000000    0.000000     0.000087
# 6773717    0.0  4093.000000  4092.172448    0.001302     0.001086
# 6773718    1.0  4093.505590  4095.000000    0.000000     0.000811
# 6773719    0.0  4094.919367  4095.000000    0.000000     0.000088
#
# [6773720 rows x 11 columns]

# %%
# Step 2: Create the new columns for step index and gait cycles
all_foot_sensors_df['step_index'] = None
all_foot_sensors_df['left_gait_cycle'] = None
all_foot_sensors_df['right_gait_cycle'] = None

# Step 3: Assign a sequential index based on unique participant and time groups
# Sort by 'participant_id' and 'time' to ensure sequential order
all_foot_sensors_df.sort_values(by=['participant_id', 'time'], inplace=True)

# Use `groupby` with `cumcount` to assign a sequential step index for each participant and time combination
all_foot_sensors_df['step_index'] = all_foot_sensors_df.groupby(['participant_id', 'time']).ngroup()

# Step 5: Set the new index as 'participant_id', 'step_index', and 'sensor_location'
all_foot_sensors_df.set_index(['participant_id', 'step_index', 'sensor_location'], inplace=True)

# Step 6: Sort the DataFrame based on the new index
all_foot_sensors_df.sort_index(inplace=True)

print("Step indexing complete and DataFrame sorted.")
# Out:
# Step indexing complete and DataFrame sorted.

# %%
all_foot_sensors_df
# Out:
#                                              time task surface_type   Left  \
# participant_id step_index sensor_location
# 1              0          Arch                  0    A         walk  406.0
#                           Hallux                0    A         walk    3.0
#                           Heel_L                0    A         walk  286.0
#                           Heel_R                0    A         walk  430.0
#                           Met1                  0    A         walk    1.0
# ...                                           ...  ...          ...    ...
# 25             846714     Heel_R           771750    A         walk  422.0
#                           Met1             771750    A         walk  287.0
#                           Met3             771750    A         walk  388.0
#                           Met5             771750    A         walk  415.0
#                           Toes             771750    A         walk    0.0
#
#                                            Right   Right__raw    Left__raw  \
# participant_id step_index sensor_location
# 1              0          Arch             465.0  3839.406648  4093.000000
#                           Hallux             0.0  2782.670582  4094.362659
#                           Heel_L           393.0  4094.362659  3611.384155
#                           Heel_R           437.0  4090.274681  3485.834793
#                           Met1               1.0  3424.637341  4091.318670
# ...                                          ...          ...          ...
# 25             846714     Heel_R             8.0  4081.568781  3108.550972
#                           Met1               6.0  3233.706342  4091.146829
#                           Met3               4.0  2835.586590  4092.926586
#                           Met5               9.0  3694.779757  4094.357805
#                           Toes              14.0  3653.357805  4092.853171
#
#                                            Left__norm  Right__norm  \
# participant_id step_index sensor_location
# 1              0          Arch               0.001299     0.160105
#                           Hallux             0.000223     0.968475
#                           Heel_L             0.457522     0.000275
#                           Heel_R             0.372672     0.002728
#                           Met1               0.001484     0.987995
# ...                                               ...          ...
# 25             846714     Heel_R             0.868584     0.004348
#                           Met1               0.001864     0.699607
#                           Met3               0.000800     0.741234
#                           Met5               0.000682     0.438408
#                           Toes               0.004617     0.922018
#
#                                           left_gait_cycle right_gait_cycle
# participant_id step_index sensor_location
# 1              0          Arch                       None             None
#                           Hallux                     None             None
#                           Heel_L                     None             None
#                           Heel_R                     None             None
#                           Met1                       None             None
# ...                                                   ...              ...
# 25             846714     Heel_R                     None             None
#                           Met1                       None             None
#                           Met3                       None             None
#                           Met5                       None             None
#                           Toes                       None             None
#
# [6773720 rows x 11 columns]

# %%
all_heel_strike_insole_segments_list
# Out:
# [array([    0,    41,    74, ..., 43287, 43323, 43359]),
#  array([    0,    38,    70, ..., 38863, 38893, 38926]),
#  array([    0,    45,    77, ..., 47328, 47358, 47398]),
#  array([    0,    37,    72, ..., 40423, 40455, 40491]),
#  array([    0,     4,    45, ..., 46192, 46227, 46271]),
#  array([    0,    42,    83, ..., 48561, 48594, 48626]),
#  array([    0,     4,    44, ..., 46709, 46736, 46774]),
#  array([    0,    41,    71, ..., 46239, 46274, 46304]),
#  array([    0,    35,    72, ..., 41131, 41162, 41196]),
#  array([    0,    33,    65, ..., 41400, 41438, 41479]),
#  array([    0,    35,    76, ..., 45663, 45695, 45733]),
#  array([    0,    39,    73, ..., 42485, 42518, 42549]),
#  array([    0,    33,    64, ..., 38225, 38255, 38287]),
#  array([    0,     1,    52, ..., 39953, 39987, 40019]),
#  array([    0,    28,    60, ..., 35449, 35476, 35506]),
#  array([    0,    41,    77, ..., 38053, 38085, 38122]),
#  array([    0,    53,    89, ..., 42519, 42554, 42586]),
#  array([    0,    39,    69, ..., 39145, 39177, 39205]),
#  array([    0,    45,    79, ..., 37250, 37279, 37309]),
#  array([    0,    43,    76, ..., 46377, 46408, 46443])]

# %%
ppant_all_foot_sensors_df = []
all_foot_sensors_df = foot_sensors_df

for p in all_foot_sensors_df['participant_id'].unique():
    current_ppant_df = all_foot_sensors_df.loc[all_foot_sensors_df['participant_id'] == p]
    # current_ppant_df = current_ppant_df.loc[current_ppant_df['sensor_location'] == 'Arch']
    # current_ppant_df = current_ppant_df.reset_index(drop=True)
    ppant_all_foot_sensors_df.append(current_ppant_df)

# %%
ppant_all_foot_sensors_df[0]
# Out:
#           time  participant_id task surface_type sensor_location   Left  \
# 0            0               1    A         walk            Arch  406.0
# 1            0               1    A         walk          Hallux    3.0
# 2            0               1    A         walk          Heel_L  286.0
# 3            0               1    A         walk          Heel_R  430.0
# 4            0               1    A         walk            Met1    1.0
# ...        ...             ...  ...          ...             ...    ...
# 331835  691316               1    A         walk          Heel_R    3.0
# 331836  691316               1    A         walk            Met1    1.0
# 331837  691316               1    A         walk            Met3    1.0
# 331838  691316               1    A         walk            Met5    1.0
# 331839  691316               1    A         walk            Toes    1.0
#
#         Right   Right__raw    Left__raw  Left__norm  Right__norm  \
# 0       465.0  3839.406648  4093.000000    0.001299     0.160105
# 1         0.0  2782.670582  4094.362659    0.000223     0.968475
# 2       393.0  4094.362659  3611.384155    0.457522     0.000275
# 3       437.0  4090.274681  3485.834793    0.372672     0.002728
# 4         1.0  3424.637341  4091.318670    0.001484     0.987995
# ...       ...          ...          ...         ...          ...
# 331835    1.0  4093.032885  3643.282511    0.251700     0.000896
# 331836  364.0  3840.098655  4094.868460    0.000055     0.290752
# 331837  654.0  3367.375187  4093.000000    0.000491     0.560072
# 331838  549.0  3295.704036  4093.934230    0.001211     1.000000
# 331839  308.0  3359.934230  4091.098655    0.003574     0.641455
#
#        right_gait_cycles left_gait_cycles all_steps
# 0                      1                1         1
# 1                      1                1         1
# 2                      1                1         1
# 3                      1                1         1
# 4                      1                1         1
# ...                  ...              ...       ...
# 331835              None             None      1411
# 331836              None             None      1411
# 331837              None             None      1411
# 331838              None             None      1411
# 331839              None             None      1411
#
# [331840 rows x 14 columns]

# %%
for i, df in enumerate(ppant_all_foot_sensors_df):
    if not isinstance(df, pd.DataFrame):
        print(f"Error: Element at index {i} in ppant_all_foot_sensors_df is not a DataFrame.")
    else:
        # Reset index to ensure compatibility with start and end positions
        df = df.reset_index(drop=True)

        # Process right gait cycles using heel_strike_insole_segments
        if i < len(heel_strike_insole_segments):
            right_cycles = heel_strike_insole_segments[i]
            df.loc[:, 'right_gait_cycles'] = None  # Initialize the column
            for j, (start, end) in enumerate(right_cycles):
                if start < len(df) and end < len(df):  # Check bounds
                    df.loc[start:end, 'right_gait_cycles'] = j + 1

        # Process left gait cycles using heel_strike_insole_segments_left
        if i < len(heel_strike_insole_segments_left):
            left_cycles = heel_strike_insole_segments_left[i]
            df.loc[:, 'left_gait_cycles'] = None  # Initialize the column
            for j, (start, end) in enumerate(left_cycles):
                if start < len(df) and end < len(df):  # Check bounds
                    df.loc[start:end, 'left_gait_cycles'] = j + 1

        # Process all steps using all_heel_strike_insole_segments_list
        if i < len(all_heel_strike_insole_segments_list):
            all_steps = all_heel_strike_insole_segments_list[i]
            df.loc[:, 'all_steps'] = None  # Initialize the column

            # Loop through each step and fill from the current to the next step
            for j in range(len(all_steps) - 1):
                start, end = all_steps[j], all_steps[j + 1] - 1
                if start < len(df) and end < len(df):  # Check bounds
                    df.loc[start:end, 'all_steps'] = j + 1

            # Fill the last step to the end of the DataFrame
            last_step = all_steps[-1]
            if last_step < len(df):
                df.loc[last_step:, 'all_steps'] = len(all_steps)

        # Save updated DataFrame back to the list
        ppant_all_foot_sensors_df[i] = df

# %%
# ppant_all_foot_sensors_df[2]

# %%
# plot_8_Hallux = all_foot_sensors_df[all_foot_sensors_df['participant_id'] == 8] & all_foot_sensors_df[all_foot_sensors_df['sensor_location'] == 'Hallux']

# %%
# merge all the ppant_all_foot_sensors_df together
all_foot_sensors_df = pd.concat(ppant_all_foot_sensors_df)

# %%
# all_foot_sensors_df

# %%
# export csv to folder
all_foot_sensors_df.to_csv('/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/foot_pressure_data/all_foot_sensors_df.csv', index=False)

# %%
# export csv to folder
all_foot_sensor_extras_df.to_csv('/content/drive/MyDrive/Next_Step/Honda_Participants/CourseA/foot_pressure_data/all_foot_sensor_extras_df.csv', index=False)
