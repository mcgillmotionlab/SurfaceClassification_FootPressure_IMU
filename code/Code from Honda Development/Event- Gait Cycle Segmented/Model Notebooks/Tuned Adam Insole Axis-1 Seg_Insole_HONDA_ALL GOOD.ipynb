# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip3 install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.5.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.60.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
import sys
from glob import glob
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
from scipy import stats
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %% [markdown]
# ## Load in Data

# %%
# import csv
path = "/content/gdrive/MyDrive/Next_Step/Honda: multi_modal_gait_database/merged/interpolated_insole_sensor_df.csv"

interpolated_final_df = pd.read_csv(path)

# %%
interpolated_final_df['participant_id'] = interpolated_final_df['gait_cycle_id'].str.split('_').str[0]
interpolated_final_df['left_gait_cycle'] = interpolated_final_df['gait_cycle_id'].str.split('_').str[1]
interpolated_final_df['task'] = interpolated_final_df['gait_cycle_id'].str.split('_').str[2]

# %%
interpolated_final_df.sort_values(by=['participant_id', 'task', 'time', 'sensor_location'], inplace=True)

# %%
interpolated_final_df['time'] = (interpolated_final_df['time'] * 1000).astype(int)
interpolated_final_df['Left_norm'] = (interpolated_final_df['Left_norm'] * 1000).astype(int)
interpolated_final_df['Right_norm'] = (interpolated_final_df['Right_norm'] * 1000).astype(int)
interpolated_final_df['Left_norm_cumulative'] = (interpolated_final_df['Left_norm_cumulative'] * 1000).astype(int)
interpolated_final_df['Right_norm_cumulative'] = (interpolated_final_df['Right_norm_cumulative'] * 1000).astype(int)

# %%
le = LabelEncoder()
interpolated_final_df['task'] = le.fit_transform(interpolated_final_df['task'])
interpolated_final_df['walk_mode'] = le.fit_transform(interpolated_final_df['walk_mode'])

# %%
interpolated_final_df = interpolated_final_df.drop(columns=['Left_raw', 'Right_raw'])

# %%
# Define columns to be converted to integers, excluding sensor_location and gait_cycle_id
columns_to_convert = ['participant_id', 'task', 'time', 'Left_norm',
                      'Right_norm', 'Left_norm_cumulative',
                      'Right_norm_cumulative', 'walk_mode']

# Convert specified columns to integer
interpolated_final_df[columns_to_convert] = interpolated_final_df[columns_to_convert].astype(int)

# Handle 'left_gait_cycle' separately (convert only the part before the decimal)
interpolated_final_df['left_gait_cycle'] = (
    interpolated_final_df['left_gait_cycle']
    .str.split('.')
    .str[0]
    .astype(int)
)

# %%
interpolated_final_df.head()
# Out:
#          time  Left_norm  Right_norm  Left_norm_cumulative  \
# 8664320     0          1         160                   838
# 8664400     0          0         968                   838
# 8664480     0        457           0                   838
# 8664560     0        372           2                   838
# 8664640     0          1         987                   838
#
#          Right_norm_cumulative sensor_location gait_cycle_id  walk_mode  \
# 8664320                   3509            Arch       1_1.0_A          4
# 8664400                   3509          Hallux       1_1.0_A          4
# 8664480                   3509          Heel_L       1_1.0_A          4
# 8664560                   3509          Heel_R       1_1.0_A          4
# 8664640                   3509            Met1       1_1.0_A          4
#
#          participant_id  left_gait_cycle  task
# 8664320               1                1     0
# 8664400               1                1     0
# 8664480               1                1     0
# 8664560               1                1     0
# 8664640               1                1     0

# %%
import random

number_list = list(interpolated_final_df['participant_id'].unique())
# Choose 3 numbers without replacement
test_three_numbers = random.sample(number_list, 2)
print(test_three_numbers)
train_list = [x for x in number_list if x not in test_three_numbers]

val_three_numbers = random.sample(train_list, 2)
print(val_three_numbers)

train_list = [x for x in train_list if x not in val_three_numbers]
print(train_list)
# Out:
# [4, 3]
# [12, 15]
# [1, 10, 13, 14, 16, 17, 18, 19, 2, 22, 23, 24, 25, 5, 7, 8]

# %%
train = interpolated_final_df.loc[interpolated_final_df['participant_id'].isin(train_list)]
val = interpolated_final_df.loc[interpolated_final_df['participant_id'].isin(val_three_numbers)]
test = interpolated_final_df.loc[interpolated_final_df['participant_id'].isin(test_three_numbers)]

# %%
# retain only the first instance of gait_cycle_id
train_gc = train.drop_duplicates(subset=['gait_cycle_id'], keep='first')

# %%
# count how many unique gait cycle ids are in each walk mode
train_gc[['walk_mode']].value_counts()
# Out:
# walk_mode
# 4            13715
# 0             4580
# 1             3300
# 3             1644
# 2              932
# Name: count, dtype: int64

# %%
# Oversample smaller classes to balance the dataset
min_samples = int(train_gc['walk_mode'].value_counts().min())

# %%
min_samples
# Out:
# 932

# %%
# Downsample to balance classes
balanced_gait_cycles = (
    train_gc.groupby('walk_mode')
    .apply(lambda group: group.sample(n=min_samples, replace=False, random_state=42))
    .reset_index(drop=True)
)
# Out:
# <ipython-input-18-20f7be106a20>:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.sample(n=min_samples, replace=False, random_state=42))

# %%
print(balanced_gait_cycles['walk_mode'].value_counts())
# Out:
# walk_mode
# 0    932
# 1    932
# 2    932
# 3    932
# 4    932
# Name: count, dtype: int64

# %%
filtered_interpolated_final_df = pd.merge(
    train,
    balanced_gait_cycles[['gait_cycle_id']],
    on='gait_cycle_id',
    how='inner'
)

# %%
train = filtered_interpolated_final_df.copy()

# %%
le = LabelEncoder()

train['gait_cycle_id'] = le.fit_transform(train['gait_cycle_id'])
train['sensor_location'] = le.fit_transform(train['sensor_location'])
train['task'] = le.fit_transform(train['task'])
train['walk_mode'] = le.fit_transform(train['walk_mode'])

val['gait_cycle_id'] = le.fit_transform(val['gait_cycle_id'])
val['sensor_location'] = le.fit_transform(val['sensor_location'])
val['task'] = le.fit_transform(val['task'])
val['walk_mode'] = le.fit_transform(val['walk_mode'])

test['gait_cycle_id'] = le.fit_transform(test['gait_cycle_id'])
test['sensor_location'] = le.fit_transform(test['sensor_location'])
test['task'] = le.fit_transform(test['task'])
test['walk_mode'] = le.fit_transform(test['walk_mode'])
# Out:
# <ipython-input-22-b990848ca3d9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['gait_cycle_id'] = le.fit_transform(val['gait_cycle_id'])
# <ipython-input-22-b990848ca3d9>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['sensor_location'] = le.fit_transform(val['sensor_location'])
# <ipython-input-22-b990848ca3d9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['task'] = le.fit_transform(val['task'])
# <ipython-input-22-b990848ca3d9>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['walk_mode'] = le.fit_transform(val['walk_mode'])
# <ipython-input-22-b990848ca3d9>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['gait_cycle_id'] = le.fit_transform(test['gait_cycle_id'])
# <ipython-input-22-b990848ca3d9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sensor_location'] = le.fit_transform(test['sensor_location'])
# <ipython-input-22-b990848ca3d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['task'] = le.fit_transform(test['task'])
# <ipython-input-22-b990848ca3d9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['walk_mode'] = le.fit_transform(test['walk_mode'])

# %%
train['walk_mode'].value_counts()
# Out:
# walk_mode
# 2    596480
# 4    596480
# 3    596480
# 0    596480
# 1    596480
# Name: count, dtype: int64

# %%
print(train.isnull().sum())
# Out:
# time                     0
# Left_norm                0
# Right_norm               0
# Left_norm_cumulative     0
# Right_norm_cumulative    0
# sensor_location          0
# gait_cycle_id            0
# walk_mode                0
# participant_id           0
# left_gait_cycle          0
# task                     0
# dtype: int64

# %%
def preprocess_data(df):
    all_data_x = []
    all_labels_y = []

    for gait_cycle_id, group_data in df.groupby('gait_cycle_id'):
        # Sort by time to ensure consistent order
        group_data = group_data.sort_values(by='time')

        # Prepare a 2D array to hold data for the current gait cycle (80, 18)
        segment_data = []

        # Group by sensor location and extract data in the desired order
        sensor_data_dict = {}
        for sensor_location, sensor_data in group_data.groupby('sensor_location'):
            sensor_array = sensor_data[['Left_norm', 'Right_norm']].values
            sensor_data_dict[sensor_location] = sensor_array

        # Ensure all sensor data has the same time length (80)
        for sensor_location in sorted(sensor_data_dict.keys()):
            sensor_array = sensor_data_dict[sensor_location]
            if len(sensor_array) < 80:
                # Pad with zeros if shorter
                padding = np.zeros((80 - len(sensor_array), 2))
                sensor_array = np.vstack([sensor_array, padding])
            elif len(sensor_array) > 80:
                # Truncate if longer
                sensor_array = sensor_array[:80]

            segment_data.append(sensor_array)

        # Add cumulative data
        cumulative_data = group_data[['Left_norm_cumulative', 'Right_norm_cumulative']].values[:80]
        if len(cumulative_data) < 80:
            padding = np.zeros((80 - len(cumulative_data), 2))
            cumulative_data = np.vstack([cumulative_data, padding])

        segment_data.append(cumulative_data)

        # Combine all sensor data into the final 2D array for the segment (80, 18)
        segment_data = np.hstack(segment_data)
        all_data_x.append(segment_data)

        # Extract labels for the gait cycle
        walk_mode_data = group_data['walk_mode'].values[:80]
        if len(walk_mode_data) < 80:
            walk_mode_data = np.pad(walk_mode_data, (0, 80 - len(walk_mode_data)), constant_values=-1)  # Use -1 for padding

        all_labels_y.append(walk_mode_data)

    # Convert lists to NumPy arrays
    all_data_x = np.array(all_data_x)  # Shape: [x, 80, 18]
    all_labels_y = np.array(all_labels_y)  # Shape: [x, 80]

    return all_data_x, all_labels_y

# %%
train_all_data_x, train_all_labels_y = preprocess_data(train)

# %%
val_all_data_x, val_all_labels_y = preprocess_data(val)

# %%
test_all_data_x, test_all_labels_y = preprocess_data(test)

# %%
train_all_labels_y = np.swapaxes(train_all_labels_y, 0, 1)
train_all_labels_y = train_all_labels_y[0]

val_all_labels_y = np.swapaxes(val_all_labels_y, 0, 1)
val_all_labels_y = val_all_labels_y[0]

test_all_labels_y = np.swapaxes(test_all_labels_y, 0, 1)
test_all_labels_y = test_all_labels_y[0]

# %%
from keras.utils import to_categorical

# Assuming the labels are already numeric
train_all_labels_y = to_categorical(train_all_labels_y)
val_all_labels_y = to_categorical(val_all_labels_y)
test_all_labels_y = to_categorical(test_all_labels_y)

# %%
train_all_labels_y.shape, train_all_labels_y[0]
# Out:
# ((4660, 5), array([0., 0., 1., 0., 0.]))

# %%
train_all_data_x.shape, train_all_labels_y.shape, val_all_data_x.shape, val_all_labels_y.shape, test_all_data_x.shape, test_all_labels_y.shape
# Out:
# ((4660, 80, 18),
#  (4660, 5),
#  (3336, 80, 18),
#  (3336, 5),
#  (2957, 80, 18),
#  (2957, 5))

# %%
train_X = train_all_data_x
train_Y = train_all_labels_y

val_X = val_all_data_x
val_Y = val_all_labels_y

test_X = test_all_data_x
test_Y = test_all_labels_y

# %%
n_obs, n_timesteps, n_features, n_classes = train_X.shape[0], train_X.shape[1], train_X.shape[2], train_Y.shape[1]

# %%
n_obs, n_timesteps, n_features, n_classes
# Out:
# (4660, 80, 18, 5)

# %% [markdown]
# ## hyperparameter tuning

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
# train_X.shape, train_Y.shape
# Out:
# ((4181, 80, 18), (4181, 5))

# %%
# val_X.shape, val_Y.shape
# Out:
# ((2971, 80, 18), (2971, 5))

# %%
# # Clears the session for TensorFlow
# tf.keras.backend.clear_session()

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional, BatchNormalization, MaxPooling1D, Dropout, Flatten
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasClassifier
# from tensorflow.keras.callbacks import EarlyStopping

# # Function to create the Keras model
# def create_model(input_shape=(80, 18), cnn_units=128, learning_rate=0.001, dropout=0.4, lstm_units=64, n_classes=5):

#     # Clears the session for TensorFlow
#     tf.keras.backend.clear_session()

#     inputs = Input(shape=input_shape)

#     # CNN layer
#     cnn_out = BatchNormalization()(inputs)
#     cnn_out = Conv1D(cnn_units, kernel_size=3, activation='relu')(cnn_out)
#     cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
#     cnn_out = Dropout(dropout)(cnn_out)

#     # Bidirectional LSTM layer
#     lstm_out = Bidirectional(LSTM(units=lstm_units, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)

#     # Attention layer
#     attention = Attention()([cnn_out, lstm_out])

#     # Concatenate attention output with LSTM output
#     merged = Concatenate(axis=-1)([lstm_out, attention])

#     # MLP layer after attention and LSTM output
#     mlp_out = Flatten()(merged)
#     mlp_out = Dense(128, activation='relu')(mlp_out)
#     mlp_out = Dense(64, activation='relu')(mlp_out)
#     output_layer = Dense(n_classes, activation='softmax')(mlp_out)

#     # Model compilation
#     model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
#     optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
#     model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#     return model


# # Wrap the model with KerasClassifier
# model = KerasClassifier(model=create_model, input_shape=(80, 18), verbose=2)

# # Define hyperparameter grid using double underscores for parameter names
# param_grid = {
#     'model__cnn_units': [64, 128, 256],  # Number of filters for the CNN layer
#     'model__learning_rate': [0.001, 0.0001, 0.00001],
#     'model__dropout': [0.3, 0.4, 0.5],
#     'model__lstm_units': [32, 64, 128],
#     'model__n_classes': [5]  # Number of classes for classification (fixed as per your data)
# }

# # Create the GridSearchCV object
# grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=None, scoring='accuracy')

# # Define the early stopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Fit the grid search with early stopping
# grid_result = grid.fit(train_X, train_Y, validation_data=(val_X, val_Y), callbacks=[early_stopping])

# # Print the best result
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# 105/105 - 9s - 85ms/step - accuracy: 0.3837 - loss: 1.3546 - val_accuracy: 0.4675 - val_loss: 1.1565
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.4353 - loss: 1.3107 - val_accuracy: 0.5480 - val_loss: 1.0843
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 83ms/step - accuracy: 0.4281 - loss: 1.3017 - val_accuracy: 0.3851 - val_loss: 1.2360
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 89ms/step - accuracy: 0.4227 - loss: 1.2870 - val_accuracy: 0.5042 - val_loss: 1.0827
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.4374 - loss: 1.2779 - val_accuracy: 0.3618 - val_loss: 1.1678
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 88ms/step - accuracy: 0.3251 - loss: 1.4927 - val_accuracy: 0.0720 - val_loss: 1.6564
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.3151 - loss: 1.5109 - val_accuracy: 0.2807 - val_loss: 1.5489
# 27/27 - 1s - 42ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.3558 - loss: 1.4580 - val_accuracy: 0.2861 - val_loss: 1.5090
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.3306 - loss: 1.4739 - val_accuracy: 0.4382 - val_loss: 1.4236
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.3178 - loss: 1.5149 - val_accuracy: 0.1666 - val_loss: 1.7145
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.2234 - loss: 1.6093 - val_accuracy: 0.2232 - val_loss: 1.6090
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.2377 - loss: 1.6037 - val_accuracy: 0.1387 - val_loss: 1.5366
# 27/27 - 1s - 40ms/step
# 105/105 - 10s - 94ms/step - accuracy: 0.2526 - loss: 1.5939 - val_accuracy: 0.3692 - val_loss: 1.5181
# 27/27 - 1s - 45ms/step
# 105/105 - 10s - 93ms/step - accuracy: 0.2341 - loss: 1.5985 - val_accuracy: 0.2292 - val_loss: 1.5527
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 94ms/step - accuracy: 0.2269 - loss: 1.6012 - val_accuracy: 0.5395 - val_loss: 1.4925
# 27/27 - 1s - 43ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.3956 - loss: 1.3390 - val_accuracy: 0.3012 - val_loss: 1.3138
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 82ms/step - accuracy: 0.4087 - loss: 1.3267 - val_accuracy: 0.6176 - val_loss: 0.9832
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.4173 - loss: 1.3123 - val_accuracy: 0.3403 - val_loss: 1.5328
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.4009 - loss: 1.3583 - val_accuracy: 0.5749 - val_loss: 1.0042
# 27/27 - 1s - 42ms/step
# 105/105 - 9s - 89ms/step - accuracy: 0.4386 - loss: 1.2885 - val_accuracy: 0.4241 - val_loss: 1.1236
# 27/27 - 1s - 39ms/step
# 105/105 - 10s - 92ms/step - accuracy: 0.3203 - loss: 1.4911 - val_accuracy: 0.5274 - val_loss: 1.2814
# 27/27 - 1s - 42ms/step
# 105/105 - 9s - 85ms/step - accuracy: 0.3241 - loss: 1.4931 - val_accuracy: 0.3790 - val_loss: 1.3705
# 27/27 - 1s - 39ms/step
# 105/105 - 10s - 91ms/step - accuracy: 0.3339 - loss: 1.4753 - val_accuracy: 0.1706 - val_loss: 1.6409
# 27/27 - 1s - 46ms/step
# 105/105 - 9s - 90ms/step - accuracy: 0.3280 - loss: 1.5172 - val_accuracy: 0.2221 - val_loss: 1.4205
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.3190 - loss: 1.5104 - val_accuracy: 0.2181 - val_loss: 1.5917
# 27/27 - 1s - 41ms/step
# 105/105 - 10s - 98ms/step - accuracy: 0.2515 - loss: 1.5951 - val_accuracy: 0.0700 - val_loss: 1.6467
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 92ms/step - accuracy: 0.2365 - loss: 1.5957 - val_accuracy: 0.1255 - val_loss: 1.5941
# 27/27 - 1s - 41ms/step
# 105/105 - 10s - 94ms/step - accuracy: 0.2652 - loss: 1.5841 - val_accuracy: 0.1427 - val_loss: 1.6139
# 27/27 - 1s - 42ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.2380 - loss: 1.6013 - val_accuracy: 0.4655 - val_loss: 1.5152
# 27/27 - 1s - 41ms/step
# 105/105 - 9s - 90ms/step - accuracy: 0.2493 - loss: 1.5976 - val_accuracy: 0.1410 - val_loss: 1.6242
# 27/27 - 1s - 43ms/step
# 105/105 - 9s - 88ms/step - accuracy: 0.3956 - loss: 1.3563 - val_accuracy: 0.5187 - val_loss: 1.1680
# 27/27 - 1s - 42ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.4042 - loss: 1.3267 - val_accuracy: 0.4177 - val_loss: 1.1642
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.4230 - loss: 1.3128 - val_accuracy: 0.2844 - val_loss: 1.3991
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 85ms/step - accuracy: 0.4021 - loss: 1.3776 - val_accuracy: 0.3750 - val_loss: 1.1823
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 85ms/step - accuracy: 0.4114 - loss: 1.3109 - val_accuracy: 0.3231 - val_loss: 1.2590
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 86ms/step - accuracy: 0.3119 - loss: 1.4783 - val_accuracy: 0.2107 - val_loss: 1.5209
# 27/27 - 1s - 38ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.3312 - loss: 1.4951 - val_accuracy: 0.2110 - val_loss: 1.4634
# 27/27 - 1s - 38ms/step
# 105/105 - 9s - 88ms/step - accuracy: 0.3444 - loss: 1.4850 - val_accuracy: 0.2184 - val_loss: 1.5108
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.3366 - loss: 1.4988 - val_accuracy: 0.2174 - val_loss: 1.4662
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 88ms/step - accuracy: 0.3229 - loss: 1.4855 - val_accuracy: 0.2531 - val_loss: 1.6086
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 89ms/step - accuracy: 0.2156 - loss: 1.6002 - val_accuracy: 0.0922 - val_loss: 1.5758
# 27/27 - 1s - 40ms/step
# 105/105 - 9s - 89ms/step - accuracy: 0.2445 - loss: 1.6012 - val_accuracy: 0.0875 - val_loss: 1.6008
# 27/27 - 1s - 41ms/step
# 105/105 - 9s - 83ms/step - accuracy: 0.2075 - loss: 1.6375 - val_accuracy: 0.1915 - val_loss: 1.6129
# 27/27 - 1s - 39ms/step
# 105/105 - 9s - 87ms/step - accuracy: 0.2386 - loss: 1.5965 - val_accuracy: 0.5877 - val_loss: 1.4641
# 27/27 - 1s - 41ms/step
# 105/105 - 9s - 84ms/step - accuracy: 0.2589 - loss: 1.5903 - val_accuracy: 0.5382 - val_loss: 1.4582
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.4417 - loss: 1.2811 - val_accuracy: 0.3713 - val_loss: 1.1600
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.4592 - loss: 1.2664 - val_accuracy: 0.5449 - val_loss: 1.0750
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.4870 - loss: 1.1894 - val_accuracy: 0.3743 - val_loss: 1.2430
# 27/27 - 1s - 45ms/step
# 105/105 - 11s - 101ms/step - accuracy: 0.4454 - loss: 1.2801 - val_accuracy: 0.4672 - val_loss: 1.1066
# 27/27 - 1s - 45ms/step
# 105/105 - 11s - 100ms/step - accuracy: 0.4729 - loss: 1.2390 - val_accuracy: 0.5419 - val_loss: 1.0238
# 27/27 - 1s - 46ms/step
# 105/105 - 10s - 99ms/step - accuracy: 0.3562 - loss: 1.4135 - val_accuracy: 0.5369 - val_loss: 1.3238
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 98ms/step - accuracy: 0.3830 - loss: 1.4039 - val_accuracy: 0.1841 - val_loss: 1.4537
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 99ms/step - accuracy: 0.3862 - loss: 1.3954 - val_accuracy: 0.4194 - val_loss: 1.2555
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 99ms/step - accuracy: 0.3833 - loss: 1.3869 - val_accuracy: 0.2417 - val_loss: 1.4188
# 27/27 - 1s - 46ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.3689 - loss: 1.3952 - val_accuracy: 0.5231 - val_loss: 1.1693
# 27/27 - 1s - 43ms/step
# 105/105 - 11s - 104ms/step - accuracy: 0.2611 - loss: 1.5683 - val_accuracy: 0.0815 - val_loss: 1.5921
# 27/27 - 1s - 50ms/step
# 105/105 - 11s - 103ms/step - accuracy: 0.2607 - loss: 1.5797 - val_accuracy: 0.0569 - val_loss: 1.6431
# 27/27 - 1s - 45ms/step
# 105/105 - 11s - 101ms/step - accuracy: 0.2759 - loss: 1.5753 - val_accuracy: 0.0629 - val_loss: 1.5909
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 92ms/step - accuracy: 0.2526 - loss: 1.5936 - val_accuracy: 0.4541 - val_loss: 1.4868
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 99ms/step - accuracy: 0.2843 - loss: 1.5690 - val_accuracy: 0.0592 - val_loss: 1.6302
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 99ms/step - accuracy: 0.4432 - loss: 1.2746 - val_accuracy: 0.3544 - val_loss: 1.2547
# 27/27 - 1s - 48ms/step
# 105/105 - 11s - 102ms/step - accuracy: 0.4499 - loss: 1.2705 - val_accuracy: 0.4487 - val_loss: 1.0875
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.4652 - loss: 1.2641 - val_accuracy: 0.5298 - val_loss: 1.0313
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 97ms/step - accuracy: 0.4233 - loss: 1.2968 - val_accuracy: 0.3676 - val_loss: 1.2303
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 98ms/step - accuracy: 0.4541 - loss: 1.2458 - val_accuracy: 0.3554 - val_loss: 1.3054
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 100ms/step - accuracy: 0.3439 - loss: 1.4292 - val_accuracy: 0.2491 - val_loss: 1.3045
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 100ms/step - accuracy: 0.3629 - loss: 1.4034 - val_accuracy: 0.4315 - val_loss: 1.1922
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.3839 - loss: 1.3859 - val_accuracy: 0.1929 - val_loss: 1.8420
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.3629 - loss: 1.4448 - val_accuracy: 0.2497 - val_loss: 1.4769
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 97ms/step - accuracy: 0.3782 - loss: 1.4169 - val_accuracy: 0.2444 - val_loss: 1.3284
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.2691 - loss: 1.5818 - val_accuracy: 0.1252 - val_loss: 1.6108
# 27/27 - 1s - 44ms/step
# 105/105 - 11s - 101ms/step - accuracy: 0.2529 - loss: 1.5861 - val_accuracy: 0.1848 - val_loss: 1.5470
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 100ms/step - accuracy: 0.2619 - loss: 1.5849 - val_accuracy: 0.2221 - val_loss: 1.6613
# 27/27 - 1s - 47ms/step
# 105/105 - 11s - 104ms/step - accuracy: 0.2673 - loss: 1.5832 - val_accuracy: 0.2063 - val_loss: 1.5566
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 100ms/step - accuracy: 0.2753 - loss: 1.5774 - val_accuracy: 0.2141 - val_loss: 1.5938
# 27/27 - 1s - 47ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.4196 - loss: 1.2986 - val_accuracy: 0.2800 - val_loss: 1.6144
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.4460 - loss: 1.2701 - val_accuracy: 0.5291 - val_loss: 0.9893
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 98ms/step - accuracy: 0.4568 - loss: 1.2603 - val_accuracy: 0.3278 - val_loss: 1.2913
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.4422 - loss: 1.2867 - val_accuracy: 0.4133 - val_loss: 1.2982
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.4538 - loss: 1.2586 - val_accuracy: 0.3406 - val_loss: 1.4395
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.3496 - loss: 1.4416 - val_accuracy: 0.5651 - val_loss: 1.2359
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.3791 - loss: 1.4365 - val_accuracy: 0.2279 - val_loss: 1.4546
# 27/27 - 1s - 45ms/step
# 105/105 - 10s - 96ms/step - accuracy: 0.3492 - loss: 1.4452 - val_accuracy: 0.1834 - val_loss: 1.6126
# 27/27 - 1s - 45ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.3701 - loss: 1.4086 - val_accuracy: 0.2440 - val_loss: 1.4763
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 97ms/step - accuracy: 0.3546 - loss: 1.4405 - val_accuracy: 0.5332 - val_loss: 1.2853
# 27/27 - 1s - 44ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.2413 - loss: 1.5909 - val_accuracy: 0.1121 - val_loss: 1.5639
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 95ms/step - accuracy: 0.2712 - loss: 1.5813 - val_accuracy: 0.1525 - val_loss: 1.6105
# 27/27 - 1s - 46ms/step
# 105/105 - 10s - 100ms/step - accuracy: 0.2744 - loss: 1.5732 - val_accuracy: 0.0572 - val_loss: 1.6449
# 27/27 - 1s - 42ms/step
# 105/105 - 10s - 94ms/step - accuracy: 0.2445 - loss: 1.5870 - val_accuracy: 0.0710 - val_loss: 1.5959
# 27/27 - 1s - 43ms/step
# 105/105 - 10s - 94ms/step - accuracy: 0.2529 - loss: 1.5940 - val_accuracy: 0.1659 - val_loss: 1.5739
# 27/27 - 1s - 43ms/step
# 105/105 - 15s - 140ms/step - accuracy: 0.4321 - loss: 1.3002 - val_accuracy: 0.6590 - val_loss: 0.9653
# 27/27 - 1s - 51ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.4960 - loss: 1.2118 - val_accuracy: 0.4598 - val_loss: 1.1219
# 27/27 - 1s - 55ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.4903 - loss: 1.2500 - val_accuracy: 0.4113 - val_loss: 1.0994
# 27/27 - 2s - 58ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.4655 - loss: 1.2878 - val_accuracy: 0.5870 - val_loss: 0.9940
# 27/27 - 2s - 56ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.4747 - loss: 1.2405 - val_accuracy: 0.3241 - val_loss: 1.1736
# 27/27 - 1s - 53ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.4115 - loss: 1.3254 - val_accuracy: 0.3046 - val_loss: 1.3098
# 27/27 - 1s - 54ms/step
# 105/105 - 15s - 140ms/step - accuracy: 0.4120 - loss: 1.3304 - val_accuracy: 0.6654 - val_loss: 1.0371
# 27/27 - 1s - 51ms/step
# 105/105 - 15s - 138ms/step - accuracy: 0.4395 - loss: 1.2897 - val_accuracy: 0.2097 - val_loss: 1.4357
# 27/27 - 1s - 53ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.4278 - loss: 1.3174 - val_accuracy: 0.2467 - val_loss: 1.3705
# 27/27 - 2s - 57ms/step
# 105/105 - 15s - 144ms/step - accuracy: 0.4167 - loss: 1.3172 - val_accuracy: 0.3615 - val_loss: 1.3517
# 27/27 - 1s - 51ms/step
# 105/105 - 15s - 142ms/step - accuracy: 0.3146 - loss: 1.5522 - val_accuracy: 0.0569 - val_loss: 1.6693
# 27/27 - 1s - 53ms/step
# 105/105 - 15s - 143ms/step - accuracy: 0.2993 - loss: 1.5587 - val_accuracy: 0.1764 - val_loss: 1.6059
# 27/27 - 2s - 57ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.3007 - loss: 1.5346 - val_accuracy: 0.2006 - val_loss: 1.5743
# 27/27 - 2s - 56ms/step
# 105/105 - 15s - 143ms/step - accuracy: 0.2978 - loss: 1.5470 - val_accuracy: 0.1097 - val_loss: 1.6089
# 27/27 - 1s - 52ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.3268 - loss: 1.5383 - val_accuracy: 0.0838 - val_loss: 1.7433
# 27/27 - 1s - 55ms/step
# 105/105 - 14s - 136ms/step - accuracy: 0.4510 - loss: 1.2439 - val_accuracy: 0.3952 - val_loss: 1.1902
# 27/27 - 1s - 54ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.4720 - loss: 1.2529 - val_accuracy: 0.3447 - val_loss: 1.1515
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 136ms/step - accuracy: 0.4807 - loss: 1.2041 - val_accuracy: 0.3295 - val_loss: 1.2634
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 135ms/step - accuracy: 0.4559 - loss: 1.2367 - val_accuracy: 0.6479 - val_loss: 0.9851
# 27/27 - 1s - 55ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.4924 - loss: 1.2105 - val_accuracy: 0.3201 - val_loss: 1.3489
# 27/27 - 1s - 50ms/step
# 105/105 - 15s - 140ms/step - accuracy: 0.3840 - loss: 1.3753 - val_accuracy: 0.6200 - val_loss: 1.0948
# 27/27 - 1s - 54ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.4317 - loss: 1.3237 - val_accuracy: 0.4867 - val_loss: 1.1716
# 27/27 - 1s - 54ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.3955 - loss: 1.3730 - val_accuracy: 0.3336 - val_loss: 1.3565
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.4039 - loss: 1.3409 - val_accuracy: 0.4012 - val_loss: 1.2168
# 27/27 - 1s - 53ms/step
# 105/105 - 14s - 136ms/step - accuracy: 0.4332 - loss: 1.3178 - val_accuracy: 0.3440 - val_loss: 1.2139
# 27/27 - 1s - 54ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.2931 - loss: 1.5627 - val_accuracy: 0.0576 - val_loss: 1.6292
# 27/27 - 1s - 53ms/step
# 105/105 - 14s - 136ms/step - accuracy: 0.3058 - loss: 1.5488 - val_accuracy: 0.0703 - val_loss: 1.7105
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.2864 - loss: 1.5629 - val_accuracy: 0.0569 - val_loss: 1.6700
# 27/27 - 1s - 54ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.3049 - loss: 1.5326 - val_accuracy: 0.1266 - val_loss: 1.5767
# 27/27 - 1s - 55ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.2846 - loss: 1.5582 - val_accuracy: 0.0653 - val_loss: 1.7093
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.4656 - loss: 1.2511 - val_accuracy: 0.3440 - val_loss: 1.2506
# 27/27 - 1s - 51ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.4795 - loss: 1.2257 - val_accuracy: 0.6186 - val_loss: 0.9172
# 27/27 - 1s - 52ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.4888 - loss: 1.2116 - val_accuracy: 0.4931 - val_loss: 1.0894
# 27/27 - 2s - 57ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.4577 - loss: 1.2801 - val_accuracy: 0.3463 - val_loss: 1.2405
# 27/27 - 1s - 51ms/step
# 105/105 - 15s - 141ms/step - accuracy: 0.4580 - loss: 1.2501 - val_accuracy: 0.4544 - val_loss: 1.3284
# 27/27 - 1s - 53ms/step
# 105/105 - 14s - 135ms/step - accuracy: 0.3771 - loss: 1.3740 - val_accuracy: 0.4426 - val_loss: 1.3310
# 27/27 - 1s - 52ms/step
# 105/105 - 15s - 142ms/step - accuracy: 0.4081 - loss: 1.3419 - val_accuracy: 0.4305 - val_loss: 1.2067
# 27/27 - 2s - 58ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.4233 - loss: 1.3187 - val_accuracy: 0.3682 - val_loss: 1.3406
# 27/27 - 1s - 55ms/step
# 105/105 - 14s - 137ms/step - accuracy: 0.4003 - loss: 1.3681 - val_accuracy: 0.3187 - val_loss: 1.2477
# 27/27 - 1s - 53ms/step
# 105/105 - 15s - 142ms/step - accuracy: 0.4230 - loss: 1.3314 - val_accuracy: 0.4588 - val_loss: 1.2115
# 27/27 - 1s - 53ms/step
# 105/105 - 15s - 138ms/step - accuracy: 0.2608 - loss: 1.5638 - val_accuracy: 0.0569 - val_loss: 1.6582
# 27/27 - 1s - 51ms/step
# 105/105 - 15s - 139ms/step - accuracy: 0.2837 - loss: 1.5612 - val_accuracy: 0.0606 - val_loss: 1.6555
# 27/27 - 1s - 53ms/step
# 105/105 - 14s - 134ms/step - accuracy: 0.2762 - loss: 1.5603 - val_accuracy: 0.0569 - val_loss: 1.7428
# 27/27 - 2s - 56ms/step
# 105/105 - 14s - 138ms/step - accuracy: 0.2894 - loss: 1.5639 - val_accuracy: 0.1454 - val_loss: 1.5452
# 27/27 - 1s - 52ms/step
# 105/105 - 15s - 140ms/step - accuracy: 0.2930 - loss: 1.5674 - val_accuracy: 0.2131 - val_loss: 1.5874
# 27/27 - 1s - 55ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 270 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 64 and 128 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,64], [?,128,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 64), dtype=float32)', 'tf.Tensor(shape=(None, 39, 128), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 64 and 256 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,64], [?,256,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 64), dtype=float32)', 'tf.Tensor(shape=(None, 39, 256), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 128 and 64 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,128], [?,64,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 128), dtype=float32)', 'tf.Tensor(shape=(None, 39, 64), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 128 and 256 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,128], [?,256,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 128), dtype=float32)', 'tf.Tensor(shape=(None, 39, 256), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 256 and 64 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,256], [?,64,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 256), dtype=float32)', 'tf.Tensor(shape=(None, 39, 64), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
# ValueError: Exception encountered when calling Attention.call().
#
# Dimensions must be equal, but are 256 and 128 for '{{node functional_1/attention_1/MatMul}} = BatchMatMulV2[T=DT_FLOAT, adj_x=false, adj_y=false, grad_x=false, grad_y=false](functional_1/dropout_1/stateless_dropout/SelectV2, functional_1/attention_1/transpose)' with input shapes: [?,39,256], [?,128,39].
#
# Arguments received by Attention.call():
#   • inputs=['tf.Tensor(shape=(None, 39, 256), dtype=float32)', 'tf.Tensor(shape=(None, 39, 128), dtype=float32)']
#   • mask=['None', 'None']
#   • training=True
#   • return_attention_scores=False
#   • use_causal_mask=False
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.46851795        nan        nan 0.35543179        nan        nan
#  0.3099601         nan        nan 0.47139876        nan        nan
#  0.33339822        nan        nan 0.2590306         nan        nan
#  0.48458238        nan        nan 0.35467693        nan        nan
#  0.2444273         nan        nan        nan 0.49557088        nan
#         nan 0.39581954        nan        nan 0.27335437        nan
#         nan 0.5204404         nan        nan 0.39247426        nan
#         nan 0.27313886        nan        nan 0.45994924        nan
#         nan 0.35183013        nan        nan 0.26500946        nan
#         nan        nan 0.4941389         nan        nan 0.44151046
#         nan        nan 0.27577844        nan        nan 0.49078504
#         nan        nan 0.46947546        nan        nan 0.28127712
#         nan        nan 0.47856179        nan        nan 0.46114655
#         nan        nan 0.28940909]
#   warnings.warn(
# 131/131 - 11s - 84ms/step - accuracy: 0.4731 - loss: 1.2322 - val_accuracy: 0.6432 - val_loss: 0.9234
# Best: 0.520440 using {'model__cnn_units': 128, 'model__dropout': 0.4, 'model__learning_rate': 0.001, 'model__lstm_units': 64, 'model__n_classes': 5}

# %% [markdown]
# ## Train Model

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Layer, Attention, Concatenate, Dense, Bidirectional, BatchNormalization, MaxPooling1D, Dropout, Flatten
from sklearn.model_selection import train_test_split

# Clears the session for TensorFlow
tf.keras.backend.clear_session()

# Define input shape and number of inputs
input_shape = (n_timesteps, n_features)
number_of_inputs = n_obs
number_of_sensors = len(train_X)
inputs = []

attention_weights_list = []  # To store attention weights for each branch
count = 0


input_layer = Input(shape=input_shape)
inputs.append(input_layer)

# CNN layer
cnn_out = BatchNormalization()(input_layer)
cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
cnn_out = Dropout(0.45)(cnn_out)

# Bidirectional LSTM layer
lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)

# Attention layer
attention = Attention()([cnn_out, lstm_out])
# Concatenate attention output with LSTM output
merged = Concatenate(axis=-1)([lstm_out, attention])
# Dense layer for individual branch output
merged_output = Dense(units=n_classes, activation='softmax')(merged)

# MLP layer
mlp_out = Flatten()(merged_output)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)

# Model outputs both classification and attention weights
model = tf.keras.models.Model(inputs=inputs, outputs=[output_layer])

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 80, 18)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 80, 18)         │             72 │ input_layer[0][0]      │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 78, 128)        │          7,040 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d             │ (None, 39, 128)        │              0 │ conv1d[0][0]           │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 39, 128)        │              0 │ max_pooling1d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional             │ (None, 39, 128)        │         98,816 │ dropout[0][0]          │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention (Attention)     │ (None, 39, 128)        │              0 │ dropout[0][0],         │
# │                           │                        │                │ bidirectional[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 39, 256)        │              0 │ bidirectional[0][0],   │
# │                           │                        │                │ attention[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 39, 5)          │          1,285 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 195)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 128)            │         25,088 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 64)             │          8,256 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 5)              │            325 │ dense_2[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 140,882 (550.32 KB)
#  Trainable params: 140,846 (550.18 KB)
#  Non-trainable params: 36 (144.00 B)

# %%
# Assuming each entry in train_X_split_trimmed corresponds to one sensor's data
# Make sure that train_X_split_trimmed has exactly 6 entries for the 6 sensors
history = model.fit(train_X, train_Y, epochs=200, batch_size=128, callbacks=[callback], validation_data=(val_X, val_Y))
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.3012 - loss: 1.5278 - val_accuracy: 0.5677 - val_loss: 1.0911
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.6013 - loss: 0.9937 - val_accuracy: 0.6226 - val_loss: 0.9007
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.6825 - loss: 0.8418 - val_accuracy: 0.6232 - val_loss: 0.9212
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.7053 - loss: 0.7570 - val_accuracy: 0.6517 - val_loss: 0.8786
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.7416 - loss: 0.6976 - val_accuracy: 0.6178 - val_loss: 1.0050
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.7541 - loss: 0.6673 - val_accuracy: 0.6643 - val_loss: 0.9089
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.7702 - loss: 0.6487 - val_accuracy: 0.6865 - val_loss: 0.8800
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.7776 - loss: 0.6099 - val_accuracy: 0.5486 - val_loss: 1.2901
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.7919 - loss: 0.5771 - val_accuracy: 0.5872 - val_loss: 1.1835

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_X, test_Y)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5107 - loss: 1.2666

# %%
# Check shapes of test data before evaluation
print("Test X shape:", test_X[0].shape)
print("Test Y shape:", test_Y[0].shape)
# Out:
# Test X shape: (80, 18)
# Test Y shape: (5,)

# %%
#predictions
predictions = model.predict(test_X)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step

# %%
# Convert predictions to class labels
predicted_classes = tf.argmax(predictions, axis=-1)

# Convert true labels to class labels (if needed)
true_classes = tf.argmax(test_Y, axis=-1)

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted_classes, true_classes), tf.float32))
print(f"Test accuracy: {accuracy.numpy() * 100:.2f}%")

# Display predicted and true classes for further inspection
print("Predicted classes:", predicted_classes.numpy())
print("True classes:", true_classes.numpy())
# Out:
# Test accuracy: 54.38%
# Predicted classes: [2 0 1 ... 0 0 1]
# True classes: [2 0 4 ... 0 0 4]

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import recall_score

# Convert predictions and true labels to NumPy arrays
# The variables are already numpy arrays, so no conversion is needed.
predicted_classes_np = predicted_classes
true_classes_np = true_classes

# Generate a classification report (includes precision, recall, F1-score for each class)
report = classification_report(true_classes_np, predicted_classes_np, digits=4)
print("Classification Report:\n", report)

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes_np, predicted_classes_np)
print("Confusion Matrix:\n", conf_matrix)
print(" ")
# Calculate F1-score and sensitivity (recall) per class
f1_scores = recall_score(true_classes_np, predicted_classes_np, average=None)
f1_scores = [round(item, 3) for item in f1_scores]
print(f"F1-Scores (per class): {f1_scores}")

# Custom calculation for specificity per class
specificities = []

for i in range(conf_matrix.shape[0]):
    tn = conf_matrix.sum() - (conf_matrix[i, :].sum() + conf_matrix[:, i].sum() - conf_matrix[i, i])
    fp = conf_matrix[:, i].sum() - conf_matrix[i, i]
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    # round to 3 decimal points
    specificity = round(specificity, 3)
    specificities.append(specificity)

    sensitivity = recall_score(true_classes_np, predicted_classes_np, average=None)
    # round the sensitivity items to 3 decimal points
    sensitivity = [round(item, 3) for item in sensitivity]

print(f"Sensitivity (per class): {sensitivity}")
print(f"Specificities (per class): {specificities}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.6810    0.7245    0.7020       548
#            1     0.3360    0.7412    0.4624       398
#            2     0.0889    0.6102    0.1552        59
#            3     0.8462    0.1630    0.2733       270
#            4     0.8046    0.4970    0.6145      1682
#
#     accuracy                         0.5438      2957
#    macro avg     0.5513    0.5472    0.4415      2957
# weighted avg     0.7081    0.5438    0.5699      2957
#
# Confusion Matrix:
#  [[397   3  70   0  78]
#  [  1 295   2   0 100]
#  [  8   3  36   0  12]
#  [  1  16 196  44  13]
#  [176 561 101   8 836]]
#
# F1-Scores (per class): [0.724, 0.741, 0.61, 0.163, 0.497]
# Sensitivity (per class): [0.724, 0.741, 0.61, 0.163, 0.497]
# Specificities (per class): [0.923, 0.772, 0.873, 0.997, 0.841]

# %% [markdown]
# ## Confusion Matrix

# %%
# Compute the confusion matrix
result = confusion_matrix(true_classes, predicted_classes)

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['slope down', 'slope up', 'stairs down', 'stairs up', 'walk'])

cm_display.plot()
plt.show()

# %%
# Create the confusion matrix display using the from_predictions method
cm_display = ConfusionMatrixDisplay.from_predictions(
    true_classes,
    predicted_classes,
    display_labels=['slope down', 'slope up', 'stairs down', 'stairs up', 'walk'],
    normalize='true'  # Normalize by the true labels
)

plt.title("Normalized Confusion Matrix")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
