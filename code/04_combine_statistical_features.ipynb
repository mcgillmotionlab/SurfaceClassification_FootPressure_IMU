# %%
import os
import pandas as pd

# %%
base_dir = 'data_set'

# Initialize an empty list to hold DataFrames
dfs = []

# Walk through all folders and subfolders in the base directory
for root, dirs, files in os.walk(base_dir):
    # Check if 'statistical_features.csv' is in the current folder
    # if 'statistical_features_all.csv' in files:
    # if 'statistical_features.csv' in files:
    # if 'statistical_features_imu.csv' in files:
    # if 'statistical_features_imu_all_locations.csv' in files:
    # if 'statistical_features_imu_luo.csv' in files:
    # if 'statistical_features_imu_right_forearm.csv' in files:
    # if 'statistical_features_imu_pelvis.csv' in files:
    # if 'statistical_features_imu_pelvis_right_forearm.csv' in files:
    # if 'statistical_features_imu_pelvis_right_forearm_insoles.csv' in files:
    # if 'statistical_features_insoles_imu.csv' in files:
    # if 'statistical_features_insoles_pressure.csv' in files:
    # if 'statistical_features_insoles_pressure_imu.csv' in files:
    # if 'statistical_features_xsens_luo.csv' in files:
    # if 'statistical_features_xsens_all_insoles_all.csv' in files:
    # if 'statistical_features_xsens_best_insoles_best.csv' in files:
    # if 'statistical_features_imu_left_forearm.csv' in files:
    # if 'magnitude_statistical_features_imu_luo_all_data_sources.csv' in files:
    # if 'magnitude_statistical_features_imu_luo_only_acceleration.csv' in files:
    # if 'statistical_features_xsens_best_insoles_best_no_magnetometer.csv' in files:
    # if 'statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer.csv' in files:
    # if 'statistical_features_xsens_best_insoles_best_no_magnetometer(merged_gait_count_shank).csv' in files:
    # if 'statistical_features_xsens_best_insoles_best_no_magnetometer(sliding window of 2 seconds with a step of 1 second).csv' in files:
    if 'statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv' in files:
        # csv_file_path = os.path.join(root, 'statistical_features_all.csv')
        # csv_file_path = os.path.join(root, 'statistical_features.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_all_locations.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_luo.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_right_forearm.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_pelvis.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_pelvis_right_forearm.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_pelvis_right_forearm_insoles.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_insoles_imu.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_insoles_pressure.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_insoles_pressure_imu.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_luo.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_all_insoles_all.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_best_insoles_best.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_imu_left_forearm.csv')
        # csv_file_path = os.path.join(root, 'magnitude_statistical_features_imu_luo_all_data_sources.csv')
        # csv_file_path = os.path.join(root, 'magnitude_statistical_features_imu_luo_only_acceleration.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_best_insoles_best_no_magnetometer.csv')
        # csv_file_path = os.path.join(root, 'statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer.csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_best_insoles_best_no_magnetometer(merged_gait_count_shank).csv')
        # csv_file_path = os.path.join(root, 'statistical_features_xsens_best_insoles_best_no_magnetometer(sliding window of 2 seconds with a step of 1 second).csv')
        csv_file_path = os.path.join(root, 'statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv')
        print("merging", csv_file_path)
        
        df = pd.read_csv(csv_file_path)
        dfs.append(df)

# Concatenate all the DataFrames vertically
combined_df = pd.concat(dfs, ignore_index=True)

# Optionally, save the combined DataFrame to a new CSV file
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_all.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_all_locations.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_luo.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_right_forearm.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_pelvis.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_pelvis_right_forearm.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_pelvis_right_forearm_insoles.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_insoles_imu.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_insoles_pressure.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_insoles_pressure_imu.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_luo.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_all_insoles_all.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_best_insoles_best.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_imu_left_forearm.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_magnitude_statistical_features_imu_luo_all_data_sources.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_magnitude_statistical_features_imu_luo_only_acceleration.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_best_insoles_best_no_magnetometer.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer.csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv'), index=False)
# combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_features_xsens_best_insoles_best_no_magnetometer(sliding window of 2 seconds with a step of 1 second).csv'), index=False)
combined_df.to_csv(os.path.join(base_dir, 'combined_statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv'), index=False)
print("merging complete")
# Out:
# merging data_set\courseA\id01\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id02\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id03\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id04\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id05\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id07\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# merging data_set\courseA\id08\statistical_and_frequency_features_xsens_best_insoles_best_no_magnetometer(shank_based_gait_detection).csv
# ...
