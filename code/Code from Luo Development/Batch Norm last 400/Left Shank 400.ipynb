# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !pip3 install tslearn
# Out:
# Requirement already satisfied: tslearn in /usr/local/lib/python3.10/dist-packages (0.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.3.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.60.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load in Data

# %%
# start from the sampled dataframe
all_samples = pd.read_csv('/content/gdrive/MyDrive/Next_Step/400_step_samples_forAll.csv')

# %%
# remove all the unneccesary columns
all_samples = all_samples.drop(columns=['Unnamed: 0',' Latitude', ' SampleTimeFine' , ' Longitude',' Altitude', ' Vel_X', ' Vel_Y', ' Vel_Z'])

# %%
all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)
# Out:
# <ipython-input-72-4c1cbb6f442e>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
# making sure all sensors have equal classes
all_samples["sensor_place"].value_counts()
# Out:
# sensor_place
# 93    684000
# 8B    684000
# 9B    684000
# B6    684000
# 95    684000
# CC    684000
# Name: count, dtype: int64

# %%
# remove the calibration data points and the banked R/L to evaluate model performance
# without these variables because in our data collection they wont be included
all_samples = all_samples.drop(all_samples[all_samples["trial_label"] == 'calibration'].index)

# %%
# making sure all surface types have equal classes
all_samples["trial_label"].value_counts()
# Out:
# trial_label
# GR      432000
# BNKR    432000
# BNKL    432000
# SLPD    432000
# SLPU    432000
# STD     432000
# STU     432000
# CS      432000
# FE      432000
# Name: count, dtype: int64

# %%
all_samples = all_samples.sort_values(by=['participant_num', 'trial_num', 'og_df_order'])

# %%
# seperating inputs by the sensor placement
all_samples_93 = all_samples.loc[all_samples['sensor_place'] == "B6"] # left shank

# %%
# list of all of the separated dfs
sensor_dfs = [all_samples_93]

# %%
all_sensor_metrics = []
all_sensor_non_metrics = []

for df in sensor_dfs:
    sensor_df_metrics = []
    metrics = pd.DataFrame(df, columns=[' Acc_X', ' Acc_Y',' Acc_Z', ' FreeAcc_X', ' FreeAcc_Y', ' FreeAcc_Z', ' Gyr_X', ' Gyr_Y',
                                                            ' Gyr_Z', ' Mag_X', ' Mag_Y', ' Mag_Z', ' VelInc_X', ' VelInc_Y',
                                                            ' VelInc_Z', ' Yaw', ' Pitch', ' Roll'])

    # normalize
    metrics = MinMaxScaler().fit_transform(metrics)
    # reshaping numpy array to the correct format (number of sequences, sequence length, number of features)
    numpy_metrics = metrics
    reshape_metrics = np.reshape(numpy_metrics, (1620, 400, 18))
    sensor_df_metrics.append(reshape_metrics)
    all_sensor_metrics.append(sensor_df_metrics)


    # dataframe of the non measurements
    non_metrics = df[['participant_num', 'trial_num', 'trial_label']].copy()
    # reducing the trial label column down to just 1 label per sequence
    drop_doop = non_metrics.drop_duplicates()
    # one hot encode the surface labels (outcome labels)
    label_encoder = LabelEncoder()
    integer_encoded_labels = label_encoder.fit_transform(drop_doop['trial_label'])
    one_hot_encoded_labels = to_categorical(integer_encoded_labels)
    # make encoded variable into numpy
    numpy_result = np.array(one_hot_encoded_labels)
    reshape_non_metrics = np.reshape(numpy_result, (1620, 9))
    all_sensor_non_metrics.append(reshape_non_metrics)

# %%
len(all_sensor_metrics)
# Out:
# 1

# %% [markdown]
# ## Setting up X and Y train/test

# %%
X_93 = np.array(all_sensor_metrics[0])
Y_93 = np.array(all_sensor_non_metrics[0])

index_split = list(range(1620))
# train, test = train_test_split(index_split, test_size=0.15)

X_93 = X_93.squeeze()

# %%
# check variables
n_obs, n_timesteps, n_features, n_classes = 1377, 400, 18, 9

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional

# # clears the session for tensorflow
# tf.keras.backend.clear_session()

# # Define input shape
# input_shape = (n_timesteps, n_features)
# number_of_inputs = len(all_sensor_metrics)

# # Define 6 parallel branches with different inputs
# branch_models = []
# inputs = []
# branches = []
# labels = []
# count = 0


# input_layer = Input(shape=input_shape)
# inputs.append(input_layer)
# # CNN layer
# cnn_out = BatchNormalization()(input_layer)
# cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
# cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
# cnn_out = Dropout(0.4)(cnn_out)
# # Bidirectional LSTM layer
# lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)
# # Attention layer
# attention = Attention()([cnn_out, lstm_out])
# # # Concatenate attention output with LSTM output
# merged = Concatenate(axis=-1)([lstm_out, attention])

# # MLP layer
# mlp_out = Flatten()(merged)
# mlp_out = Dense(units=128, activation='relu')(mlp_out)
# mlp_out = Dense(units=64, activation='relu')(mlp_out)
# output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)
# # Create the model
# model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# # Print the model summary
# model.summary()

# %% [markdown]
# ## Train Model

# %%
# Assuming you have X_93 and Y_93 defined as your training data
X_train, X_test, Y_train, Y_test = train_test_split(X_93, Y_93, test_size=0.15)


n_obs, n_timesteps, n_features, n_classes = X_train.shape[0], X_train.shape[1], X_train.shape[2], Y_train.shape[1]

import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional, BatchNormalization, MaxPooling1D, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping

# clears the session for tensorflow
tf.keras.backend.clear_session()

# Define input shape
input_shape = (n_timesteps, n_features)

# Define the model
input_layer = Input(shape=input_shape)
cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(input_layer)
cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
cnn_out = Dropout(0.2)(cnn_out)
cnn_out = BatchNormalization()(cnn_out)
lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)
attention = Attention()([cnn_out, lstm_out])
merged = Concatenate(axis=-1)([lstm_out, attention])
mlp_out = Flatten()(merged)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)

model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Early stopping callback
callback = EarlyStopping(monitor='loss', patience=10)

# Train the model
history = model.fit(X_train, Y_train, epochs=200, batch_size=128, validation_split=0.15, callbacks=[callback])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test)
print('Test accuracy:', accuracy)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 400, 18)        │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 398, 128)       │          7,040 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling1d             │ (None, 199, 128)       │              0 │ conv1d[0][0]           │
# │ (MaxPooling1D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 199, 128)       │              0 │ max_pooling1d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 199, 128)       │            512 │ dropout[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional             │ (None, 199, 128)       │         98,816 │ batch_normalization[0… │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention (Attention)     │ (None, 199, 128)       │              0 │ batch_normalization[0… │
# │                           │                        │                │ bidirectional[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 199, 256)       │              0 │ bidirectional[0][0],   │
# │                           │                        │                │ attention[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 50944)          │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │      6,520,960 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 9)              │            585 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,636,169 (25.31 MB)
#  Trainable params: 6,635,913 (25.31 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 459ms/step - accuracy: 0.2714 - loss: 2.0133 - val_accuracy: 0.2271 - val_loss: 2.0322
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 440ms/step - accuracy: 0.4668 - loss: 1.5332 - val_accuracy: 0.1836 - val_loss: 2.0845
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.5576 - loss: 1.2644 - val_accuracy: 0.1498 - val_loss: 2.0598
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - accuracy: 0.6118 - loss: 1.1218 - val_accuracy: 0.1498 - val_loss: 2.0892
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.6297 - loss: 1.0134 - val_accuracy: 0.1981 - val_loss: 2.0319
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - accuracy: 0.6578 - loss: 0.9839 - val_accuracy: 0.2077 - val_loss: 2.0163
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - accuracy: 0.6879 - loss: 0.8976 - val_accuracy: 0.2899 - val_loss: 1.9167
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.7084 - loss: 0.8213 - val_accuracy: 0.2657 - val_loss: 1.9272
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 515ms/step - accuracy: 0.7277 - loss: 0.7806 - val_accuracy: 0.3140 - val_loss: 1.8635
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 456ms/step - accuracy: 0.7370 - loss: 0.7798 - val_accuracy: 0.2947 - val_loss: 1.8209
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.7563 - loss: 0.7039 - val_accuracy: 0.3188 - val_loss: 1.7570
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.7898 - loss: 0.6153 - val_accuracy: 0.3478 - val_loss: 1.6754
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 444ms/step - accuracy: 0.7839 - loss: 0.6388 - val_accuracy: 0.4155 - val_loss: 1.5375
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.7719 - loss: 0.6348 - val_accuracy: 0.4251 - val_loss: 1.5170
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.8126 - loss: 0.5686 - val_accuracy: 0.4396 - val_loss: 1.4689
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 492ms/step - accuracy: 0.8002 - loss: 0.5742 - val_accuracy: 0.4831 - val_loss: 1.4284
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - accuracy: 0.8068 - loss: 0.5399 - val_accuracy: 0.4783 - val_loss: 1.4012
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - accuracy: 0.8106 - loss: 0.5359 - val_accuracy: 0.5072 - val_loss: 1.2879
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.8309 - loss: 0.4909 - val_accuracy: 0.4976 - val_loss: 1.2374
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.8433 - loss: 0.4745 - val_accuracy: 0.5072 - val_loss: 1.2729
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 418ms/step - accuracy: 0.8478 - loss: 0.4493 - val_accuracy: 0.5169 - val_loss: 1.2336
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.8654 - loss: 0.4216 - val_accuracy: 0.5652 - val_loss: 1.1829
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 398ms/step - accuracy: 0.8824 - loss: 0.3830 - val_accuracy: 0.5894 - val_loss: 1.1419
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.8730 - loss: 0.3802 - val_accuracy: 0.6135 - val_loss: 1.1496
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 454ms/step - accuracy: 0.8788 - loss: 0.3779 - val_accuracy: 0.5942 - val_loss: 1.1500
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 403ms/step - accuracy: 0.8721 - loss: 0.3791 - val_accuracy: 0.6135 - val_loss: 1.1197
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - accuracy: 0.8970 - loss: 0.3544 - val_accuracy: 0.6039 - val_loss: 1.1615
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 404ms/step - accuracy: 0.8902 - loss: 0.3364 - val_accuracy: 0.6184 - val_loss: 1.1191
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 387ms/step - accuracy: 0.8895 - loss: 0.3201 - val_accuracy: 0.5556 - val_loss: 1.1991
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 395ms/step - accuracy: 0.9069 - loss: 0.2962 - val_accuracy: 0.6087 - val_loss: 1.1554
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 407ms/step - accuracy: 0.9123 - loss: 0.3025 - val_accuracy: 0.6184 - val_loss: 1.1281
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - accuracy: 0.9232 - loss: 0.2702 - val_accuracy: 0.5894 - val_loss: 1.1399
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 395ms/step - accuracy: 0.9235 - loss: 0.2635 - val_accuracy: 0.5604 - val_loss: 1.2283
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - accuracy: 0.8969 - loss: 0.2859 - val_accuracy: 0.5797 - val_loss: 1.2251
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 413ms/step - accuracy: 0.9204 - loss: 0.2610 - val_accuracy: 0.6522 - val_loss: 1.0830
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - accuracy: 0.9174 - loss: 0.2585 - val_accuracy: 0.6135 - val_loss: 1.1435
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 432ms/step - accuracy: 0.9438 - loss: 0.1927 - val_accuracy: 0.5797 - val_loss: 1.2858
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 377ms/step - accuracy: 0.9408 - loss: 0.2194 - val_accuracy: 0.6135 - val_loss: 1.1994
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - accuracy: 0.9238 - loss: 0.2378 - val_accuracy: 0.6329 - val_loss: 1.1496
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - accuracy: 0.9372 - loss: 0.2019 - val_accuracy: 0.6618 - val_loss: 1.0485
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 416ms/step - accuracy: 0.9376 - loss: 0.2138 - val_accuracy: 0.6087 - val_loss: 1.1849
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 387ms/step - accuracy: 0.9414 - loss: 0.1980 - val_accuracy: 0.6667 - val_loss: 1.0777
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 419ms/step - accuracy: 0.9427 - loss: 0.1803 - val_accuracy: 0.5797 - val_loss: 1.3517
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 406ms/step - accuracy: 0.9521 - loss: 0.1764 - val_accuracy: 0.6135 - val_loss: 1.3433
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 435ms/step - accuracy: 0.9646 - loss: 0.1491 - val_accuracy: 0.6473 - val_loss: 1.1782
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 577ms/step - accuracy: 0.9514 - loss: 0.1541 - val_accuracy: 0.5845 - val_loss: 1.4061
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 543ms/step - accuracy: 0.9549 - loss: 0.1690 - val_accuracy: 0.6280 - val_loss: 1.2942
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 552ms/step - accuracy: 0.9591 - loss: 0.1563 - val_accuracy: 0.6425 - val_loss: 1.2149
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - accuracy: 0.9647 - loss: 0.1536 - val_accuracy: 0.6280 - val_loss: 1.4443
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 497ms/step - accuracy: 0.9742 - loss: 0.1268 - val_accuracy: 0.6812 - val_loss: 1.2266
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 498ms/step - accuracy: 0.9668 - loss: 0.1244 - val_accuracy: 0.6715 - val_loss: 1.2126
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 513ms/step - accuracy: 0.9485 - loss: 0.1463 - val_accuracy: 0.6667 - val_loss: 1.1714
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 533ms/step - accuracy: 0.9627 - loss: 0.1388 - val_accuracy: 0.6618 - val_loss: 1.3292
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 587ms/step - accuracy: 0.9708 - loss: 0.1145 - val_accuracy: 0.6812 - val_loss: 1.2706
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 620ms/step - accuracy: 0.9723 - loss: 0.1158 - val_accuracy: 0.6812 - val_loss: 1.3007
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 668ms/step - accuracy: 0.9673 - loss: 0.1245 - val_accuracy: 0.7391 - val_loss: 1.0073
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 690ms/step - accuracy: 0.9585 - loss: 0.1397 - val_accuracy: 0.6908 - val_loss: 1.2714
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 591ms/step - accuracy: 0.9625 - loss: 0.1353 - val_accuracy: 0.7246 - val_loss: 1.1680
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 506ms/step - accuracy: 0.9548 - loss: 0.1264 - val_accuracy: 0.7246 - val_loss: 1.1507
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - accuracy: 0.9605 - loss: 0.1214 - val_accuracy: 0.7053 - val_loss: 1.1959
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 629ms/step - accuracy: 0.9808 - loss: 0.0998 - val_accuracy: 0.6957 - val_loss: 1.1991
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 565ms/step - accuracy: 0.9763 - loss: 0.0941 - val_accuracy: 0.7101 - val_loss: 1.1738
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 553ms/step - accuracy: 0.9669 - loss: 0.1090 - val_accuracy: 0.6763 - val_loss: 1.2979
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 532ms/step - accuracy: 0.9737 - loss: 0.0995 - val_accuracy: 0.6957 - val_loss: 1.1942
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 558ms/step - accuracy: 0.9540 - loss: 0.1352 - val_accuracy: 0.6715 - val_loss: 1.4143
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 538ms/step - accuracy: 0.9655 - loss: 0.1352 - val_accuracy: 0.6570 - val_loss: 1.4812
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.9761 - loss: 0.1048 - val_accuracy: 0.6618 - val_loss: 1.4596
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 491ms/step - accuracy: 0.9807 - loss: 0.0936 - val_accuracy: 0.6425 - val_loss: 1.5867
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 519ms/step - accuracy: 0.9615 - loss: 0.1059 - val_accuracy: 0.6908 - val_loss: 1.2720
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 542ms/step - accuracy: 0.9818 - loss: 0.0779 - val_accuracy: 0.6232 - val_loss: 1.5300
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 540ms/step - accuracy: 0.9758 - loss: 0.0842 - val_accuracy: 0.6860 - val_loss: 1.2819
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step - accuracy: 0.9809 - loss: 0.0782 - val_accuracy: 0.7343 - val_loss: 1.1580
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 515ms/step - accuracy: 0.9797 - loss: 0.0833 - val_accuracy: 0.6860 - val_loss: 1.3371
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 686ms/step - accuracy: 0.9825 - loss: 0.0781 - val_accuracy: 0.6812 - val_loss: 1.3944
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 663ms/step - accuracy: 0.9790 - loss: 0.0779 - val_accuracy: 0.6860 - val_loss: 1.3605
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 607ms/step - accuracy: 0.9779 - loss: 0.0749 - val_accuracy: 0.7005 - val_loss: 1.2871
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 727ms/step - accuracy: 0.9878 - loss: 0.0578 - val_accuracy: 0.7246 - val_loss: 1.3199
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 533ms/step - accuracy: 0.9828 - loss: 0.0689 - val_accuracy: 0.6812 - val_loss: 1.3571
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 574ms/step - accuracy: 0.9910 - loss: 0.0578 - val_accuracy: 0.6860 - val_loss: 1.4434
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 609ms/step - accuracy: 0.9794 - loss: 0.0672 - val_accuracy: 0.7005 - val_loss: 1.3849
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 583ms/step - accuracy: 0.9785 - loss: 0.0679 - val_accuracy: 0.6860 - val_loss: 1.4532
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 519ms/step - accuracy: 0.9874 - loss: 0.0592 - val_accuracy: 0.7005 - val_loss: 1.2237
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 722ms/step - accuracy: 0.9840 - loss: 0.0717 - val_accuracy: 0.7101 - val_loss: 1.2685
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 646ms/step - accuracy: 0.9919 - loss: 0.0546 - val_accuracy: 0.7101 - val_loss: 1.3635
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 550ms/step - accuracy: 0.9812 - loss: 0.0593 - val_accuracy: 0.7343 - val_loss: 1.2845
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 665ms/step - accuracy: 0.9954 - loss: 0.0445 - val_accuracy: 0.7246 - val_loss: 1.2753
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 576ms/step - accuracy: 0.9738 - loss: 0.0721 - val_accuracy: 0.7053 - val_loss: 1.4552
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 553ms/step - accuracy: 0.9845 - loss: 0.0528 - val_accuracy: 0.7150 - val_loss: 1.3235
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.9922 - loss: 0.0500 - val_accuracy: 0.7488 - val_loss: 1.2373
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 518ms/step - accuracy: 0.9852 - loss: 0.0488 - val_accuracy: 0.7198 - val_loss: 1.3362
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 571ms/step - accuracy: 0.9879 - loss: 0.0539 - val_accuracy: 0.7246 - val_loss: 1.4226
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 589ms/step - accuracy: 0.9869 - loss: 0.0481 - val_accuracy: 0.7150 - val_loss: 1.4388
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 568ms/step - accuracy: 0.9890 - loss: 0.0526 - val_accuracy: 0.7343 - val_loss: 1.3118
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 528ms/step - accuracy: 0.9861 - loss: 0.0597 - val_accuracy: 0.7295 - val_loss: 1.2467
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 494ms/step - accuracy: 0.9874 - loss: 0.0488 - val_accuracy: 0.7101 - val_loss: 1.3652
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 615ms/step - accuracy: 0.9908 - loss: 0.0492 - val_accuracy: 0.7391 - val_loss: 1.2607
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8009 - loss: 0.8710
# Test accuracy: 0.7860082387924194

# %% [markdown]
# ### 10 fold cross validation, not really needed

# %%
# import numpy as np
# from sklearn.model_selection import KFold
# from sklearn.metrics import accuracy_score, confusion_matrix
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense, Bidirectional, Concatenate
# from tensorflow.keras.callbacks import EarlyStopping

# num_samples = n_obs
# sequence_length = n_timesteps
# feature_dim = n_features
# num_classes = n_classes

# # Split data into train-validation and test sets
# X_train_val, X_test, y_train_val, y_test = train_test_split(X_93, Y_93, test_size=0.15, random_state=42)

# # Initialize KFold with desired number of folds
# kfold = KFold(n_splits=10, shuffle=True)

# # Initialize lists to store evaluation metrics
# accuracies = []
# conf_matrices = []

# # Perform k-fold cross-validation
# for train_index, test_index in kfold.split(X_train_val):
#     x_train, x_valid = X_train_val[train_index], X_train_val[test_index]
#     y_train, y_valid = y_train_val[train_index], y_train_val[test_index]

#     # clears the session for tensorflow
#     tf.keras.backend.clear_session()

#     # Define input shape
#     input_shape = (sequence_length, feature_dim)

#     # Define the model
#     input_layer = Input(shape=input_shape)
#     cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(input_layer)
#     cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
#     cnn_out = Dropout(0.2)(cnn_out)
#     cnn_out = BatchNormalization()(cnn_out)
#     lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)
#     attention = Attention()([lstm_out, lstm_out])
#     merged = Concatenate(axis=-1)([lstm_out, attention])
#     mlp_out = Flatten()(merged)
#     mlp_out = Dense(units=128, activation='relu')(mlp_out)
#     mlp_out = Dense(units=64, activation='relu')(mlp_out)
#     output_layer = Dense(units=num_classes, activation='softmax')(mlp_out)
#     model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

#     # Compile the model
#     optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
#     model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#     # Early stopping callback
#     callback = EarlyStopping(monitor='loss', patience=10)


#     # Train the model
#     history = model.fit(x=x_train, y=y_train, validation_data=(x_valid, y_valid), epochs=200, batch_size=128, callbacks=[callback])

#     # Make predictions on the validation data
#     fold_predictions = model.predict(x_valid)
#     fold_predictions_labels = np.argmax(fold_predictions, axis=1)
#     y_valids_labels = np.argmax(y_valid, axis=1)

#     # Compute accuracy for this fold
#     accuracy = accuracy_score(y_valids_labels, fold_predictions_labels)
#     accuracies.append(accuracy)

#     # Compute confusion matrix for this fold
#     conf_matrix = confusion_matrix(y_valids_labels, fold_predictions_labels)
#     conf_matrices.append(conf_matrix)

# # Calculate average accuracy across all folds
# avg_accuracy = sum(accuracies) / len(accuracies)
# print("Average Validation Accuracy:", avg_accuracy)

# # Print confusion matrices for each fold
# for i, conf_matrix in enumerate(conf_matrices):
#     print("Confusion Matrix - Fold", i+1, ":\n", conf_matrix)

# # Evaluate the model on the test set
# test_loss, test_accuracy = model.evaluate(X_test, y_test)
# print("Test Loss:", test_loss)
# print("Test Accuracy:", test_accuracy)

# %% [markdown]
# ## Model performance graphs

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Get the weights of the individual branch models
# branch_weights = []

# for branch_model in branch_models:
#     branch_weights.append(branch_model.get_weights())

# # Print the weights for each branch
# for i, branch_weight in enumerate(branch_weights):
#     print(f"Weights for Branch {i + 1}:", branch_weight)

# %%
# Get the weights of the main model
main_model_weights = model.get_weights()

# # Print the weights for each layer
# for layer_weights in main_model_weights:
#     print(layer_weights)

# %% [markdown]
# ![Screenshot 2024-02-14 at 11.57.13.png](data:image/png;base64,...)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# input_data = np.array(x_trains)

print("Evaluate on test data")
results = model.evaluate(X_test, Y_test, batch_size=128)
print("test loss, test acc:", results)



# # Generate predictions (probabilities -- the output of the last layer)
# # on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(fft_x_tests, verbose=0)[:100]
# print("predictions shape:", predictions.shape)


#Predict
y_prediction = model.predict(X_test)

#Create confusion matrix and normalizes it over predicted (columns)
y_prediction = np.argmax(y_prediction, axis=1)
print(y_prediction)
Y_9B_test_proc = np.argmax(Y_test, axis=1)
print(Y_9B_test_proc)
result = confusion_matrix(Y_9B_test_proc, y_prediction , normalize='pred')

# Compute F1 score
f1 = f1_score(Y_9B_test_proc, y_prediction, average='weighted')

print("F1 score:", f1)
# Out:
# Evaluate on test data
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - accuracy: 0.7818 - loss: 0.9299
# test loss, test acc: [0.9125090837478638, 0.7860082387924194]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step
# [4 7 1 4 4 4 3 2 5 2 0 6 5 0 7 1 6 3 3 1 1 1 7 2 8 4 2 8 6 1 7 0 5 6 6 6 5
#  7 3 8 1 2 6 1 5 5 1 4 0 6 8 8 8 0 4 0 8 1 6 7 3 1 6 6 1 8 8 6 4 4 4 5 7 7
#  3 0 6 5 7 4 3 6 0 8 3 0 3 4 2 5 7 7 6 6 4 3 8 4 0 8 7 2 3 5 3 7 1 4 6 1 2
#  1 7 8 2 7 4 1 8 1 0 7 4 7 1 1 4 7 6 1 5 3 8 2 4 7 1 3 1 4 8 5 1 2 0 6 3 0
#  2 6 4 8 3 1 8 6 4 0 1 0 0 1 7 8 8 0 1 3 6 6 8 2 1 8 4 0 6 2 8 4 4 8 3 6 3
#  6 1 8 5 6 6 7 1 7 4 2 5 7 8 0 6 2 1 6 3 3 0 4 0 2 0 7 3 3 1 2 4 0 8 6 8 1
#  4 1 1 6 1 4 4 7 5 5 2 6 7 1 3 7 3 7 1 3 4]
# [4 4 1 6 4 4 3 0 5 2 0 6 5 0 7 1 6 3 4 1 1 1 7 2 8 0 2 8 6 1 7 0 4 6 6 6 2
#  7 3 8 1 2 6 1 5 5 1 5 0 6 8 8 8 0 4 0 8 3 6 7 0 1 6 6 5 8 8 6 0 4 3 5 7 7
#  2 4 3 5 7 4 3 6 0 8 1 0 4 4 2 5 7 7 6 6 3 3 8 0 0 8 7 0 6 1 6 7 1 4 6 1 2
#  3 7 8 2 7 4 1 8 5 0 3 5 7 1 5 4 7 6 1 5 3 8 2 0 7 1 3 1 3 8 5 1 2 0 6 3 0
#  2 3 4 8 4 5 8 3 4 0 1 0 0 1 7 8 8 0 5 4 6 6 8 2 1 8 4 0 6 2 7 4 4 8 3 6 3
#  6 1 8 5 6 6 7 5 7 4 5 5 7 8 0 6 2 1 6 2 4 0 3 0 2 0 7 4 3 1 2 4 0 8 0 8 3
#  5 1 1 6 3 4 6 7 5 5 0 6 7 1 4 7 4 7 1 3 4]
# F1 score: 0.785335514200352

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['Grass', 'Bank Right', 'Bank Left', 'Slope Down', 'Slope Up', 'Downstairs', 'Upstairs', 'Cobble Stone', 'Flat Even'])

cm_display.plot()
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(Y_9B_test_proc, y_prediction)

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
