# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip3 install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.58.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load in Data

# %%
# start from the sampled dataframe
all_samples = pd.read_csv('/content/gdrive/MyDrive/Next_Step/Current Worksheet versions/Varying Input sizes/200_step_samples_forAll.csv')

# %%
# remove all the unneccesary columns
all_samples = all_samples.drop(columns=['Unnamed: 0',' Latitude', ' SampleTimeFine' , ' Longitude',' Altitude', ' Vel_X', ' Vel_Y', ' Vel_Z'])

# %%
all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
# making sure all sensors have equal classes
all_samples["sensor_place"].value_counts()
# Out:
# sensor_place
# 93    342000
# 8B    342000
# 9B    342000
# B6    342000
# 95    342000
# CC    342000
# Name: count, dtype: int64

# %%
# remove the calibration data points and the banked R/L to evaluate model performance
# without these variables because in our data collection they wont be included
all_samples = all_samples.drop(all_samples[all_samples["trial_label"] == 'calibration'].index)

# %%
# making sure all surface types have equal classes
all_samples["trial_label"].value_counts()
# Out:
# trial_label
# GR      216000
# BNKR    216000
# BNKL    216000
# SLPD    216000
# SLPU    216000
# STD     216000
# STU     216000
# CS      216000
# FE      216000
# Name: count, dtype: int64

# %%
all_samples = all_samples.sort_values(by=['participant_num', 'trial_num', 'og_df_order'])

# %%
# seperating inputs by the sensor placement
all_samples_CC = all_samples.loc[all_samples['sensor_place'] == "CC"] # trunk
all_samples_95 = all_samples.loc[all_samples['sensor_place'] == "95"] # wrist
all_samples_93 = all_samples.loc[all_samples['sensor_place'] == "93"] # right thigh
all_samples_8B = all_samples.loc[all_samples['sensor_place'] == "8B"] # left thigh
all_samples_9B = all_samples.loc[all_samples['sensor_place'] == "9B"] # right shank
all_samples_B6 = all_samples.loc[all_samples['sensor_place'] == "B6"] # left shank

# %%
# list of all of the separated dfs
sensor_dfs = [all_samples_CC, all_samples_95 , all_samples_93, all_samples_8B, all_samples_9B, all_samples_B6]

# %%
all_sensor_metrics = []
all_sensor_non_metrics = []

for df in sensor_dfs:
    sensor_df_metrics = []
    metrics = pd.DataFrame(df, columns=[' Acc_X', ' Acc_Y',' Acc_Z', ' FreeAcc_X', ' FreeAcc_Y', ' FreeAcc_Z', ' Gyr_X', ' Gyr_Y',
                                                            ' Gyr_Z', ' Mag_X', ' Mag_Y', ' Mag_Z', ' VelInc_X', ' VelInc_Y',
                                                            ' VelInc_Z', ' Yaw', ' Pitch', ' Roll'])

    # normalize
    metrics = MinMaxScaler().fit_transform(metrics)
    # reshaping numpy array to the correct format (number of sequences, sequence length, number of features)
    numpy_metrics = metrics
    reshape_metrics = np.reshape(numpy_metrics, (1620, 200, 18))
    sensor_df_metrics.append(reshape_metrics)
    all_sensor_metrics.append(sensor_df_metrics)


    # dataframe of the non measurements
    non_metrics = df[['participant_num', 'trial_num', 'trial_label']].copy()
    # reducing the trial label column down to just 1 label per sequence
    drop_doop = non_metrics.drop_duplicates()
    # one hot encode the surface labels (outcome labels)
    label_encoder = LabelEncoder()
    integer_encoded_labels = label_encoder.fit_transform(drop_doop['trial_label'])
    one_hot_encoded_labels = to_categorical(integer_encoded_labels)
    # make encoded variable into numpy
    numpy_result = np.array(one_hot_encoded_labels)
    reshape_non_metrics = np.reshape(numpy_result, (1620, 9))
    all_sensor_non_metrics.append(reshape_non_metrics)

# %%
len(all_sensor_metrics)
# Out:
# 6

# %% [markdown]
# ## Setting up X and Y train/test

# %%
# establish X and Y variables
X_CC, X_95, X_93, X_8B, X_9B, X_B6 = np.array(all_sensor_metrics[0]), np.array(all_sensor_metrics[1]), np.array(all_sensor_metrics[2]), np.array(all_sensor_metrics[3]), np.array(all_sensor_metrics[4]), np.array(all_sensor_metrics[5])
Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6 = np.array(all_sensor_non_metrics[0]), np.array(all_sensor_non_metrics[1]), np.array(all_sensor_non_metrics[2]), np.array(all_sensor_non_metrics[3]), np.array(all_sensor_non_metrics[4]), np.array(all_sensor_non_metrics[5])

# %%
Y_CC.shape
# Out:
# (1620, 9)

# %%
# Concatenate input arrays and target arrays for each dataset horizontally
X_combined = np.concatenate(([X_CC, X_95, X_93, X_8B, X_9B, X_B6]), axis=1)
Y_combined = np.concatenate(([Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6]), axis=0)

# %%
# remove singleton dimensions
X_CC = np.squeeze(X_CC)
X_95 = np.squeeze(X_95)
X_93 = np.squeeze(X_93)
X_8B = np.squeeze(X_8B)
X_9B = np.squeeze(X_9B)
X_B6 = np.squeeze(X_B6)

X_combined = np.squeeze(X_combined)
Y_combined = np.squeeze(Y_combined)

# %%
index_split = list(range(9720))
index_split_signal = list(range(1620))

# %%
train, test = train_test_split(index_split, test_size=0.15)
train_signals, test_signals = train_test_split(index_split_signal, test_size=0.15)

# %%
len(train), len(train_signals)
# Out:
# (8262, 1377)

# %%
len(test), len(test_signals)
# Out:
# (1458, 243)

# %%
# get the splits from each of the signal arrays
X_combined_train = X_combined[train]
X_combined_test = X_combined[test]

Y_combined_train = Y_combined[train]
Y_combined_test = Y_combined[test]

# get the splits from the combined array
X_CC_train = X_CC[train_signals]
X_CC_test = X_CC[test_signals]
Y_CC_train = Y_CC[train_signals]
Y_CC_test = Y_CC[test_signals]

X_95_train = X_95[train_signals]
X_95_test = X_95[test_signals]
Y_95_train = Y_95[train_signals]
Y_95_test = Y_95[test_signals]

X_93_train = X_93[train_signals]
X_93_test = X_93[test_signals]
Y_93_train = Y_93[train_signals]
Y_93_test = Y_93[test_signals]

X_8B_train = X_8B[train_signals]
X_8B_test = X_8B[test_signals]
Y_8B_train = Y_8B[train_signals]
Y_8B_test = Y_8B[test_signals]

X_9B_train = X_9B[train_signals]
X_9B_test = X_9B[test_signals]
Y_9B_train = Y_9B[train_signals]
Y_9B_test = Y_9B[test_signals]

X_B6_train = X_B6[train_signals]
X_B6_test = X_B6[test_signals]
Y_B6_train = Y_B6[train_signals]
Y_B6_test = Y_B6[test_signals]

# %%
# lists of the x, y train and test sets by sensors
x_trains = [X_CC_train, X_95_train, X_93_train, X_8B_train, X_9B_train, X_B6_train]
x_tests = [X_CC_test, X_95_test, X_93_test, X_8B_test, X_9B_test, X_B6_test]
y_trains = [Y_CC_train, Y_95_train, Y_93_train, Y_8B_train, Y_9B_train, Y_B6_train]
y_tests = [Y_CC_test, Y_95_test, Y_93_test, Y_8B_test, Y_9B_test, Y_B6_test]

# %%
# create variables that establish information that will be needed later SIGNAL VERSION
n_obs, n_timesteps, n_features, n_classes = X_CC_train.shape[0], X_CC_test.shape[1], X_CC_test.shape[2], Y_CC_test.shape[1]

# %%
# check variables
n_obs, n_timesteps, n_features, n_classes
# Out:
# (1377, 200, 18, 9)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense, Bidirectional, Concatenate
from tensorflow.keras.callbacks import EarlyStopping

num_samples = n_obs
sequence_length = n_timesteps
feature_dim = n_features
num_classes = n_classes

# Split data into train-validation and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X_93, Y_93, test_size=0.2, random_state=42)

# Define search space for hyperparameters
space = {
    'learning_rate': hp.loguniform('learning_rate', np.log(0.0001), np.log(0.001)),
    'dropout_rate': hp.uniform('dropout_rate', 0.1, 0.5),
    'num_units_lstm': hp.choice('num_units_lstm', [32, 64, 128]),
    'num_filters_cnn': hp.choice('num_filters_cnn', [64, 128, 256]),
}

# Define objective function
def objective(params):
    # Define the model
    input_shape = (sequence_length, feature_dim)
    input_layer = Input(shape=input_shape)
    cnn_out = BatchNormalization()(input_layer)
    cnn_out = Conv1D(filters=params['num_filters_cnn'], kernel_size=3, activation='relu')(cnn_out)
    cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
    cnn_out = Dropout(params['dropout_rate'])(cnn_out)
    cnn_out = Dense(units=params['num_units_lstm'], activation='relu')(cnn_out)  # Adjusted
    lstm_out = Bidirectional(LSTM(units=params['num_units_lstm'], dropout=params['dropout_rate'], recurrent_dropout=params['dropout_rate'], return_sequences=True))(cnn_out)
    attention = Attention()([lstm_out, lstm_out])  # Adjusted
    merged = Concatenate(axis=-1)([lstm_out, attention])
    mlp_out = Flatten()(merged)
    mlp_out = Dense(units=128, activation='relu')(mlp_out)
    mlp_out = Dense(units=64, activation='relu')(mlp_out)
    output_layer = Dense(units=num_classes, activation='softmax')(mlp_out)
    model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # Early stopping callback
    callback = EarlyStopping(monitor='val_loss', patience=10)

    # Train the model
    history = model.fit(x=X_train_val, y=y_train_val, validation_split=0.2, epochs=200, batch_size=128, callbacks=[callback])

    # Evaluate the model on the validation set
    loss, accuracy = model.evaluate(X_test, y_test)

    return {'loss': -accuracy, 'status': STATUS_OK}

# Run Hyperopt optimization
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=30, trials=trials)

print("Best Hyperparameters:", best)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 8/200
#
# 1/9 [==>...........................] - ETA: 4s - loss: 1.0717 - accuracy: 0.6172
# 2/9 [=====>........................] - ETA: 4s - loss: 1.1742 - accuracy: 0.5703
# 3/9 [=========>....................] - ETA: 3s - loss: 1.2015 - accuracy: 0.5625
# 4/9 [============>.................] - ETA: 2s - loss: 1.2293 - accuracy: 0.5352
# 5/9 [===============>..............] - ETA: 2s - loss: 1.2066 - accuracy: 0.5406
# 6/9 [===================>..........] - ETA: 1s - loss: 1.2112 - accuracy: 0.5391
# 7/9 [======================>.......] - ETA: 1s - loss: 1.2072 - accuracy: 0.5435
# 8/9 [=========================>....] - ETA: 0s - loss: 1.2028 - accuracy: 0.5459
# 9/9 [==============================] - ETA: 0s - loss: 1.2014 - accuracy: 0.5463
# 9/9 [==============================] - 5s 575ms/step - loss: 1.2014 - accuracy: 0.5463 - val_loss: 2.0743 - val_accuracy: 0.2192
#
# Epoch 9/200
#
# 1/9 [==>...........................] - ETA: 5s - loss: 1.1340 - accuracy: 0.5703
# 2/9 [=====>........................] - ETA: 4s - loss: 1.1124 - accuracy: 0.5820
# 3/9 [=========>....................] - ETA: 3s - loss: 1.1209 - accuracy: 0.5990
# 4/9 [============>.................] - ETA: 3s - loss: 1.1209 - accuracy: 0.5957
# 5/9 [===============>..............] - ETA: 2s - loss: 1.1065 - accuracy: 0.6094
# 6/9 [===================>..........] - ETA: 1s - loss: 1.1217 - accuracy: 0.5951
# 7/9 [======================>.......] - ETA: 1s - loss: 1.1243 - accuracy: 0.5949
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1244 - accuracy: 0.5889
# 9/9 [==============================] - ETA: 0s - loss: 1.1243 - accuracy: 0.5878
# 9/9 [==============================] - 6s 606ms/step - loss: 1.1243 - accuracy: 0.5878 - val_loss: 2.0930 - val_accuracy: 0.2615
#
# Epoch 10/200
#
# 1/9 [==>...........................] - ETA: 5s - loss: 1.1246 - accuracy: 0.5859
# 2/9 [=====>........................] - ETA: 4s - loss: 1.1969 - accuracy: 0.5703
# 3/9 [=========>....................] - ETA: 3s - loss: 1.1762 - accuracy: 0.5651
# 4/9 [============>.................] - ETA: 3s - loss: 1.1552 - accuracy: 0.5605
# 5/9 [===============>..............] - ETA: 2s - loss: 1.1536 - accuracy: 0.5609
# 6/9 [===================>..........] - ETA: 1s - loss: 1.1492 - accuracy: 0.5625
# 7/9 [======================>.......] - ETA: 1s - loss: 1.1371 - accuracy: 0.5703
# 8/9 [=========================>....] - ETA: 0s - loss: 1.1086 - accuracy: 0.5879
# 9/9 [==============================] - ETA: 0s - loss: 1.1077 - accuracy: 0.5869
# 9/9 [==============================] - 6s 610ms/step - loss: 1.1077 - accuracy: 0.5869 - val_loss: 2.0110 - val_accuracy: 0.2385
#
# Epoch 11/200
#
# 1/9 [==>...........................] - ETA: 4s - loss: 1.0877 - accuracy: 0.5938
# 2/9 [=====>........................] - ETA: 3s - loss: 1.0921 - accuracy: 0.5742
# 3/9 [=========>....................] - ETA: 3s - loss: 1.0638 - accuracy: 0.5833
# 4/9 [============>.................] - ETA: 3s - loss: 1.0535 - accuracy: 0.5781
# 5/9 [===============>..............] - ETA: 2s - loss: 1.0727 - accuracy: 0.5750
# 6/9 [===================>..........] - ETA: 1s - loss: 1.0700 - accuracy: 0.5859
# 7/9 [======================>.......] - ETA: 1s - loss: 1.0534 - accuracy: 0.5960
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0477 - accuracy: 0.5977
# 9/9 [==============================] - ETA: 0s - loss: 1.0494 - accuracy: 0.5965
# 9/9 [==============================] - 5s 605ms/step - loss: 1.0494 - accuracy: 0.5965 - val_loss: 2.0542 - val_accuracy: 0.2346
#
# Epoch 12/200
#
# 1/9 [==>...........................] - ETA: 4s - loss: 0.9365 - accuracy: 0.6953
# 2/9 [=====>........................] - ETA: 4s - loss: 0.9044 - accuracy: 0.7109
# 3/9 [=========>....................] - ETA: 3s - loss: 0.9532 - accuracy: 0.6589
# 4/9 [============>.................] - ETA: 2s - loss: 1.0040 - accuracy: 0.6328
# 5/9 [===============>..............] - ETA: 2s - loss: 1.0189 - accuracy: 0.6281
# 6/9 [===================>..........] - ETA: 1s - loss: 1.0051 - accuracy: 0.6419
# 7/9 [======================>.......] - ETA: 1s - loss: 0.9999 - accuracy: 0.6440
# 8/9 [=========================>....] - ETA: 0s - loss: 1.0001 - accuracy: 0.6416
# 9/9 [==============================] - ETA: 0s - loss: 0.9990 - accuracy: 0.6400
# 9/9 [==============================] - 5s 580ms/step - loss: 0.9990 - accuracy: 0.6400 - val_loss: 1.9869 - val_accuracy: 0.2346
#
# Epoch 13/200
#
# 1/9 [==>...........................] - ETA: 4s - loss: 1.1191 - accuracy: 0.5938
# 2/9 [=====>........................] - ETA: 4s - loss: 1.0818 - accuracy: 0.5859
# 3/9 [=========>....................] - ETA: 3s - loss: 1.0644 - accuracy: 0.6016
# 4/9 [============>.................] - ETA: 2s - loss: 1.0524 - accuracy: 0.5957
# 5/9 [===============>..............] - ETA: 2s - loss: 1.0362 - accuracy: 0.6047
# 6/9 [===================>..........] - ETA: 1s - loss: 1.0154 - accuracy: 0.6185
# 7/9 [======================>.......] - ETA: 1s - loss: 0.9902 - accuracy: 0.6317
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9787 - accuracy: 0.6338
# 9/9 [==============================] - ETA: 0s - loss: 0.9760 - accuracy: 0.6351
# 9/9 [==============================] - 5s 598ms/step - loss: 0.9760 - accuracy: 0.6351 - val_loss: 1.9642 - val_accuracy: 0.2615
#
# Epoch 14/200
#
# 1/9 [==>...........................] - ETA: 5s - loss: 0.8588 - accuracy: 0.6875
# 2/9 [=====>........................] - ETA: 4s - loss: 0.8954 - accuracy: 0.6758
# 3/9 [=========>....................] - ETA: 3s - loss: 0.9217 - accuracy: 0.6536
# 4/9 [============>.................] - ETA: 3s - loss: 0.9010 - accuracy: 0.6641
# 5/9 [===============>..............] - ETA: 2s - loss: 0.8898 - accuracy: 0.6750
# 6/9 [===================>..........] - ETA: 1s - loss: 0.9058 - accuracy: 0.6706
# 7/9 [======================>.......] - ETA: 1s - loss: 0.9136 - accuracy: 0.6708
# 8/9 [=========================>....] - ETA: 0s - loss: 0.


# %%
# Extract best hyperparameters and their corresponding validation accuracy
best_params = trials.best_trial['misc']['vals']
best_accuracy = -trials.best_trial['result']['loss']  # Note the negative sign as we minimized the negative validation accuracy

print("Best Hyperparameters:")
print("Learning Rate:", best_params['learning_rate'][0])
print("Dropout Rate:", best_params['dropout_rate'][0])
print("Number of LSTM Units:", [32, 64, 128][best_params['num_units_lstm'][0]])
print("Number of CNN Filters:", [64, 128, 256][best_params['num_filters_cnn'][0]])
print("Best Validation Accuracy:", best_accuracy)
# Out:
# Best Hyperparameters:
# Learning Rate: 0.00015813825361229338
# Dropout Rate: 0.4048811076627022
# Number of LSTM Units: 64
# Number of CNN Filters: 256
# Best Validation Accuracy: 0.6913580298423767

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional

# clears the session for tensorflow
tf.keras.backend.clear_session()

# Define input shape
input_shape = (n_timesteps, n_features)
number_of_inputs = len(x_trains)

# Define 6 parallel branches with different inputs
branch_models = []
inputs = []
branches = []
labels = []
count = 0

for _ in range(number_of_inputs):
    count += 1
    input_layer = Input(shape=input_shape)
    inputs.append(input_layer)

    # CNN layer
    cnn_out = BatchNormalization()(input_layer)
    cnn_out = Conv1D(filters=256, kernel_size=3, activation='relu')(cnn_out)
    cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
    cnn_out = Dropout(0.4)(cnn_out)


    # Bidirectional LSTM layer
    lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)

     # Attention layer
    attention = Attention()([lstm_out, lstm_out])
    # # Concatenate attention output with LSTM output
    merged = Concatenate(axis=-1)([lstm_out, attention])
    # Dense layer for individual branch output
    output_branch = Dense(units=n_classes, activation='softmax')(merged)


   # Print information about the branch before appending
    print(f"Branch {count} Summary:")
    branch_model = tf.keras.models.Model(inputs=input_layer, outputs=output_branch)
    branch_model.summary()
    print("\n" + "="*50 + "\n")
    # Add the branch model to the list
    branch_models.append(branch_model)
    # Add the branch to the list
    branches.append(output_branch)

# Concatenate the outputs of the 6 branches
merged_output = Concatenate(axis=-1)(branches)
# MLP layer
mlp_out = Flatten()(merged_output)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)
# Create the model
model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Branch 1 Summary:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization (Batch  (None, 200, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 198, 256)             14080     ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 99, 256)              0         ['conv1d[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 99, 256)              0         ['max_pooling1d[0][0]']
#
#  bidirectional (Bidirection  (None, 99, 128)              164352    ['dropout[0][0]']
#  al)
#
#  attention (Attention)       (None, 99, 128)              0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  concatenate (Concatenate)   (None, 99, 256)              0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  dense (Dense)               (None, 99, 9)                2313      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 2 Summary:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization_1 (Bat  (None, 200, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 99, 256)              0         ['conv1d_1[0][0]']
#  g1D)
#
#  dropout_1 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_1[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 99, 128)              164352    ['dropout_1[0][0]']
#  onal)
#
#  attention_1 (Attention)     (None, 99, 128)              0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 99, 256)              0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  dense_1 (Dense)             (None, 99, 9)                2313      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 3 Summary:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization_2 (Bat  (None, 200, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 99, 256)              0         ['conv1d_2[0][0]']
#  g1D)
#
#  dropout_2 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_2[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 99, 128)              164352    ['dropout_2[0][0]']
#  onal)
#
#  attention_2 (Attention)     (None, 99, 128)              0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 99, 256)              0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  dense_2 (Dense)             (None, 99, 9)                2313      ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 4 Summary:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization_3 (Bat  (None, 200, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_3 (MaxPoolin  (None, 99, 256)              0         ['conv1d_3[0][0]']
#  g1D)
#
#  dropout_3 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_3[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 99, 128)              164352    ['dropout_3[0][0]']
#  onal)
#
#  attention_3 (Attention)     (None, 99, 128)              0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 99, 256)              0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  dense_3 (Dense)             (None, 99, 9)                2313      ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 5 Summary:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization_4 (Bat  (None, 200, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling1d_4 (MaxPoolin  (None, 99, 256)              0         ['conv1d_4[0][0]']
#  g1D)
#
#  dropout_4 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_4[0][0]']
#
#  bidirectional_4 (Bidirecti  (None, 99, 128)              164352    ['dropout_4[0][0]']
#  onal)
#
#  attention_4 (Attention)     (None, 99, 128)              0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 99, 256)              0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  dense_4 (Dense)             (None, 99, 9)                2313      ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 6 Summary:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization_5 (Bat  (None, 200, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 99, 256)              0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout_5 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_5[0][0]']
#
#  bidirectional_5 (Bidirecti  (None, 99, 128)              164352    ['dropout_5[0][0]']
#  onal)
#
#  attention_5 (Attention)     (None, 99, 128)              0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate_5 (Concatenate  (None, 99, 256)              0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense_5 (Dense)             (None, 99, 9)                2313      ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 180817 (706.32 KB)
# Trainable params: 180781 (706.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 18)]            0         []
#
#  input_2 (InputLayer)        [(None, 200, 18)]            0         []
#
#  input_3 (InputLayer)        [(None, 200, 18)]            0         []
#
#  input_4 (InputLayer)        [(None, 200, 18)]            0         []
#
#  input_5 (InputLayer)        [(None, 200, 18)]            0         []
#
#  input_6 (InputLayer)        [(None, 200, 18)]            0         []
#
#  batch_normalization (Batch  (None, 200, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 200, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 200, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 200, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 200, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 200, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d (Conv1D)             (None, 198, 256)             14080     ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv1d_3 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv1d_5 (Conv1D)           (None, 198, 256)             14080     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 99, 256)              0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 99, 256)              0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 99, 256)              0         ['conv1d_2[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 99, 256)              0         ['conv1d_3[0][0]']
#  g1D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 99, 256)              0         ['conv1d_4[0][0]']
#  g1D)
#
#  max_pooling1d_5 (MaxPoolin  (None, 99, 256)              0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout (Dropout)           (None, 99, 256)              0         ['max_pooling1d[0][0]']
#
#  dropout_1 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 99, 256)              0         ['max_pooling1d_5[0][0]']
#
#  bidirectional (Bidirection  (None, 99, 128)              164352    ['dropout[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 99, 128)              164352    ['dropout_1[0][0]']
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 99, 128)              164352    ['dropout_2[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 99, 128)              164352    ['dropout_3[0][0]']
#  onal)
#
#  bidirectional_4 (Bidirecti  (None, 99, 128)              164352    ['dropout_4[0][0]']
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 99, 128)              164352    ['dropout_5[0][0]']
#  onal)
#
#  attention (Attention)       (None, 99, 128)              0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  attention_1 (Attention)     (None, 99, 128)              0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  attention_2 (Attention)     (None, 99, 128)              0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  attention_3 (Attention)     (None, 99, 128)              0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  attention_4 (Attention)     (None, 99, 128)              0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  attention_5 (Attention)     (None, 99, 128)              0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate (Concatenate)   (None, 99, 256)              0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  concatenate_1 (Concatenate  (None, 99, 256)              0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 99, 256)              0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  concatenate_3 (Concatenate  (None, 99, 256)              0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  concatenate_4 (Concatenate  (None, 99, 256)              0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  concatenate_5 (Concatenate  (None, 99, 256)              0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense (Dense)               (None, 99, 9)                2313      ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 99, 9)                2313      ['concatenate_1[0][0]']
#
#  dense_2 (Dense)             (None, 99, 9)                2313      ['concatenate_2[0][0]']
#
#  dense_3 (Dense)             (None, 99, 9)                2313      ['concatenate_3[0][0]']
#
#  dense_4 (Dense)             (None, 99, 9)                2313      ['concatenate_4[0][0]']
#
#  dense_5 (Dense)             (None, 99, 9)                2313      ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 99, 54)               0         ['dense[0][0]',
#  )                                                                   'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]',
#                                                                      'dense_5[0][0]']
#
#  flatten (Flatten)           (None, 5346)                 0         ['concatenate_6[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  684416    ['flatten[0][0]']
#
#  dense_7 (Dense)             (None, 64)                   8256      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 9)                    585       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 1778159 (6.78 MB)
# Trainable params: 1777943 (6.78 MB)
# Non-trainable params: 216 (864.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
# Generate some random data for demonstration purposes
num_samples = n_obs
sequence_length = n_timesteps
feature_dim = n_features
num_classes = n_classes

input_data = np.array(x_trains)
labels = np.array(Y_9B_train)

input_dict = {'input_1': input_data[0],
              'input_2': input_data[1],
              'input_3': input_data[2],
              'input_4': input_data[3],
              'input_5': input_data[4],
              'input_6': input_data[5]}

# Compile the model (if not compiled already)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x=input_dict, y=Y_9B_train, epochs=200, batch_size=128, validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# 9/9 [==============================] - 60s 2s/step - loss: 2.1945 - accuracy: 0.1526 - val_loss: 2.2025 - val_accuracy: 0.0870
# Epoch 2/200
# 9/9 [==============================] - 17s 2s/step - loss: 2.1606 - accuracy: 0.1935 - val_loss: 2.1992 - val_accuracy: 0.0833
# Epoch 3/200
# 9/9 [==============================] - 17s 2s/step - loss: 2.0967 - accuracy: 0.3106 - val_loss: 2.1867 - val_accuracy: 0.1558
# Epoch 4/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.9957 - accuracy: 0.3406 - val_loss: 2.1629 - val_accuracy: 0.2101
# Epoch 5/200
# 9/9 [==============================] - 18s 2s/step - loss: 1.8943 - accuracy: 0.2988 - val_loss: 2.1346 - val_accuracy: 0.1812
# Epoch 6/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.7898 - accuracy: 0.3960 - val_loss: 2.1091 - val_accuracy: 0.2210
# Epoch 7/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.6659 - accuracy: 0.4114 - val_loss: 2.0958 - val_accuracy: 0.1594
# Epoch 8/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.5302 - accuracy: 0.4605 - val_loss: 2.0660 - val_accuracy: 0.1848
# Epoch 9/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.3954 - accuracy: 0.5286 - val_loss: 2.0841 - val_accuracy: 0.2065
# Epoch 10/200
# 9/9 [==============================] - 18s 2s/step - loss: 1.2857 - accuracy: 0.5577 - val_loss: 2.0928 - val_accuracy: 0.1486
# Epoch 11/200
# 9/9 [==============================] - 19s 2s/step - loss: 1.1911 - accuracy: 0.6049 - val_loss: 2.0772 - val_accuracy: 0.1486
# Epoch 12/200
# 9/9 [==============================] - 17s 2s/step - loss: 1.1038 - accuracy: 0.6349 - val_loss: 2.0692 - val_accuracy: 0.1630
# Epoch 13/200
# 9/9 [==============================] - 18s 2s/step - loss: 1.0272 - accuracy: 0.6558 - val_loss: 2.0956 - val_accuracy: 0.1594
# Epoch 14/200
# 9/9 [==============================] - 18s 2s/step - loss: 0.9747 - accuracy: 0.6703 - val_loss: 2.1118 - val_accuracy: 0.1522
# Epoch 15/200
# 9/9 [==============================] - 18s 2s/step - loss: 0.9075 - accuracy: 0.6939 - val_loss: 2.1027 - val_accuracy: 0.1920
# Epoch 16/200
# 9/9 [==============================] - 17s 2s/step - loss: 0.8584 - accuracy: 0.7139 - val_loss: 2.0556 - val_accuracy: 0.1667
# Epoch 17/200
# 9/9 [==============================] - 18s 2s/step - loss: 0
step - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.5193 - val_accuracy: 0.9094
# Epoch 168/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0169 - accuracy: 0.9964 - val_loss: 0.5010 - val_accuracy: 0.9058
# Epoch 169/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.5243 - val_accuracy: 0.8986
# Epoch 170/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0157 - accuracy: 0.9982 - val_loss: 0.5012 - val_accuracy: 0.9058
# Epoch 171/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0156 - accuracy: 0.9964 - val_loss: 0.4681 - val_accuracy: 0.9167
# Epoch 172/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0226 - accuracy: 0.9955 - val_loss: 0.5748 - val_accuracy: 0.9058
# Epoch 173/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0181 - accuracy: 0.9973 - val_loss: 0.5012 - val_accuracy: 0.8949
# Epoch 174/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0209 - accuracy: 0.9964 - val_loss: 0.4977 - val_accuracy: 0.9094
# Epoch 175/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.5174 - val_accuracy: 0.8986
# Epoch 176/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 0.5247 - val_accuracy: 0.8986
# Epoch 177/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0107 - accuracy: 0.9991 - val_loss: 0.5539 - val_accuracy: 0.9058
# Epoch 178/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.5283 - val_accuracy: 0.9022
# Epoch 179/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0190 - accuracy: 0.9927 - val_loss: 0.5126 - val_accuracy: 0.9022
# Epoch 180/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0141 - accuracy: 0.9973 - val_loss: 0.5088 - val_accuracy: 0.8986
# Epoch 181/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.5453 - val_accuracy: 0.8986
# Epoch 182/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0162 - accuracy: 0.9973 - val_loss: 0.5141 - val_accuracy: 0.9022
# Epoch 183/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0136 - accuracy: 0.9973 - val_loss: 0.5313 - val_accuracy: 0.9058
# Epoch 184/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.9022
# Epoch 185/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5359 - val_accuracy: 0.9022
# Epoch 186/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0109 - accuracy: 0.9982 - val_loss: 0.5563 - val_accuracy: 0.9058
# Epoch 187/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 0.5084 - val_accuracy: 0.8986
# Epoch 188/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5925 - val_accuracy: 0.8986
# Epoch 189/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.5075 - val_accuracy: 0.8949
# Epoch 190/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0260 - accuracy: 0.9955 - val_loss: 0.5438 - val_accuracy: 0.9058
# Epoch 191/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0208 - accuracy: 0.9936 - val_loss: 0.5716 - val_accuracy: 0.8986
# Epoch 192/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0176 - accuracy: 0.9982 - val_loss: 0.5180 - val_accuracy: 0.8986
# Epoch 193/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.5449 - val_accuracy: 0.8986
# Epoch 194/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.5932 - val_accuracy: 0.8913
# Epoch 195/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.5730 - val_accuracy: 0.8913

# %% [markdown]
# ## Model performance graphs

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Get the weights of the individual branch models
branch_weights = []

for branch_model in branch_models:
    branch_weights.append(branch_model.get_weights())

# # Print the weights for each branch
# for i, branch_weight in enumerate(branch_weights):
#     print(f"Weights for Branch {i + 1}:", branch_weight)

# %%
# Get the weights of the main model
main_model_weights = model.get_weights()

# # Print the weights for each layer
# for layer_weights in main_model_weights:
#     print(layer_weights)

# %% [markdown]
# ![Screenshot 2024-02-14 at 11.57.13.png](data:image/png;base64,...)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# input_data = np.array(x_trains)

print("Evaluate on test data")
results = model.evaluate(x_tests, Y_9B_test, batch_size=128)
print("test loss, test acc:", results)


# # Generate predictions (probabilities -- the output of the last layer)
# # on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(fft_x_tests, verbose=0)[:100]
# print("predictions shape:", predictions.shape)


#Predict
y_prediction = model.predict(x_tests)

#Create confusion matrix and normalizes it over predicted (columns)
y_prediction = np.argmax(y_prediction, axis=1)
print(y_prediction)
Y_9B_test_proc = np.argmax(Y_9B_test, axis=1)
print(Y_9B_test_proc)
result = confusion_matrix(Y_9B_test_proc, y_prediction , normalize='pred')

# Compute F1 score
f1 = f1_score(Y_9B_test_proc, y_prediction, average='weighted')

print("F1 score:", f1)
# Out:
# Evaluate on test data
# 2/2 [==============================] - 5s 228ms/step - loss: 0.3730 - accuracy: 0.9012
# test loss, test acc: [0.3730372190475464, 0.9012345671653748]
# 8/8 [==============================] - 3s 73ms/step
# [2 8 7 7 4 0 4 8 5 4 6 8 2 6 5 6 6 4 2 4 7 0 2 5 3 0 6 6 4 0 2 0 7 8 6 1 6
#  0 8 8 6 4 2 3 6 1 4 0 3 4 4 1 3 1 5 7 5 3 4 1 4 6 1 3 3 1 2 4 6 6 7 6 8 6
#  4 1 5 1 6 3 6 8 8 7 4 6 6 6 4 6 2 4 0 0 6 0 4 2 4 1 0 4 0 7 5 8 4 1 1 2 7
#  0 4 4 4 0 8 5 5 1 4 7 2 6 4 4 3 5 0 2 2 0 6 8 2 0 6 1 7 4 7 2 2 0 6 6 2 7
#  1 7 7 5 6 8 8 3 2 0 2 0 7 1 6 7 6 5 2 6 0 6 3 6 6 3 7 2 3 5 5 4 5 0 2 2 5
#  6 5 2 0 8 6 2 8 1 7 1 8 1 6 7 1 4 4 1 5 1 2 5 0 0 1 0 2 0 6 5 1 7 0 0 2 3
#  3 2 4 3 7 3 5 1 1 4 4 6 7 7 8 2 8 1 2 2 0]
# [2 8 7 7 4 0 4 8 5 5 6 8 2 6 5 6 6 4 2 4 7 0 2 7 3 2 3 6 4 0 4 0 7 8 6 1 6
#  0 8 8 6 4 2 3 6 1 4 0 3 4 4 1 3 1 5 7 5 3 4 2 4 6 1 3 1 3 2 4 6 6 7 6 8 6
#  4 1 5 1 8 3 6 8 8 7 4 6 6 6 4 6 2 4 0 0 6 0 4 2 4 1 0 4 0 5 5 8 4 1 1 2 7
#  0 4 3 6 2 8 5 5 1 4 7 2 6 4 4 2 5 0 2 3 0 6 8 2 0 6 1 7 4 7 2 2 0 6 6 2 7
#  1 5 8 5 6 8 8 3 1 2 2 0 7 1 6 7 6 5 2 6 0 6 3 6 6 3 7 2 3 5 5 4 5 0 2 0 5
#  6 5 2 0 8 6 2 8 1 7 1 8 1 6 7 1 4 4 1 5 1 2 5 0 0 1 0 2 0 6 5 1 7 0 0 0 3
#  3 2 4 3 7 3 5 1 5 4 4 6 7 7 8 0 8 1 2 2 3]
# F1 score: 0.9006600250366086

# %%
# import numpy as np
# import tensorflow as tf

# def integrated_gradients(inputs, model, baseline=None, num_steps=50):
#     if baseline is None:
#         baseline = 0 * inputs

#     scaled_inputs = [baseline + (float(i) / num_steps) * (inputs - baseline) for i in range(num_steps + 1)]
#     scaled_inputs = tf.stack(scaled_inputs)

#     with tf.GradientTape() as tape:
#         tape.watch(scaled_inputs)
#         predictions = model(scaled_inputs)

#     grads = tape.gradient(predictions, scaled_inputs)
#     avg_grads = tf.reduce_mean(grads[:-1], axis=0)
#     integrated_grad = (inputs - baseline) * avg_grads
#     return integrated_grad.numpy()

# # Usage example:
# inputs = x_tests
# baseline = np.zeros_like(inputs)

# ig = integrated_gradients(inputs, model, baseline=baseline)

# %%
# import numpy as np
# import cv2
# import tensorflow as tf
# from tensorflow.keras.models import Model

# def grad_cam(model, x, layer_name):
#     cls = np.argmax(model.predict(x))
#     with tf.GradientTape() as tape:
#         last_conv_layer = model.get_layer(layer_name)
#         iterate = Model([model.inputs], [model.output, last_conv_layer.output])
#         model_out, last_conv_layer = iterate(x)
#         grads = tape.gradient(model_out[:, cls], last_conv_layer)
#         pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)
#     heatmap = np.maximum(heatmap, 0)
#     heatmap /= np.max(heatmap)
#     return heatmap

# # Usage example:
# heatmap = grad_cam(model, x_tests, layer_name='conv1d')  # Adjust layer_name to the appropriate layer in your model

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['GR', 'BNKR', 'BNKL', 'SLPD', 'SLPU', 'STD', 'STU', 'CS', 'FE'])

cm_display.plot()
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(Y_9B_test_proc, y_prediction)

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
