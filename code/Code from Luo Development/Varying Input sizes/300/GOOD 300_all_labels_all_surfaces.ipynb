# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip3 install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.58.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load in Data

# %%
# start from the sampled dataframe
all_samples = pd.read_csv('/content/gdrive/MyDrive/Next_Step/Current Worksheet versions/Varying Input sizes/300_step_samples_forAll.csv')

# %%
# remove all the unneccesary columns
all_samples = all_samples.drop(columns=['Unnamed: 0',' Latitude', ' SampleTimeFine' , ' Longitude',' Altitude', ' Vel_X', ' Vel_Y', ' Vel_Z'])

# %%
all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
# making sure all sensors have equal classes
all_samples["sensor_place"].value_counts()
# Out:
# sensor_place
# 93    513000
# 8B    513000
# 9B    513000
# B6    513000
# 95    513000
# CC    513000
# Name: count, dtype: int64

# %%
# remove the calibration data points and the banked R/L to evaluate model performance
# without these variables because in our data collection they wont be included
all_samples = all_samples.drop(all_samples[all_samples["trial_label"] == 'calibration'].index)

# %%
# making sure all surface types have equal classes
all_samples["trial_label"].value_counts()
# Out:
# trial_label
# GR      324000
# BNKR    324000
# BNKL    324000
# SLPD    324000
# SLPU    324000
# STD     324000
# STU     324000
# CS      324000
# FE      324000
# Name: count, dtype: int64

# %%
all_samples = all_samples.sort_values(by=['participant_num', 'trial_num', 'og_df_order'])

# %%
# seperating inputs by the sensor placement
all_samples_CC = all_samples.loc[all_samples['sensor_place'] == "CC"] # trunk
all_samples_95 = all_samples.loc[all_samples['sensor_place'] == "95"] # wrist
all_samples_93 = all_samples.loc[all_samples['sensor_place'] == "93"] # right thigh
all_samples_8B = all_samples.loc[all_samples['sensor_place'] == "8B"] # left thigh
all_samples_9B = all_samples.loc[all_samples['sensor_place'] == "9B"] # right shank
all_samples_B6 = all_samples.loc[all_samples['sensor_place'] == "B6"] # left shank

# %%
# list of all of the separated dfs
sensor_dfs = [all_samples_CC, all_samples_95 , all_samples_93, all_samples_8B, all_samples_9B, all_samples_B6]

# %%
all_sensor_metrics = []
all_sensor_non_metrics = []

for df in sensor_dfs:
    sensor_df_metrics = []
    metrics = pd.DataFrame(df, columns=[' Acc_X', ' Acc_Y',' Acc_Z', ' FreeAcc_X', ' FreeAcc_Y', ' FreeAcc_Z', ' Gyr_X', ' Gyr_Y',
                                                            ' Gyr_Z', ' Mag_X', ' Mag_Y', ' Mag_Z', ' VelInc_X', ' VelInc_Y',
                                                            ' VelInc_Z', ' Yaw', ' Pitch', ' Roll'])

    # normalize
    metrics = MinMaxScaler().fit_transform(metrics)
    # reshaping numpy array to the correct format (number of sequences, sequence length, number of features)
    numpy_metrics = metrics
    reshape_metrics = np.reshape(numpy_metrics, (1620, 300, 18))
    sensor_df_metrics.append(reshape_metrics)
    all_sensor_metrics.append(sensor_df_metrics)


    # dataframe of the non measurements
    non_metrics = df[['participant_num', 'trial_num', 'trial_label']].copy()
    # reducing the trial label column down to just 1 label per sequence
    drop_doop = non_metrics.drop_duplicates()
    # one hot encode the surface labels (outcome labels)
    label_encoder = LabelEncoder()
    integer_encoded_labels = label_encoder.fit_transform(drop_doop['trial_label'])
    one_hot_encoded_labels = to_categorical(integer_encoded_labels)
    # make encoded variable into numpy
    numpy_result = np.array(one_hot_encoded_labels)
    reshape_non_metrics = np.reshape(numpy_result, (1620, 9))
    all_sensor_non_metrics.append(reshape_non_metrics)

# %%
len(all_sensor_metrics)
# Out:
# 6

# %% [markdown]
# ## Setting up X and Y train/test

# %%
# establish X and Y variables
X_CC, X_95, X_93, X_8B, X_9B, X_B6 = np.array(all_sensor_metrics[0]), np.array(all_sensor_metrics[1]), np.array(all_sensor_metrics[2]), np.array(all_sensor_metrics[3]), np.array(all_sensor_metrics[4]), np.array(all_sensor_metrics[5])
Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6 = np.array(all_sensor_non_metrics[0]), np.array(all_sensor_non_metrics[1]), np.array(all_sensor_non_metrics[2]), np.array(all_sensor_non_metrics[3]), np.array(all_sensor_non_metrics[4]), np.array(all_sensor_non_metrics[5])

# %%
Y_CC.shape
# Out:
# (1620, 9)

# %%
# Concatenate input arrays and target arrays for each dataset horizontally
X_combined = np.concatenate(([X_CC, X_95, X_93, X_8B, X_9B, X_B6]), axis=1)
Y_combined = np.concatenate(([Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6]), axis=0)

# %%
# remove singleton dimensions
X_CC = np.squeeze(X_CC)
X_95 = np.squeeze(X_95)
X_93 = np.squeeze(X_93)
X_8B = np.squeeze(X_8B)
X_9B = np.squeeze(X_9B)
X_B6 = np.squeeze(X_B6)

X_combined = np.squeeze(X_combined)
Y_combined = np.squeeze(Y_combined)

# %%
index_split = list(range(9720))
index_split_signal = list(range(1620))

# %%
train, test = train_test_split(index_split, test_size=0.15)
train_signals, test_signals = train_test_split(index_split_signal, test_size=0.15)

# %%
len(train), len(train_signals)
# Out:
# (8262, 1377)

# %%
len(test), len(test_signals)
# Out:
# (1458, 243)

# %%
# get the splits from each of the signal arrays
X_combined_train = X_combined[train]
X_combined_test = X_combined[test]

Y_combined_train = Y_combined[train]
Y_combined_test = Y_combined[test]

# get the splits from the combined array
X_CC_train = X_CC[train_signals]
X_CC_test = X_CC[test_signals]
Y_CC_train = Y_CC[train_signals]
Y_CC_test = Y_CC[test_signals]

X_95_train = X_95[train_signals]
X_95_test = X_95[test_signals]
Y_95_train = Y_95[train_signals]
Y_95_test = Y_95[test_signals]

X_93_train = X_93[train_signals]
X_93_test = X_93[test_signals]
Y_93_train = Y_93[train_signals]
Y_93_test = Y_93[test_signals]

X_8B_train = X_8B[train_signals]
X_8B_test = X_8B[test_signals]
Y_8B_train = Y_8B[train_signals]
Y_8B_test = Y_8B[test_signals]

X_9B_train = X_9B[train_signals]
X_9B_test = X_9B[test_signals]
Y_9B_train = Y_9B[train_signals]
Y_9B_test = Y_9B[test_signals]

X_B6_train = X_B6[train_signals]
X_B6_test = X_B6[test_signals]
Y_B6_train = Y_B6[train_signals]
Y_B6_test = Y_B6[test_signals]

# %%
# lists of the x, y train and test sets by sensors
x_trains = [X_CC_train, X_95_train, X_93_train, X_8B_train, X_9B_train, X_B6_train]
x_tests = [X_CC_test, X_95_test, X_93_test, X_8B_test, X_9B_test, X_B6_test]
y_trains = [Y_CC_train, Y_95_train, Y_93_train, Y_8B_train, Y_9B_train, Y_B6_train]
y_tests = [Y_CC_test, Y_95_test, Y_93_test, Y_8B_test, Y_9B_test, Y_B6_test]

# %%
# create variables that establish information that will be needed later SIGNAL VERSION
n_obs, n_timesteps, n_features, n_classes = X_CC_train.shape[0], X_CC_test.shape[1], X_CC_test.shape[2], Y_CC_test.shape[1]

# %%
# check variables
n_obs, n_timesteps, n_features, n_classes
# Out:
# (1377, 300, 18, 9)

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense, Bidirectional, Concatenate
# from tensorflow.keras.callbacks import EarlyStopping

# num_samples = n_obs
# sequence_length = n_timesteps
# feature_dim = n_features
# num_classes = n_classes

# # Split data into train-validation and test sets
# X_train_val, X_test, y_train_val, y_test = train_test_split(X_93, Y_93, test_size=0.15)

# # Define search space for hyperparameters
# space = {
#     'learning_rate': hp.loguniform('learning_rate', np.log(0.0001), np.log(0.001)),
#     'dropout_rate': hp.uniform('dropout_rate', 0.1, 0.5),
#     'num_units_lstm': hp.choice('num_units_lstm', [32, 64, 128]),
#     'num_filters_cnn': hp.choice('num_filters_cnn', [64, 128, 256]),
# }

# # Define objective function
# def objective(params):
#     # Define the model
#     input_shape = (sequence_length, feature_dim)
#     input_layer = Input(shape=input_shape)
#     cnn_out = BatchNormalization()(input_layer)
#     cnn_out = Conv1D(filters=params['num_filters_cnn'], kernel_size=3, activation='relu')(cnn_out)
#     cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
#     cnn_out = Dropout(params['dropout_rate'])(cnn_out)
#     cnn_out = Dense(units=params['num_units_lstm'], activation='relu')(cnn_out)  # Adjusted
#     lstm_out = Bidirectional(LSTM(units=params['num_units_lstm'], dropout=params['dropout_rate'], recurrent_dropout=params['dropout_rate'], return_sequences=True))(cnn_out)
#     attention = Attention()([lstm_out, lstm_out])  # Adjusted
#     merged = Concatenate(axis=-1)([lstm_out, attention])
#     mlp_out = Flatten()(merged)
#     mlp_out = Dense(units=128, activation='relu')(mlp_out)
#     mlp_out = Dense(units=64, activation='relu')(mlp_out)
#     output_layer = Dense(units=num_classes, activation='softmax')(mlp_out)
#     model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

#     # Compile the model
#     optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
#     model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#     # Early stopping callback
#     callback = EarlyStopping(monitor='val_loss', patience=10)

#     # Train the model
#     history = model.fit(x=X_train_val, y=y_train_val, validation_split=0.2, epochs=200, batch_size=128, callbacks=[callback])

#     # Evaluate the model on the validation set
#     loss, accuracy = model.evaluate(X_test, y_test)

#     return {'loss': -accuracy, 'status': STATUS_OK}

# # Run Hyperopt optimization
# trials = Trials()
# best = fmin(objective, space, algo=tpe.suggest, max_evals=30, trials=trials)

# print("Best Hyperparameters:", best)

# %%
# Extract best hyperparameters and their corresponding validation accuracy
best_params = trials.best_trial['misc']['vals']
best_accuracy = -trials.best_trial['result']['loss']  # Note the negative sign as we minimized the negative validation accuracy

print("Best Hyperparameters:")
print("Learning Rate:", best_params['learning_rate'][0])
print("Dropout Rate:", best_params['dropout_rate'][0])
print("Number of LSTM Units:", [32, 64, 128][best_params['num_units_lstm'][0]])
print("Number of CNN Filters:", [64, 128, 256][best_params['num_filters_cnn'][0]])
print("Best Validation Accuracy:", best_accuracy)
# Out:
# Best Hyperparameters:
# Learning Rate: 0.00015845796199432126
# Dropout Rate: 0.4104987211744884
# Number of LSTM Units: 32
# Number of CNN Filters: 128
# Best Validation Accuracy: 0.7839506268501282

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional

# clears the session for tensorflow
tf.keras.backend.clear_session()

# Define input shape
input_shape = (n_timesteps, n_features)
number_of_inputs = len(x_trains)

# Define 6 parallel branches with different inputs
branch_models = []
inputs = []
branches = []
labels = []
count = 0

for _ in range(number_of_inputs):
    count += 1
    input_layer = Input(shape=input_shape)
    inputs.append(input_layer)

    # CNN layer
    cnn_out = BatchNormalization()(input_layer)
    cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
    cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
    cnn_out = Dropout(0.4)(cnn_out)


    # Bidirectional LSTM layer
    lstm_out = Bidirectional(LSTM(units=32, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)

     # Attention layer
    attention = Attention()([lstm_out, lstm_out])
    # # Concatenate attention output with LSTM output
    merged = Concatenate(axis=-1)([lstm_out, attention])
    # Dense layer for individual branch output
    output_branch = Dense(units=n_classes, activation='softmax')(merged)


   # Print information about the branch before appending
    print(f"Branch {count} Summary:")
    branch_model = tf.keras.models.Model(inputs=input_layer, outputs=output_branch)
    branch_model.summary()
    print("\n" + "="*50 + "\n")
    # Add the branch model to the list
    branch_models.append(branch_model)
    # Add the branch to the list
    branches.append(output_branch)

# Concatenate the outputs of the 6 branches
merged_output = Concatenate(axis=-1)(branches)
# MLP layer
mlp_out = Flatten()(merged_output)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)
# Create the model
model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Branch 1 Summary:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization (Batch  (None, 300, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 298, 128)             7040      ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 149, 128)             0         ['conv1d[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 149, 128)             0         ['max_pooling1d[0][0]']
#
#  bidirectional (Bidirection  (None, 149, 64)              41216     ['dropout[0][0]']
#  al)
#
#  attention (Attention)       (None, 149, 64)              0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  concatenate (Concatenate)   (None, 149, 128)             0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  dense (Dense)               (None, 149, 9)               1161      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 2 Summary:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization_1 (Bat  (None, 300, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 149, 128)             0         ['conv1d_1[0][0]']
#  g1D)
#
#  dropout_1 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_1[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 149, 64)              41216     ['dropout_1[0][0]']
#  onal)
#
#  attention_1 (Attention)     (None, 149, 64)              0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 149, 128)             0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  dense_1 (Dense)             (None, 149, 9)               1161      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 3 Summary:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization_2 (Bat  (None, 300, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 149, 128)             0         ['conv1d_2[0][0]']
#  g1D)
#
#  dropout_2 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_2[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 149, 64)              41216     ['dropout_2[0][0]']
#  onal)
#
#  attention_2 (Attention)     (None, 149, 64)              0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 149, 128)             0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  dense_2 (Dense)             (None, 149, 9)               1161      ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 4 Summary:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization_3 (Bat  (None, 300, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_3 (MaxPoolin  (None, 149, 128)             0         ['conv1d_3[0][0]']
#  g1D)
#
#  dropout_3 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_3[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 149, 64)              41216     ['dropout_3[0][0]']
#  onal)
#
#  attention_3 (Attention)     (None, 149, 64)              0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 149, 128)             0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  dense_3 (Dense)             (None, 149, 9)               1161      ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 5 Summary:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization_4 (Bat  (None, 300, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling1d_4 (MaxPoolin  (None, 149, 128)             0         ['conv1d_4[0][0]']
#  g1D)
#
#  dropout_4 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_4[0][0]']
#
#  bidirectional_4 (Bidirecti  (None, 149, 64)              41216     ['dropout_4[0][0]']
#  onal)
#
#  attention_4 (Attention)     (None, 149, 64)              0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 149, 128)             0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  dense_4 (Dense)             (None, 149, 9)               1161      ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 6 Summary:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization_5 (Bat  (None, 300, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 149, 128)             0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout_5 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_5[0][0]']
#
#  bidirectional_5 (Bidirecti  (None, 149, 64)              41216     ['dropout_5[0][0]']
#  onal)
#
#  attention_5 (Attention)     (None, 149, 64)              0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate_5 (Concatenate  (None, 149, 128)             0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense_5 (Dense)             (None, 149, 9)               1161      ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 49489 (193.32 KB)
# Trainable params: 49453 (193.18 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 300, 18)]            0         []
#
#  input_2 (InputLayer)        [(None, 300, 18)]            0         []
#
#  input_3 (InputLayer)        [(None, 300, 18)]            0         []
#
#  input_4 (InputLayer)        [(None, 300, 18)]            0         []
#
#  input_5 (InputLayer)        [(None, 300, 18)]            0         []
#
#  input_6 (InputLayer)        [(None, 300, 18)]            0         []
#
#  batch_normalization (Batch  (None, 300, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 300, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 300, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 300, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 300, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 300, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d (Conv1D)             (None, 298, 128)             7040      ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv1d_3 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv1d_5 (Conv1D)           (None, 298, 128)             7040      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 149, 128)             0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 149, 128)             0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 149, 128)             0         ['conv1d_2[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 149, 128)             0         ['conv1d_3[0][0]']
#  g1D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 149, 128)             0         ['conv1d_4[0][0]']
#  g1D)
#
#  max_pooling1d_5 (MaxPoolin  (None, 149, 128)             0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout (Dropout)           (None, 149, 128)             0         ['max_pooling1d[0][0]']
#
#  dropout_1 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 149, 128)             0         ['max_pooling1d_5[0][0]']
#
#  bidirectional (Bidirection  (None, 149, 64)              41216     ['dropout[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 149, 64)              41216     ['dropout_1[0][0]']
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 149, 64)              41216     ['dropout_2[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 149, 64)              41216     ['dropout_3[0][0]']
#  onal)
#
#  bidirectional_4 (Bidirecti  (None, 149, 64)              41216     ['dropout_4[0][0]']
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 149, 64)              41216     ['dropout_5[0][0]']
#  onal)
#
#  attention (Attention)       (None, 149, 64)              0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  attention_1 (Attention)     (None, 149, 64)              0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  attention_2 (Attention)     (None, 149, 64)              0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  attention_3 (Attention)     (None, 149, 64)              0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  attention_4 (Attention)     (None, 149, 64)              0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  attention_5 (Attention)     (None, 149, 64)              0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate (Concatenate)   (None, 149, 128)             0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  concatenate_1 (Concatenate  (None, 149, 128)             0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 149, 128)             0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  concatenate_3 (Concatenate  (None, 149, 128)             0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  concatenate_4 (Concatenate  (None, 149, 128)             0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  concatenate_5 (Concatenate  (None, 149, 128)             0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense (Dense)               (None, 149, 9)               1161      ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 149, 9)               1161      ['concatenate_1[0][0]']
#
#  dense_2 (Dense)             (None, 149, 9)               1161      ['concatenate_2[0][0]']
#
#  dense_3 (Dense)             (None, 149, 9)               1161      ['concatenate_3[0][0]']
#
#  dense_4 (Dense)             (None, 149, 9)               1161      ['concatenate_4[0][0]']
#
#  dense_5 (Dense)             (None, 149, 9)               1161      ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 149, 54)              0         ['dense[0][0]',
#  )                                                                   'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]',
#                                                                      'dense_5[0][0]']
#
#  flatten (Flatten)           (None, 8046)                 0         ['concatenate_6[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  1030016   ['flatten[0][0]']
#
#  dense_7 (Dense)             (None, 64)                   8256      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 9)                    585       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 1335791 (5.10 MB)
# Trainable params: 1335575 (5.09 MB)
# Non-trainable params: 216 (864.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
# Generate some random data for demonstration purposes
num_samples = n_obs
sequence_length = n_timesteps
feature_dim = n_features
num_classes = n_classes

input_data = np.array(x_trains)
labels = np.array(Y_9B_train)

input_dict = {'input_1': input_data[0],
              'input_2': input_data[1],
              'input_3': input_data[2],
              'input_4': input_data[3],
              'input_5': input_data[4],
              'input_6': input_data[5]}

# Compile the model (if not compiled already)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x=input_dict, y=Y_9B_train, epochs=200, batch_size=128, validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# 9/9 [==============================] - 66s 2s/step - loss: 2.2048 - accuracy: 0.1144 - val_loss: 2.2108 - val_accuracy: 0.1051
# Epoch 2/200
# 9/9 [==============================] - 14s 2s/step - loss: 2.1856 - accuracy: 0.1281 - val_loss: 2.1987 - val_accuracy: 0.1304
# Epoch 3/200
# 9/9 [==============================] - 14s 1s/step - loss: 2.1611 - accuracy: 0.2180 - val_loss: 2.2023 - val_accuracy: 0.1377
# Epoch 4/200
# 9/9 [==============================] - 13s 1s/step - loss: 2.1298 - accuracy: 0.2198 - val_loss: 2.2004 - val_accuracy: 0.0942
# Epoch 5/200
# 9/9 [==============================] - 13s 1s/step - loss: 2.0813 - accuracy: 0.2080 - val_loss: 2.1868 - val_accuracy: 0.0906
# Epoch 6/200
# 9/9 [==============================] - 14s 2s/step - loss: 2.0142 - accuracy: 0.2007 - val_loss: 2.1662 - val_accuracy: 0.1304
# Epoch 7/200
# 9/9 [==============================] - 13s 2s/step - loss: 1.9385 - accuracy: 0.2416 - val_loss: 2.1397 - val_accuracy: 0.1051
# Epoch 8/200
# 9/9 [==============================] - 14s 2s/step - loss: 1.8545 - accuracy: 0.2707 - val_loss: 2.1060 - val_accuracy: 0.1014
# Epoch 9/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.7572 - accuracy: 0.3152 - val_loss: 2.0587 - val_accuracy: 0.1993
# Epoch 10/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.6507 - accuracy: 0.3878 - val_loss: 2.0055 - val_accuracy: 0.2210
# Epoch 11/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.5348 - accuracy: 0.4705 - val_loss: 1.9623 - val_accuracy: 0.2609
# Epoch 12/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.4248 - accuracy: 0.5114 - val_loss: 1.8875 - val_accuracy: 0.2645
# Epoch 13/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.3150 - accuracy: 0.5740 - val_loss: 1.8555 - val_accuracy: 0.2464
# Epoch 14/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.2147 - accuracy: 0.5976 - val_loss: 1.7941 - val_accuracy: 0.2971
# Epoch 15/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.1199 - accuracy: 0.6185 - val_loss: 1.7577 - val_accuracy: 0.2826
# Epoch 16/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.0321 - accuracy: 0.6340 - val_loss: 1.7010 - val_accuracy: 0.2717
# Epoch 17/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.9645 - accuracy: 0.6603 - val_loss: 1.6968 - val_accuracy: 0.2464
# Epoch 18/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.9012 - accuracy: 0.6748 - val_loss: 1.6320 - val_accuracy: 0.2862
# Epoch 19/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.8433 - accuracy: 0.7030 - val_loss: 1.6309 - val_accuracy: 0.3007
# Epoch 20/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.8035 - accuracy: 0.7230 - val_loss: 1.5663 - val_accuracy: 0.3370
# Epoch 21/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.7468 - accuracy: 0.7466 - val_loss: 1.5844 - val_accuracy: 0.3297
# Epoch 22/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.7099 - accuracy: 0.7530 - val_loss: 1.5252 - val_accuracy: 0.3406
# Epoch 23/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.6716 - accuracy: 0.7702 - val_loss: 1.5458 - val_accuracy: 0.3551
# Epoch 24/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.6377 - accuracy: 0.7856 - val_loss: 1.4566 - val_accuracy: 0.3986
# Epoch 25/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.5970 - accuracy: 0.8029 - val_loss: 1.4445 - val_accuracy: 0.3841
# Epoch 26/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.5676 - accuracy: 0.8029 - val_loss: 1.4275 - val_accuracy: 0.4457
# Epoch 27/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.5479 - accuracy: 0.8202 - val_loss: 1.3879 - val_accuracy: 0.4601
# Epoch 28/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.5362 - accuracy: 0.8102 - val_loss: 1.3541 - val_accuracy: 0.4746
# Epoch 29/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.5087 - accuracy: 0.8302 - val_loss: 1.3773 - val_accuracy: 0.4348
# Epoch 30/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.4703 - accuracy: 0.8420 - val_loss: 1.3112 - val_accuracy: 0.5109
# Epoch 31/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.4568 - accuracy: 0.8510 - val_loss: 1.2775 - val_accuracy: 0.5036
# Epoch 32/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.4380 - accuracy: 0.8592 - val_loss: 1.1841 - val_accuracy: 0.5616
# Epoch 33/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.4142 - accuracy: 0.8647 - val_loss: 1.1959 - val_accuracy: 0.5652
# Epoch 34/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3898 - accuracy: 0.8756 - val_loss: 1.1262 - val_accuracy: 0.5978
# Epoch 35/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3738 - accuracy: 0.8865 - val_loss: 1.1658 - val_accuracy: 0.5797
# Epoch 36/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3804 - accuracy: 0.8865 - val_loss: 1.0090 - val_accuracy: 0.6775
# Epoch 37/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3501 - accuracy: 0.8992 - val_loss: 1.0214 - val_accuracy: 0.6558
# Epoch 38/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3454 - accuracy: 0.8965 - val_loss: 0.9668 - val_accuracy: 0.7065
# Epoch 39/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3322 - accuracy: 0.8983 - val_loss: 0.9415 - val_accuracy: 0.7101
# Epoch 40/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3134 - accuracy: 0.8965 - val_loss: 0.8809 - val_accuracy: 0.7210
# Epoch 41/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3107 - accuracy: 0.9146 - val_loss: 0.8682 - val_accuracy: 0.7246
# Epoch 42/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2929 - accuracy: 0.9128 - val_loss: 0.8446 - val_accuracy: 0.7464
# Epoch 43/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.3370 - accuracy: 0.8883 - val_loss: 0.7511 - val_accuracy: 0.7790
# Epoch 44/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2966 - accuracy: 0.9055 - val_loss: 0.7618 - val_accuracy: 0.7609
# Epoch 45/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2708 - accuracy: 0.9255 - val_loss: 0.7252 - val_accuracy: 0.7717
# Epoch 46/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2662 - accuracy: 0.9183 - val_loss: 0.6924 - val_accuracy: 0.7862
# Epoch 47/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2410 - accuracy: 0.9301 - val_loss: 0.6853 - val_accuracy: 0.7717
# Epoch 48/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2534 - accuracy: 0.9246 - val_loss: 0.6650 - val_accuracy: 0.7790
# Epoch 49/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2242 - accuracy: 0.9446 - val_loss: 0.6104 - val_accuracy: 0.7935
# Epoch 50/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2362 - accuracy: 0.9337 - val_loss: 0.5677 - val_accuracy: 0.7971
# Epoch 51/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2217 - accuracy: 0.9428 - val_loss: 0.5957 - val_accuracy: 0.7935
# Epoch 52/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2390 - accuracy: 0.9310 - val_loss: 0.5318 - val_accuracy: 0.8116
# Epoch 53/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.2190 - accuracy: 0.9337 - val_loss: 0.5605 - val_accuracy: 0.8080
# Epoch 54/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2104 - accuracy: 0.9428 - val_loss: 0.4987 - val_accuracy: 0.8225
# Epoch 55/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2027 - accuracy: 0.9382 - val_loss: 0.5147 - val_accuracy: 0.8297
# Epoch 56/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2072 - accuracy: 0.9373 - val_loss: 0.4483 - val_accuracy: 0.8333
# Epoch 57/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2120 - accuracy: 0.9346 - val_loss: 0.4341 - val_accuracy: 0.8406
# Epoch 58/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1986 - accuracy: 0.9401 - val_loss: 0.4503 - val_accuracy: 0.8478
# Epoch 59/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1928 - accuracy: 0.9428 - val_loss: 0.4412 - val_accuracy: 0.8370
# Epoch 60/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.2065 - accuracy: 0.9391 - val_loss: 0.4158 - val_accuracy: 0.8478
# Epoch 61/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.1964 - accuracy: 0.9419 - val_loss: 0.4172 - val_accuracy: 0.8478
# Epoch 62/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1674 - accuracy: 0.9519 - val_loss: 0.3978 - val_accuracy: 0.8514
# Epoch 63/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1617 - accuracy: 0.9564 - val_loss: 0.3753 - val_accuracy: 0.8587
# Epoch 64/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1730 - accuracy: 0.9419 - val_loss: 0.4152 - val_accuracy: 0.8478
# Epoch 65/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1807 - accuracy: 0.9437 - val_loss: 0.3513 - val_accuracy: 0.8623
# Epoch 66/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1661 - accuracy: 0.9473 - val_loss: 0.3820 - val_accuracy: 0.8623
# Epoch 67/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1641 - accuracy: 0.9546 - val_loss: 0.3387 - val_accuracy: 0.8804
# Epoch 68/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1558 - accuracy: 0.9555 - val_loss: 0.3166 - val_accuracy: 0.8732
# Epoch 69/200
# 9/9 [==============================] - 14s 1s/step - loss: 0.1580 - accuracy: 0.9564 - val_loss: 0.3182 - val_accuracy: 0.8732
# Epoch 70/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1508 - accuracy: 0.9546 - val_loss: 0.3372 - val_accuracy: 0.8696
# Epoch 71/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1572 - accuracy: 0.9473 - val_loss: 0.2800 - val_accuracy: 0.8841
# Epoch 72/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1422 - accuracy: 0.9573 - val_loss: 0.2792 - val_accuracy: 0.8877
# Epoch 73/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1302 - accuracy: 0.9646 - val_loss: 0.2908 - val_accuracy: 0.8804
# Epoch 74/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1818 - accuracy: 0.9428 - val_loss: 0.2804 - val_accuracy: 0.8804
# Epoch 75/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1324 - accuracy: 0.9600 - val_loss: 0.2697 - val_accuracy: 0.8986
# Epoch 76/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1405 - accuracy: 0.9573 - val_loss: 0.2738 - val_accuracy: 0.8804
# Epoch 77/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1189 - accuracy: 0.9709 - val_loss: 0.2555 - val_accuracy: 0.9094
# Epoch 78/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.1268 - accuracy: 0.9600 - val_loss: 0.2751 - val_accuracy: 0.8949
# Epoch 79/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1240 - accuracy: 0.9564 - val_loss: 0.2807 - val_accuracy: 0.8877
# Epoch 80/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1571 - accuracy: 0.9573 - val_loss: 0.2672 - val_accuracy: 0.8877
# Epoch 81/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1306 - accuracy: 0.9637 - val_loss: 0.2727 - val_accuracy: 0.8949
# Epoch 82/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1286 - accuracy: 0.9628 - val_loss: 0.2586 - val_accuracy: 0.9094
# Epoch 83/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1105 - accuracy: 0.9682 - val_loss: 0.2388 - val_accuracy: 0.9312
# Epoch 84/200
# 9/9 [==============================] - 14s 1s/step - loss: 0.1251 - accuracy: 0.9564 - val_loss: 0.2284 - val_accuracy: 0.9167
# Epoch 85/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1201 - accuracy: 0.9673 - val_loss: 0.2145 - val_accuracy: 0.9203
# Epoch 86/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1054 - accuracy: 0.9737 - val_loss: 0.2282 - val_accuracy: 0.9130
# Epoch 87/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1054 - accuracy: 0.9691 - val_loss: 0.2296 - val_accuracy: 0.9167
# Epoch 88/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1091 - accuracy: 0.9682 - val_loss: 0.2203 - val_accuracy: 0.9239
# Epoch 89/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1051 - accuracy: 0.9673 - val_loss: 0.2532 - val_accuracy: 0.9058
# Epoch 90/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1043 - accuracy: 0.9691 - val_loss: 0.2044 - val_accuracy: 0.9384
# Epoch 91/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0926 - accuracy: 0.9755 - val_loss: 0.2069 - val_accuracy: 0.9348
# Epoch 92/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0937 - accuracy: 0.9709 - val_loss: 0.2299 - val_accuracy: 0.9058
# Epoch 93/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0996 - accuracy: 0.9664 - val_loss: 0.2366 - val_accuracy: 0.9312
# Epoch 94/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0884 - accuracy: 0.9773 - val_loss: 0.2078 - val_accuracy: 0.9275
# Epoch 95/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.1013 - accuracy: 0.9664 - val_loss: 0.2196 - val_accuracy: 0.9203
# Epoch 96/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.1174 - accuracy: 0.9682 - val_loss: 0.2488 - val_accuracy: 0.9058
# Epoch 97/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0829 - accuracy: 0.9773 - val_loss: 0.2241 - val_accuracy: 0.9239
# Epoch 98/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0885 - accuracy: 0.9718 - val_loss: 0.2219 - val_accuracy: 0.9275
# Epoch 99/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0981 - accuracy: 0.9655 - val_loss: 0.2131 - val_accuracy: 0.9348
# Epoch 100/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0797 - accuracy: 0.9755 - val_loss: 0.2362 - val_accuracy: 0.9094
# Epoch 101/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0919 - accuracy: 0.9728 - val_loss: 0.2157 - val_accuracy: 0.9094
# Epoch 102/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0881 - accuracy: 0.9773 - val_loss: 0.2130 - val_accuracy: 0.9275
# Epoch 103/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0810 - accuracy: 0.9782 - val_loss: 0.2453 - val_accuracy: 0.8986
# Epoch 104/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0809 - accuracy: 0.9773 - val_loss: 0.2097 - val_accuracy: 0.9384
# Epoch 105/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0867 - accuracy: 0.9709 - val_loss: 0.2171 - val_accuracy: 0.9239
# Epoch 106/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0962 - accuracy: 0.9709 - val_loss: 0.2404 - val_accuracy: 0.9203
# Epoch 107/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0762 - accuracy: 0.9755 - val_loss: 0.2193 - val_accuracy: 0.9167
# Epoch 108/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0740 - accuracy: 0.9755 - val_loss: 0.2457 - val_accuracy: 0.9275
# Epoch 109/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0745 - accuracy: 0.9800 - val_loss: 0.2101 - val_accuracy: 0.9275
# Epoch 110/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0758 - accuracy: 0.9791 - val_loss: 0.2099 - val_accuracy: 0.9130
# Epoch 111/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0648 - accuracy: 0.9818 - val_loss: 0.1945 - val_accuracy: 0.9312
# Epoch 112/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0547 - accuracy: 0.9882 - val_loss: 0.2049 - val_accuracy: 0.9348
# Epoch 113/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0782 - accuracy: 0.9737 - val_loss: 0.2185 - val_accuracy: 0.9239
# Epoch 114/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0595 - accuracy: 0.9837 - val_loss: 0.1911 - val_accuracy: 0.9348
# Epoch 115/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0853 - accuracy: 0.9700 - val_loss: 0.2044 - val_accuracy: 0.9239
# Epoch 116/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0741 - accuracy: 0.9782 - val_loss: 0.1963 - val_accuracy: 0.9384
# Epoch 117/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0738 - accuracy: 0.9846 - val_loss: 0.1986 - val_accuracy: 0.9312
# Epoch 118/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0622 - accuracy: 0.9818 - val_loss: 0.2228 - val_accuracy: 0.9239
# Epoch 119/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0633 - accuracy: 0.9809 - val_loss: 0.2232 - val_accuracy: 0.9312
# Epoch 120/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0617 - accuracy: 0.9837 - val_loss: 0.2054 - val_accuracy: 0.9348
# Epoch 121/200
# 9/9 [==============================] - 13s 2s/step - loss: 0.0540 - accuracy: 0.9864 - val_loss: 0.2059 - val_accuracy: 0.9420
# Epoch 122/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0593 - accuracy: 0.9827 - val_loss: 0.2165 - val_accuracy: 0.9275
# Epoch 123/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0659 - accuracy: 0.9827 - val_loss: 0.1972 - val_accuracy: 0.9457
# Epoch 124/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0679 - accuracy: 0.9800 - val_loss: 0.1918 - val_accuracy: 0.9420
# Epoch 125/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0550 - accuracy: 0.9827 - val_loss: 0.2096 - val_accuracy: 0.9167
# Epoch 126/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0618 - accuracy: 0.9809 - val_loss: 0.2029 - val_accuracy: 0.9312
# Epoch 127/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0579 - accuracy: 0.9837 - val_loss: 0.1955 - val_accuracy: 0.9348
# Epoch 128/200
# 9/9 [==============================] - 14s 2s/step - loss: 0.0542 - accuracy: 0.9827 - val_loss: 0.2051 - val_accuracy: 0.9348
# Epoch 129/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0552 - accuracy: 0.9818 - val_loss: 0.1974 - val_accuracy: 0.9275
# Epoch 130/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0716 - accuracy: 0.9782 - val_loss: 0.1947 - val_accuracy: 0.9384
# Epoch 131/200
# 9/9 [==============================] - 13s 1s/step - loss: 0.0676 - accuracy: 0.9800 - val_loss: 0.2200 - val_accuracy: 0.9203

# %% [markdown]
# ## Model performance graphs

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Get the weights of the individual branch models
branch_weights = []

for branch_model in branch_models:
    branch_weights.append(branch_model.get_weights())

# # Print the weights for each branch
# for i, branch_weight in enumerate(branch_weights):
#     print(f"Weights for Branch {i + 1}:", branch_weight)

# %%
# Get the weights of the main model
main_model_weights = model.get_weights()

# # Print the weights for each layer
# for layer_weights in main_model_weights:
#     print(layer_weights)

# %% [markdown]
# ![Screenshot 2024-02-14 at 11.57.13.png](data:image/png;base64,...)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# input_data = np.array(x_trains)

print("Evaluate on test data")
results = model.evaluate(x_tests, Y_95_test, batch_size=128)
print("test loss, test acc:", results)


# # Generate predictions (probabilities -- the output of the last layer)
# # on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(fft_x_tests, verbose=0)[:100]
# print("predictions shape:", predictions.shape)


#Predict
y_prediction = model.predict(x_tests)

#Create confusion matrix and normalizes it over predicted (columns)
y_prediction = np.argmax(y_prediction, axis=1)
print(y_prediction)
Y_9B_test_proc = np.argmax(Y_95_test, axis=1)
print(Y_9B_test_proc)
result = confusion_matrix(Y_9B_test_proc, y_prediction , normalize='pred')

# Compute F1 score
f1 = f1_score(Y_9B_test_proc, y_prediction, average='weighted')

print("F1 score:", f1)
# Out:
# Evaluate on test data
# 2/2 [==============================] - 4s 204ms/step - loss: 0.5940 - accuracy: 0.8724
# test loss, test acc: [0.5939795970916748, 0.8724279999732971]
# 8/8 [==============================] - 7s 115ms/step
# [3 1 5 8 5 3 5 6 5 2 0 7 8 3 3 5 8 4 7 2 4 3 1 3 6 3 6 5 4 8 0 8 6 2 0 0 0
#  7 0 1 1 2 7 0 6 2 5 1 3 6 2 2 4 0 8 1 0 2 8 8 8 2 7 3 0 7 8 7 5 0 3 6 4 2
#  8 8 0 5 7 4 6 2 6 5 0 8 7 5 3 1 3 4 2 8 6 4 0 8 0 0 5 6 3 8 4 2 0 5 7 7 4
#  8 3 7 0 6 0 4 6 3 1 2 1 2 2 6 2 7 7 2 1 4 0 2 2 7 2 7 2 2 6 2 2 4 6 4 1 8
#  4 4 7 0 7 1 3 2 1 2 8 2 0 4 0 6 7 3 1 3 2 0 8 2 1 0 4 0 1 7 1 4 8 6 6 7 0
#  2 1 6 7 4 5 7 2 5 3 0 2 5 2 1 5 4 1 1 3 0 0 5 1 0 3 7 0 8 3 4 1 8 6 6 8 1
#  5 8 3 1 7 6 1 7 2 4 4 0 0 8 3 4 5 7 2 7 1]
# [3 1 5 8 5 3 5 6 5 2 0 7 8 3 3 5 8 4 7 2 4 3 1 3 6 3 6 5 4 8 0 8 5 0 0 2 0
#  7 0 1 1 2 7 0 6 0 5 1 3 6 2 2 4 0 7 1 0 2 8 8 8 3 7 3 0 7 8 7 5 0 3 6 4 2
#  8 8 2 5 7 4 6 2 6 8 3 8 7 5 3 1 3 4 2 8 6 4 2 8 0 0 5 6 3 8 8 0 0 5 7 7 4
#  8 3 7 0 6 0 8 6 8 0 2 1 2 2 6 5 7 7 2 1 4 2 1 1 7 3 7 2 2 6 2 2 4 6 4 1 8
#  4 4 7 0 7 1 3 5 1 2 8 0 2 4 0 6 7 3 1 3 0 2 7 2 1 0 4 0 3 7 1 4 8 6 6 7 6
#  2 1 6 7 4 8 7 2 5 3 0 2 5 2 1 5 4 1 1 3 0 1 5 1 0 3 7 0 8 3 4 1 8 6 6 8 1
#  5 8 3 1 7 6 1 7 2 4 4 0 0 8 5 4 5 7 2 7 1]
# F1 score: 0.8744380466386339

# %%
# import numpy as np
# import tensorflow as tf

# def integrated_gradients(inputs, model, baseline=None, num_steps=50):
#     if baseline is None:
#         baseline = 0 * inputs

#     scaled_inputs = [baseline + (float(i) / num_steps) * (inputs - baseline) for i in range(num_steps + 1)]
#     scaled_inputs = tf.stack(scaled_inputs)

#     with tf.GradientTape() as tape:
#         tape.watch(scaled_inputs)
#         predictions = model(scaled_inputs)

#     grads = tape.gradient(predictions, scaled_inputs)
#     avg_grads = tf.reduce_mean(grads[:-1], axis=0)
#     integrated_grad = (inputs - baseline) * avg_grads
#     return integrated_grad.numpy()

# # Usage example:
# inputs = x_tests
# baseline = np.zeros_like(inputs)

# ig = integrated_gradients(inputs, model, baseline=baseline)

# %%
# import numpy as np
# import cv2
# import tensorflow as tf
# from tensorflow.keras.models import Model

# def grad_cam(model, x, layer_name):
#     cls = np.argmax(model.predict(x))
#     with tf.GradientTape() as tape:
#         last_conv_layer = model.get_layer(layer_name)
#         iterate = Model([model.inputs], [model.output, last_conv_layer.output])
#         model_out, last_conv_layer = iterate(x)
#         grads = tape.gradient(model_out[:, cls], last_conv_layer)
#         pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)
#     heatmap = np.maximum(heatmap, 0)
#     heatmap /= np.max(heatmap)
#     return heatmap

# # Usage example:
# heatmap = grad_cam(model, x_tests, layer_name='conv1d')  # Adjust layer_name to the appropriate layer in your model

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['GR', 'BNKR', 'BNKL', 'SLPD', 'SLPU', 'STD', 'STU', 'CS', 'FE'])

cm_display.plot()
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(Y_9B_test_proc, y_prediction)

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
