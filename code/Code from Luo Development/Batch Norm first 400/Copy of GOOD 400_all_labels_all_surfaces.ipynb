# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip3 install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.58.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load in Data

# %%
# start from the sampled dataframe
all_samples = pd.read_csv('/content/gdrive/MyDrive/Next_Step/400_step_samples_forAll.csv')

# %%
# remove all the unneccesary columns
all_samples = all_samples.drop(columns=['Unnamed: 0',' Latitude', ' SampleTimeFine' , ' Longitude',' Altitude', ' Vel_X', ' Vel_Y', ' Vel_Z'])

# %%
all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
# making sure all sensors have equal classes
all_samples["sensor_place"].value_counts()
# Out:
# sensor_place
# 93    684000
# 8B    684000
# 9B    684000
# B6    684000
# 95    684000
# CC    684000
# Name: count, dtype: int64

# %%
# remove the calibration data points and the banked R/L to evaluate model performance
# without these variables because in our data collection they wont be included
all_samples = all_samples.drop(all_samples[all_samples["trial_label"] == 'calibration'].index)

# %%
# making sure all surface types have equal classes
all_samples["trial_label"].value_counts()
# Out:
# trial_label
# GR      432000
# BNKR    432000
# BNKL    432000
# SLPD    432000
# SLPU    432000
# STD     432000
# STU     432000
# CS      432000
# FE      432000
# Name: count, dtype: int64

# %%
all_samples = all_samples.sort_values(by=['participant_num', 'trial_num', 'og_df_order'])

# %%
# seperating inputs by the sensor placement
all_samples_CC = all_samples.loc[all_samples['sensor_place'] == "CC"] # trunk
all_samples_95 = all_samples.loc[all_samples['sensor_place'] == "95"] # wrist
all_samples_93 = all_samples.loc[all_samples['sensor_place'] == "93"] # right thigh
all_samples_8B = all_samples.loc[all_samples['sensor_place'] == "8B"] # left thigh
all_samples_9B = all_samples.loc[all_samples['sensor_place'] == "9B"] # right shank
all_samples_B6 = all_samples.loc[all_samples['sensor_place'] == "B6"] # left shank

# %%
# list of all of the separated dfs
sensor_dfs = [all_samples_CC, all_samples_95 , all_samples_93, all_samples_8B, all_samples_9B, all_samples_B6]

# %%
all_sensor_metrics = []
all_sensor_non_metrics = []

for df in sensor_dfs:
    sensor_df_metrics = []
    metrics = pd.DataFrame(df, columns=[' Acc_X', ' Acc_Y',' Acc_Z', ' FreeAcc_X', ' FreeAcc_Y', ' FreeAcc_Z', ' Gyr_X', ' Gyr_Y',
                                                            ' Gyr_Z', ' Mag_X', ' Mag_Y', ' Mag_Z', ' VelInc_X', ' VelInc_Y',
                                                            ' VelInc_Z', ' Yaw', ' Pitch', ' Roll'])

    # normalize
    metrics = MinMaxScaler().fit_transform(metrics)
    # reshaping numpy array to the correct format (number of sequences, sequence length, number of features)
    numpy_metrics = metrics
    reshape_metrics = np.reshape(numpy_metrics, (1620, 400, 18))
    sensor_df_metrics.append(reshape_metrics)
    all_sensor_metrics.append(sensor_df_metrics)


    # dataframe of the non measurements
    non_metrics = df[['participant_num', 'trial_num', 'trial_label']].copy()
    # reducing the trial label column down to just 1 label per sequence
    drop_doop = non_metrics.drop_duplicates()
    # one hot encode the surface labels (outcome labels)
    label_encoder = LabelEncoder()
    integer_encoded_labels = label_encoder.fit_transform(drop_doop['trial_label'])
    one_hot_encoded_labels = to_categorical(integer_encoded_labels)
    # make encoded variable into numpy
    numpy_result = np.array(one_hot_encoded_labels)
    reshape_non_metrics = np.reshape(numpy_result, (1620, 9))
    all_sensor_non_metrics.append(reshape_non_metrics)

# %%
len(all_sensor_metrics)
# Out:
# 6

# %% [markdown]
# ## Setting up X and Y train/test

# %%
# establish X and Y variables
X_CC, X_95, X_93, X_8B, X_9B, X_B6 = np.array(all_sensor_metrics[0]), np.array(all_sensor_metrics[1]), np.array(all_sensor_metrics[2]), np.array(all_sensor_metrics[3]), np.array(all_sensor_metrics[4]), np.array(all_sensor_metrics[5])
Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6 = np.array(all_sensor_non_metrics[0]), np.array(all_sensor_non_metrics[1]), np.array(all_sensor_non_metrics[2]), np.array(all_sensor_non_metrics[3]), np.array(all_sensor_non_metrics[4]), np.array(all_sensor_non_metrics[5])

# %%
Y_CC.shape
# Out:
# (1620, 9)

# %%
# Concatenate input arrays and target arrays for each dataset horizontally
X_combined = np.concatenate(([X_CC, X_95, X_93, X_8B, X_9B, X_B6]), axis=1)
Y_combined = np.concatenate(([Y_CC, Y_95, Y_93, Y_8B, Y_9B, Y_B6]), axis=0)

# %%
# remove singleton dimensions
X_CC = np.squeeze(X_CC)
X_95 = np.squeeze(X_95)
X_93 = np.squeeze(X_93)
X_8B = np.squeeze(X_8B)
X_9B = np.squeeze(X_9B)
X_B6 = np.squeeze(X_B6)

X_combined = np.squeeze(X_combined)
Y_combined = np.squeeze(Y_combined)

# %%
index_split = list(range(9720))
index_split_signal = list(range(1620))

# %%
train, test = train_test_split(index_split, test_size=0.15)
train_signals, test_signals = train_test_split(index_split_signal, test_size=0.15)

# %%
len(train), len(train_signals)
# Out:
# (8262, 1377)

# %%
len(test), len(test_signals)
# Out:
# (1458, 243)

# %%
# get the splits from each of the signal arrays
X_combined_train = X_combined[train]
X_combined_test = X_combined[test]

Y_combined_train = Y_combined[train]
Y_combined_test = Y_combined[test]

# get the splits from the combined array
X_CC_train = X_CC[train_signals]
X_CC_test = X_CC[test_signals]
Y_CC_train = Y_CC[train_signals]
Y_CC_test = Y_CC[test_signals]

X_95_train = X_95[train_signals]
X_95_test = X_95[test_signals]
Y_95_train = Y_95[train_signals]
Y_95_test = Y_95[test_signals]

X_93_train = X_93[train_signals]
X_93_test = X_93[test_signals]
Y_93_train = Y_93[train_signals]
Y_93_test = Y_93[test_signals]

X_8B_train = X_8B[train_signals]
X_8B_test = X_8B[test_signals]
Y_8B_train = Y_8B[train_signals]
Y_8B_test = Y_8B[test_signals]

X_9B_train = X_9B[train_signals]
X_9B_test = X_9B[test_signals]
Y_9B_train = Y_9B[train_signals]
Y_9B_test = Y_9B[test_signals]

X_B6_train = X_B6[train_signals]
X_B6_test = X_B6[test_signals]
Y_B6_train = Y_B6[train_signals]
Y_B6_test = Y_B6[test_signals]

# %%
# lists of the x, y train and test sets by sensors
x_trains = [X_CC_train, X_95_train, X_93_train, X_8B_train, X_9B_train, X_B6_train]
x_tests = [X_CC_test, X_95_test, X_93_test, X_8B_test, X_9B_test, X_B6_test]
y_trains = [Y_CC_train, Y_95_train, Y_93_train, Y_8B_train, Y_9B_train, Y_B6_train]
y_tests = [Y_CC_test, Y_95_test, Y_93_test, Y_8B_test, Y_9B_test, Y_B6_test]

# %%
# create variables that establish information that will be needed later SIGNAL VERSION
n_obs, n_timesteps, n_features, n_classes = X_CC_train.shape[0], X_CC_test.shape[1], X_CC_test.shape[2], Y_CC_test.shape[1]

# %%
# check variables
n_obs, n_timesteps, n_features, n_classes
# Out:
# (1377, 400, 18, 9)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional

# clears the session for tensorflow
tf.keras.backend.clear_session()

# Define input shape
input_shape = (n_timesteps, n_features)
number_of_inputs = len(x_trains)

# Define 6 parallel branches with different inputs
branch_models = []
inputs = []
branches = []
labels = []
count = 0

for _ in range(number_of_inputs):
    count += 1
    input_layer = Input(shape=input_shape)
    inputs.append(input_layer)

    # CNN layer
    cnn_out = BatchNormalization()(input_layer)
    cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
    cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
    cnn_out = Dropout(0.2)(cnn_out)


    # Bidirectional LSTM layer
    lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)

     # Attention layer
    attention = Attention()([lstm_out, lstm_out])
    # # Concatenate attention output with LSTM output
    merged = Concatenate(axis=-1)([lstm_out, attention])
    # Dense layer for individual branch output
    output_branch = Dense(units=n_classes, activation='softmax')(merged)


   # Print information about the branch before appending
    print(f"Branch {count} Summary:")
    branch_model = tf.keras.models.Model(inputs=input_layer, outputs=output_branch)
    branch_model.summary()
    print("\n" + "="*50 + "\n")
    # Add the branch model to the list
    branch_models.append(branch_model)
    # Add the branch to the list
    branches.append(output_branch)

# Concatenate the outputs of the 6 branches
merged_output = Concatenate(axis=-1)(branches)
# MLP layer
mlp_out = Flatten()(merged_output)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)
# Create the model
model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Branch 1 Summary:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization (Batch  (None, 400, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 398, 128)             7040      ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 199, 128)             0         ['conv1d[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 199, 128)             0         ['max_pooling1d[0][0]']
#
#  bidirectional (Bidirection  (None, 199, 128)             98816     ['dropout[0][0]']
#  al)
#
#  attention (Attention)       (None, 199, 128)             0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  concatenate (Concatenate)   (None, 199, 256)             0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  dense (Dense)               (None, 199, 9)               2313      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 2 Summary:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization_1 (Bat  (None, 400, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling1d_1 (MaxPoolin  (None, 199, 128)             0         ['conv1d_1[0][0]']
#  g1D)
#
#  dropout_1 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_1[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 199, 128)             98816     ['dropout_1[0][0]']
#  onal)
#
#  attention_1 (Attention)     (None, 199, 128)             0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 199, 256)             0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  dense_1 (Dense)             (None, 199, 9)               2313      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 3 Summary:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization_2 (Bat  (None, 400, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling1d_2 (MaxPoolin  (None, 199, 128)             0         ['conv1d_2[0][0]']
#  g1D)
#
#  dropout_2 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_2[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 199, 128)             98816     ['dropout_2[0][0]']
#  onal)
#
#  attention_2 (Attention)     (None, 199, 128)             0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 199, 256)             0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  dense_2 (Dense)             (None, 199, 9)               2313      ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 4 Summary:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization_3 (Bat  (None, 400, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling1d_3 (MaxPoolin  (None, 199, 128)             0         ['conv1d_3[0][0]']
#  g1D)
#
#  dropout_3 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_3[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 199, 128)             98816     ['dropout_3[0][0]']
#  onal)
#
#  attention_3 (Attention)     (None, 199, 128)             0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 199, 256)             0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  dense_3 (Dense)             (None, 199, 9)               2313      ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 5 Summary:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization_4 (Bat  (None, 400, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  conv1d_4 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling1d_4 (MaxPoolin  (None, 199, 128)             0         ['conv1d_4[0][0]']
#  g1D)
#
#  dropout_4 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_4[0][0]']
#
#  bidirectional_4 (Bidirecti  (None, 199, 128)             98816     ['dropout_4[0][0]']
#  onal)
#
#  attention_4 (Attention)     (None, 199, 128)             0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 199, 256)             0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  dense_4 (Dense)             (None, 199, 9)               2313      ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Branch 6 Summary:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization_5 (Bat  (None, 400, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 199, 128)             0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout_5 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_5[0][0]']
#
#  bidirectional_5 (Bidirecti  (None, 199, 128)             98816     ['dropout_5[0][0]']
#  onal)
#
#  attention_5 (Attention)     (None, 199, 128)             0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate_5 (Concatenate  (None, 199, 256)             0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense_5 (Dense)             (None, 199, 9)               2313      ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 108241 (422.82 KB)
# Trainable params: 108205 (422.68 KB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________
#
# ==================================================
#
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 400, 18)]            0         []
#
#  input_2 (InputLayer)        [(None, 400, 18)]            0         []
#
#  input_3 (InputLayer)        [(None, 400, 18)]            0         []
#
#  input_4 (InputLayer)        [(None, 400, 18)]            0         []
#
#  input_5 (InputLayer)        [(None, 400, 18)]            0         []
#
#  input_6 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization (Batch  (None, 400, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 400, 18)              72        ['input_2[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 400, 18)              72        ['input_3[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 400, 18)              72        ['input_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 400, 18)              72        ['input_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 400, 18)              72        ['input_6[0][0]']
#  chNormalization)
#
#  conv1d (Conv1D)             (None, 398, 128)             7040      ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv1d_3 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_4 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv1d_5 (Conv1D)           (None, 398, 128)             7040      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling1d (MaxPooling1  (None, 199, 128)             0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 199, 128)             0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 199, 128)             0         ['conv1d_2[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 199, 128)             0         ['conv1d_3[0][0]']
#  g1D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 199, 128)             0         ['conv1d_4[0][0]']
#  g1D)
#
#  max_pooling1d_5 (MaxPoolin  (None, 199, 128)             0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout (Dropout)           (None, 199, 128)             0         ['max_pooling1d[0][0]']
#
#  dropout_1 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 199, 128)             0         ['max_pooling1d_5[0][0]']
#
#  bidirectional (Bidirection  (None, 199, 128)             98816     ['dropout[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 199, 128)             98816     ['dropout_1[0][0]']
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 199, 128)             98816     ['dropout_2[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 199, 128)             98816     ['dropout_3[0][0]']
#  onal)
#
#  bidirectional_4 (Bidirecti  (None, 199, 128)             98816     ['dropout_4[0][0]']
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 199, 128)             98816     ['dropout_5[0][0]']
#  onal)
#
#  attention (Attention)       (None, 199, 128)             0         ['bidirectional[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  attention_1 (Attention)     (None, 199, 128)             0         ['bidirectional_1[0][0]',
#                                                                      'bidirectional_1[0][0]']
#
#  attention_2 (Attention)     (None, 199, 128)             0         ['bidirectional_2[0][0]',
#                                                                      'bidirectional_2[0][0]']
#
#  attention_3 (Attention)     (None, 199, 128)             0         ['bidirectional_3[0][0]',
#                                                                      'bidirectional_3[0][0]']
#
#  attention_4 (Attention)     (None, 199, 128)             0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  attention_5 (Attention)     (None, 199, 128)             0         ['bidirectional_5[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  concatenate (Concatenate)   (None, 199, 256)             0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  concatenate_1 (Concatenate  (None, 199, 256)             0         ['bidirectional_1[0][0]',
#  )                                                                   'attention_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 199, 256)             0         ['bidirectional_2[0][0]',
#  )                                                                   'attention_2[0][0]']
#
#  concatenate_3 (Concatenate  (None, 199, 256)             0         ['bidirectional_3[0][0]',
#  )                                                                   'attention_3[0][0]']
#
#  concatenate_4 (Concatenate  (None, 199, 256)             0         ['bidirectional_4[0][0]',
#  )                                                                   'attention_4[0][0]']
#
#  concatenate_5 (Concatenate  (None, 199, 256)             0         ['bidirectional_5[0][0]',
#  )                                                                   'attention_5[0][0]']
#
#  dense (Dense)               (None, 199, 9)               2313      ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 199, 9)               2313      ['concatenate_1[0][0]']
#
#  dense_2 (Dense)             (None, 199, 9)               2313      ['concatenate_2[0][0]']
#
#  dense_3 (Dense)             (None, 199, 9)               2313      ['concatenate_3[0][0]']
#
#  dense_4 (Dense)             (None, 199, 9)               2313      ['concatenate_4[0][0]']
#
#  dense_5 (Dense)             (None, 199, 9)               2313      ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 199, 54)              0         ['dense[0][0]',
#  )                                                                   'dense_1[0][0]',
#                                                                      'dense_2[0][0]',
#                                                                      'dense_3[0][0]',
#                                                                      'dense_4[0][0]',
#                                                                      'dense_5[0][0]']
#
#  flatten (Flatten)           (None, 10746)                0         ['concatenate_6[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  1375616   ['flatten[0][0]']
#
#  dense_7 (Dense)             (None, 64)                   8256      ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 9)                    585       ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 2033903 (7.76 MB)
# Trainable params: 2033687 (7.76 MB)
# Non-trainable params: 216 (864.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
# Generate some random data for demonstration purposes
num_samples = n_obs
sequence_length = n_timesteps
feature_dim = n_features
num_classes = n_classes

input_data = np.array(x_trains)
labels = np.array(Y_9B_train)

input_dict = {'input_1': input_data[0],
              'input_2': input_data[1],
              'input_3': input_data[2],
              'input_4': input_data[3],
              'input_5': input_data[4],
              'input_6': input_data[5]}

# Compile the model (if not compiled already)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x=input_dict, y=Y_9B_train, epochs=200, batch_size=128, validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/200
# 9/9 [==============================] - 83s 4s/step - loss: 2.1998 - accuracy: 0.1081 - val_loss: 2.1946 - val_accuracy: 0.0978
# Epoch 2/200
# 9/9 [==============================] - 28s 3s/step - loss: 2.1739 - accuracy: 0.1626 - val_loss: 2.1896 - val_accuracy: 0.2246
# Epoch 3/200
# 9/9 [==============================] - 28s 3s/step - loss: 2.1274 - accuracy: 0.2734 - val_loss: 2.1812 - val_accuracy: 0.2464
# Epoch 4/200
# 9/9 [==============================] - 28s 3s/step - loss: 2.0421 - accuracy: 0.3397 - val_loss: 2.1563 - val_accuracy: 0.2283
# Epoch 5/200
# 9/9 [==============================] - 28s 3s/step - loss: 1.9167 - accuracy: 0.3424 - val_loss: 2.1180 - val_accuracy: 0.2391
# Epoch 6/200
# 9/9 [==============================] - 28s 3s/step - loss: 1.7749 - accuracy: 0.3433 - val_loss: 2.0985 - val_accuracy: 0.1413
# Epoch 7/200
# 9/9 [==============================] - 28s 3s/step - loss: 1.6184 - accuracy: 0.3978 - val_loss: 2.0979 - val_accuracy: 0.1304
# Epoch 8/200
# 9/9 [==============================] - 28s 3s/step - loss: 1.4622 - accuracy: 0.4668 - val_loss: 2.1309 - val_accuracy: 0.1123
# Epoch 9/200
# 9/9 [==============================] - 27s 3s/step - loss: 1.3041 - accuracy: 0.5459 - val_loss: 2.1804 - val_accuracy: 0.1486
# Epoch 10/200
# Epoch 168/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0131 - accuracy: 0.9991 - val_loss: 0.2521 - val_accuracy: 0.9384
# Epoch 169/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0132 - accuracy: 0.9973 - val_loss: 0.2476 - val_accuracy: 0.9384
# Epoch 170/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0096 - accuracy: 0.9991 - val_loss: 0.2436 - val_accuracy: 0.9384
# Epoch 171/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0123 - accuracy: 0.9982 - val_loss: 0.2686 - val_accuracy: 0.9312
# Epoch 172/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9420
# Epoch 173/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0113 - accuracy: 0.9991 - val_loss: 0.2782 - val_accuracy: 0.9239
# Epoch 174/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2598 - val_accuracy: 0.9384
# Epoch 175/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.2842 - val_accuracy: 0.9312
# Epoch 176/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0145 - accuracy: 0.9964 - val_loss: 0.2562 - val_accuracy: 0.9457
# Epoch 177/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0149 - accuracy: 0.9982 - val_loss: 0.2239 - val_accuracy: 0.9420
# Epoch 178/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0108 - accuracy: 0.9982 - val_loss: 0.2306 - val_accuracy: 0.9493
# Epoch 179/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0086 - accuracy: 0.9991 - val_loss: 0.2554 - val_accuracy: 0.9384
# Epoch 180/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9384
# Epoch 181/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 0.2489 - val_accuracy: 0.9312
# Epoch 182/200
# 9/9 [==============================] - 29s 3s/step - loss: 0.0144 - accuracy: 0.9973 - val_loss: 0.2545 - val_accuracy: 0.9384
# Epoch 183/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0098 - accuracy: 0.9991 - val_loss: 0.2492 - val_accuracy: 0.9420
# Epoch 184/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.2754 - val_accuracy: 0.9312
# Epoch 185/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0099 - accuracy: 0.9982 - val_loss: 0.2762 - val_accuracy: 0.9384
# Epoch 186/200
# 9/9 [==============================] - 29s 3s/step - loss: 0.0090 - accuracy: 0.9982 - val_loss: 0.2536 - val_accuracy: 0.9493
# Epoch 187/200
# 9/9 [==============================] - 28s 3s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2624 - val_accuracy: 0.9384
# Epoch 188/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0085 - accuracy: 0.9991 - val_loss: 0.2532 - val_accuracy: 0.9384
# Epoch 189/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.2598 - val_accuracy: 0.9384
# Epoch 190/200
# 9/9 [==============================] - 27s 3s/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 0.2693 - val_accuracy: 0.9312

# %% [markdown]
# ## Model performance graphs

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Get the weights of the individual branch models
branch_weights = []

for branch_model in branch_models:
    branch_weights.append(branch_model.get_weights())

# # Print the weights for each branch
# for i, branch_weight in enumerate(branch_weights):
#     print(f"Weights for Branch {i + 1}:", branch_weight)

# %%
# Get the weights of the main model
main_model_weights = model.get_weights()

# # Print the weights for each layer
# for layer_weights in main_model_weights:
#     print(layer_weights)

# %% [markdown]
# ![Screenshot 2024-02-14 at 11.57.13.png](data:image/png;base64,...)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# input_data = np.array(x_trains)

print("Evaluate on test data")
results = model.evaluate(x_tests, y_95_test, batch_size=128)
print("test loss, test acc:", results)


# # Generate predictions (probabilities -- the output of the last layer)
# # on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(fft_x_tests, verbose=0)[:100]
# print("predictions shape:", predictions.shape)


#Predict
y_prediction = model.predict(x_tests)

#Create confusion matrix and normalizes it over predicted (columns)
y_prediction = np.argmax(y_prediction, axis=1)
print(y_prediction)
Y_9B_test_proc = np.argmax(y_95_test, axis=1)
print(Y_9B_test_proc)
result = confusion_matrix(Y_9B_test_proc, y_prediction , normalize='pred')

# Compute F1 score
f1 = f1_score(Y_9B_test_proc, y_prediction, average='weighted')

print("F1 score:", f1)
# Out:
# Evaluate on test data
# 2/2 [==============================] - 1s 584ms/step - loss: 0.1581 - accuracy: 0.9424
# test loss, test acc: [0.15807156264781952, 0.9423868060112]
# 8/8 [==============================] - 2s 236ms/step
# [5 5 6 7 5 1 3 8 4 2 5 1 3 1 7 1 1 3 6 8 1 0 3 0 5 3 3 0 6 1 7 8 5 0 5 6 8
#  2 8 1 5 3 8 1 7 5 2 8 8 7 4 5 4 7 8 2 8 1 4 7 8 5 0 0 4 4 8 1 2 6 3 5 0 4
#  2 6 1 1 5 3 5 6 8 4 2 3 4 6 1 2 0 7 6 7 6 7 1 5 6 8 6 7 4 4 8 3 1 2 4 2 8
#  4 4 4 3 2 8 8 3 2 5 0 3 2 0 3 2 6 7 8 3 2 4 2 0 3 6 1 4 8 7 6 6 0 2 3 7 1
#  6 2 0 5 1 6 4 7 5 1 6 4 5 4 4 6 4 2 1 8 1 7 7 8 3 0 7 4 2 1 7 6 1 7 8 7 8
#  8 8 1 1 6 6 4 3 0 8 4 3 2 0 7 3 5 1 4 1 0 3 7 2 8 5 7 1 1 4 8 5 2 0 1 1 6
#  3 6 7 2 8 5 8 5 0 7 2 0 6 1 4 8 1 2 5 3 4]
# [5 5 6 7 5 1 3 8 4 0 5 1 3 1 7 1 1 3 6 8 1 0 3 0 5 3 3 0 6 1 7 8 5 0 5 6 8
#  2 8 1 5 3 8 1 7 5 2 8 8 7 4 5 4 7 8 0 8 1 4 7 8 5 0 0 4 4 8 1 2 6 3 5 0 4
#  2 6 1 3 5 3 5 6 8 4 2 3 4 6 1 2 0 7 6 7 6 7 1 5 6 8 6 7 4 4 8 3 1 2 4 2 8
#  4 4 4 3 2 8 8 3 0 5 0 3 2 0 3 2 6 8 8 3 2 5 2 0 3 6 1 4 8 7 6 6 0 2 3 7 1
#  6 2 0 5 5 6 4 7 5 1 6 4 5 4 4 6 4 2 1 8 1 7 7 6 3 0 7 4 2 1 7 6 5 7 8 7 8
#  8 8 1 1 6 6 4 3 0 8 4 3 2 2 7 3 5 1 4 1 3 3 7 0 8 5 7 5 1 4 8 5 2 0 1 1 6
#  3 6 7 2 8 5 8 5 0 7 1 0 6 1 4 8 1 2 5 3 4]
# F1 score: 0.9425722620372297

# %%
# import numpy as np
# import tensorflow as tf

# def integrated_gradients(inputs, model, baseline=None, num_steps=50):
#     if baseline is None:
#         baseline = 0 * inputs

#     scaled_inputs = [baseline + (float(i) / num_steps) * (inputs - baseline) for i in range(num_steps + 1)]
#     scaled_inputs = tf.stack(scaled_inputs)

#     with tf.GradientTape() as tape:
#         tape.watch(scaled_inputs)
#         predictions = model(scaled_inputs)

#     grads = tape.gradient(predictions, scaled_inputs)
#     avg_grads = tf.reduce_mean(grads[:-1], axis=0)
#     integrated_grad = (inputs - baseline) * avg_grads
#     return integrated_grad.numpy()

# # Usage example:
# inputs = x_tests
# baseline = np.zeros_like(inputs)

# ig = integrated_gradients(inputs, model, baseline=baseline)

# %%
# import numpy as np
# import cv2
# import tensorflow as tf
# from tensorflow.keras.models import Model

# def grad_cam(model, x, layer_name):
#     cls = np.argmax(model.predict(x))
#     with tf.GradientTape() as tape:
#         last_conv_layer = model.get_layer(layer_name)
#         iterate = Model([model.inputs], [model.output, last_conv_layer.output])
#         model_out, last_conv_layer = iterate(x)
#         grads = tape.gradient(model_out[:, cls], last_conv_layer)
#         pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)
#     heatmap = np.maximum(heatmap, 0)
#     heatmap /= np.max(heatmap)
#     return heatmap

# # Usage example:
# heatmap = grad_cam(model, x_tests, layer_name='conv1d')  # Adjust layer_name to the appropriate layer in your model

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['GR', 'BNKR', 'BNKL', 'SLPD', 'SLPU', 'STD', 'STU', 'CS', 'FE'])

cm_display.plot()
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(Y_9B_test_proc, y_prediction)

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
