# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip3 install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.58.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.5.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
import os
from os import listdir
import random
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tslearn.datasets import UCR_UEA_datasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, TimeSeriesResampler, TimeSeriesScalerMinMax
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import layers, models
from keras.layers import Dense, BatchNormalization, LSTM, Flatten, TimeDistributed, Dropout, GlobalMaxPooling2D, GlobalMaxPooling1D, MaxPooling2D, MaxPooling1D, Conv2D, Conv1D, Input, Reshape, ConvLSTM2D
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load in Data

# %%
# start from the sampled dataframe
all_samples = pd.read_csv('/content/gdrive/MyDrive/Next_Step/400_step_samples_forAll.csv')

# %%
# remove all the unneccesary columns
all_samples = all_samples.drop(columns=['Unnamed: 0',' Latitude', ' SampleTimeFine' , ' Longitude',' Altitude', ' Vel_X', ' Vel_Y', ' Vel_Z'])

# %%
all_samples = all_samples.interpolate(method='linear', limit_direction='forward', axis=0)

# %%
# making sure all sensors have equal classes
all_samples["sensor_place"].value_counts()
# Out:
# sensor_place
# 93    684000
# 8B    684000
# 9B    684000
# B6    684000
# 95    684000
# CC    684000
# Name: count, dtype: int64

# %%
# remove the calibration data points and the banked R/L to evaluate model performance
# without these variables because in our data collection they wont be included
all_samples = all_samples.drop(all_samples[all_samples["trial_label"] == 'calibration'].index)

# %%
# making sure all surface types have equal classes
all_samples["trial_label"].value_counts()
# Out:
# trial_label
# GR      432000
# BNKR    432000
# BNKL    432000
# SLPD    432000
# SLPU    432000
# STD     432000
# STU     432000
# CS      432000
# FE      432000
# Name: count, dtype: int64

# %%
all_samples = all_samples.sort_values(by=['participant_num', 'trial_num', 'og_df_order'])

# %%
# seperating inputs by the sensor placement
all_samples_93 = all_samples.loc[all_samples['sensor_place'] == "93"] # right thigh

# %%
# list of all of the separated dfs
sensor_dfs = [all_samples_93]

# %%
all_sensor_metrics = []
all_sensor_non_metrics = []

for df in sensor_dfs:
    sensor_df_metrics = []
    metrics = pd.DataFrame(df, columns=[' Acc_X', ' Acc_Y',' Acc_Z', ' FreeAcc_X', ' FreeAcc_Y', ' FreeAcc_Z', ' Gyr_X', ' Gyr_Y',
                                                            ' Gyr_Z', ' Mag_X', ' Mag_Y', ' Mag_Z', ' VelInc_X', ' VelInc_Y',
                                                            ' VelInc_Z', ' Yaw', ' Pitch', ' Roll'])

    # normalize
    metrics = MinMaxScaler().fit_transform(metrics)
    # reshaping numpy array to the correct format (number of sequences, sequence length, number of features)
    numpy_metrics = metrics
    reshape_metrics = np.reshape(numpy_metrics, (1620, 400, 18))
    sensor_df_metrics.append(reshape_metrics)
    all_sensor_metrics.append(sensor_df_metrics)


    # dataframe of the non measurements
    non_metrics = df[['participant_num', 'trial_num', 'trial_label']].copy()
    # reducing the trial label column down to just 1 label per sequence
    drop_doop = non_metrics.drop_duplicates()
    # one hot encode the surface labels (outcome labels)
    label_encoder = LabelEncoder()
    integer_encoded_labels = label_encoder.fit_transform(drop_doop['trial_label'])
    one_hot_encoded_labels = to_categorical(integer_encoded_labels)
    # make encoded variable into numpy
    numpy_result = np.array(one_hot_encoded_labels)
    reshape_non_metrics = np.reshape(numpy_result, (1620, 9))
    all_sensor_non_metrics.append(reshape_non_metrics)

# %%
len(all_sensor_metrics)
# Out:
# 1

# %% [markdown]
# ## Setting up X and Y train/test

# %%
X_93 = np.array(all_sensor_metrics[0])
Y_93 = np.array(all_sensor_non_metrics[0])

index_split = list(range(1620))
# train, test = train_test_split(index_split, test_size=0.15)

X_93 = X_93.squeeze()

# %%
# check variables
n_obs, n_timesteps, n_features, n_classes = 1377, 400, 18, 9

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, Concatenate, Dense, Bidirectional

# clears the session for tensorflow
tf.keras.backend.clear_session()

# Define input shape
input_shape = (n_timesteps, n_features)
number_of_inputs = len(all_sensor_metrics)

# Define 6 parallel branches with different inputs
branch_models = []
inputs = []
branches = []
labels = []
count = 0


input_layer = Input(shape=input_shape)
inputs.append(input_layer)
# CNN layer
cnn_out = BatchNormalization()(input_layer)
cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
cnn_out = Dropout(0.2)(cnn_out)
# Bidirectional LSTM layer
lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)
# Attention layer
attention = Attention()([cnn_out, lstm_out])
# # Concatenate attention output with LSTM output
merged = Concatenate(axis=-1)([lstm_out, attention])

# MLP layer
mlp_out = Flatten()(merged)
mlp_out = Dense(units=128, activation='relu')(mlp_out)
mlp_out = Dense(units=64, activation='relu')(mlp_out)
output_layer = Dense(units=n_classes, activation='softmax')(mlp_out)
# Create the model
model = tf.keras.models.Model(inputs=inputs, outputs=output_layer)
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 400, 18)]            0         []
#
#  batch_normalization (Batch  (None, 400, 18)              72        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 398, 128)             7040      ['batch_normalization[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 199, 128)             0         ['conv1d[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 199, 128)             0         ['max_pooling1d[0][0]']
#
#  bidirectional (Bidirection  (None, 199, 128)             98816     ['dropout[0][0]']
#  al)
#
#  attention (Attention)       (None, 199, 128)             0         ['dropout[0][0]',
#                                                                      'bidirectional[0][0]']
#
#  concatenate (Concatenate)   (None, 199, 256)             0         ['bidirectional[0][0]',
#                                                                      'attention[0][0]']
#
#  flatten (Flatten)           (None, 50944)                0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 128)                  6520960   ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 9)                    585       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 6635729 (25.31 MB)
# Trainable params: 6635693 (25.31 MB)
# Non-trainable params: 36 (144.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Hyperparameter Tuning

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense, Bidirectional, Concatenate
# from tensorflow.keras.callbacks import EarlyStopping

# num_samples = n_obs
# sequence_length = n_timesteps
# feature_dim = n_features
# num_classes = n_classes

# # Split data into train-validation and test sets
# X_train_val, X_test, y_train_val, y_test = train_test_split(X_93, Y_93, test_size=0.2, random_state=42)

# # Define search space for hyperparameters
# space = {
#     'learning_rate': hp.loguniform('learning_rate', np.log(0.0001), np.log(0.001)),
#     'dropout_rate': hp.uniform('dropout_rate', 0.1, 0.5),
#     'num_units_lstm': hp.choice('num_units_lstm', [32, 64, 128]),
#     'num_filters_cnn': hp.choice('num_filters_cnn', [64, 128, 256]),
# }

# # Define objective function
# def objective(params):
#     # Define the model
#     input_shape = (sequence_length, feature_dim)
#     input_layer = Input(shape=input_shape)
#     cnn_out = BatchNormalization()(input_layer)
#     cnn_out = Conv1D(filters=params['num_filters_cnn'], kernel_size=3, activation='relu')(cnn_out)
#     cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
#     cnn_out = Dropout(params['dropout_rate'])(cnn_out)
#     cnn_out = Dense(units=params['num_units_lstm'], activation='relu')(cnn_out)  # Adjusted
#     lstm_out = Bidirectional(LSTM(units=params['num_units_lstm'], dropout=params['dropout_rate'], recurrent_dropout=params['dropout_rate'], return_sequences=True))(cnn_out)
#     attention = Attention()([lstm_out, lstm_out])  # Adjusted
#     merged = Concatenate(axis=-1)([lstm_out, attention])
#     mlp_out = Flatten()(merged)
#     mlp_out = Dense(units=128, activation='relu')(mlp_out)
#     mlp_out = Dense(units=64, activation='relu')(mlp_out)
#     output_layer = Dense(units=num_classes, activation='softmax')(mlp_out)
#     model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

#     # Compile the model
#     optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
#     model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#     # Early stopping callback
#     callback = EarlyStopping(monitor='val_loss', patience=10)

#     # Train the model
#     history = model.fit(x=X_train_val, y=y_train_val, validation_split=0.2, epochs=200, batch_size=128, callbacks=[callback])

#     # Evaluate the model on the validation set
#     loss, accuracy = model.evaluate(X_test, y_test)

#     return {'loss': -accuracy, 'status': STATUS_OK}

# # Run Hyperopt optimization
# trials = Trials()
# best = fmin(objective, space, algo=tpe.suggest, max_evals=30, trials=trials)

# print("Best Hyperparameters:", best)

# %%
# # Extract best hyperparameters and their corresponding validation accuracy
# best_params = trials.best_trial['misc']['vals']
# best_accuracy = -trials.best_trial['result']['loss']  # Note the negative sign as we minimized the negative validation accuracy

# print("Best Hyperparameters:")
# print("Learning Rate:", best_params['learning_rate'][0])
# print("Dropout Rate:", best_params['dropout_rate'][0])
# print("Number of LSTM Units:", [32, 64, 128][best_params['num_units_lstm'][0]])
# print("Number of CNN Filters:", [64, 128, 256][best_params['num_filters_cnn'][0]])
# print("Best Validation Accuracy:", best_accuracy)

# %% [markdown]
# ## Train Model

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Attention, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

num_samples = n_obs
sequence_length = n_timesteps
feature_dim = n_features
num_classes = n_classes

# Split data into train-validation and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X_93, Y_93, test_size=0.15, random_state=42)

# Initialize KFold with desired number of folds
kfold = KFold(n_splits=10, shuffle=True)

# Initialize lists to store evaluation metrics
accuracies = []
conf_matrices = []

# Perform k-fold cross-validation
for train_index, test_index in kfold.split(X_train_val):
    x_train, x_valid = X_train_val[train_index], X_train_val[test_index]
    y_train, y_valid = y_train_val[train_index], y_train_val[test_index]

    # clears the session for tensorflow
    tf.keras.backend.clear_session()

    # Define input shape
    input_shape = (sequence_length, feature_dim)

    # Define the model
    input_layer = Input(shape=input_shape)
    cnn_out = BatchNormalization()(input_layer)
    cnn_out = Conv1D(filters=128, kernel_size=3, activation='relu')(cnn_out)
    cnn_out = MaxPooling1D(pool_size=2)(cnn_out)
    cnn_out = Dropout(0.2)(cnn_out)
    lstm_out = Bidirectional(LSTM(units=64, dropout=0.4, recurrent_dropout=0.4, return_sequences=True))(cnn_out)
    attention = Attention()([lstm_out, lstm_out])
    merged = Concatenate(axis=-1)([lstm_out, attention])
    mlp_out = Flatten()(merged)
    mlp_out = Dense(units=128, activation='relu')(mlp_out)
    mlp_out = Dense(units=64, activation='relu')(mlp_out)
    output_layer = Dense(units=num_classes, activation='softmax')(mlp_out)
    model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # Early stopping callback
    callback = EarlyStopping(monitor='loss', patience=8)

    # Train the model
    history = model.fit(x=x_train, y=y_train, validation_data=(x_valid, y_valid), epochs=200, batch_size=128, callbacks=[callback])

    # Make predictions on the validation data
    fold_predictions = model.predict(x_valid)
    fold_predictions_labels = np.argmax(fold_predictions, axis=1)
    y_valids_labels = np.argmax(y_valid, axis=1)

    # Compute accuracy for this fold
    accuracy = accuracy_score(y_valids_labels, fold_predictions_labels)
    accuracies.append(accuracy)

    # Compute confusion matrix for this fold
    conf_matrix = confusion_matrix(y_valids_labels, fold_predictions_labels)
    conf_matrices.append(conf_matrix)

# Calculate average accuracy across all folds
avg_accuracy = sum(accuracies) / len(accuracies)
print("Average Validation Accuracy:", avg_accuracy)

# Print confusion matrices for each fold
for i, conf_matrix in enumerate(conf_matrices):
    print("Confusion Matrix - Fold", i+1, ":\n", conf_matrix)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 14s 599ms/step - loss: 1.8980 - accuracy: 0.3123 - val_loss: 2.4609 - val_accuracy: 0.1087
# Epoch 2/200
# 10/10 [==============================] - 6s 551ms/step - loss: 1.5050 - accuracy: 0.4471 - val_loss: 2.6006 - val_accuracy: 0.1014
# Epoch 3/200
# 10/10 [==============================] - 5s 534ms/step - loss: 1.2919 - accuracy: 0.5133 - val_loss: 2.5628 - val_accuracy: 0.1014
# Epoch 4/200
# 10/10 [==============================] - 6s 594ms/step - loss: 1.1418 - accuracy: 0.5868 - val_loss: 2.6006 - val_accuracy: 0.1087
# Epoch 5/200
# 10/10 [==============================] - 6s 550ms/step - loss: 1.0388 - accuracy: 0.6352 - val_loss: 2.4810 - val_accuracy: 0.1957
# Epoch 6/200
# 10/10 [==============================] - 5s 547ms/step - loss: 0.9327 - accuracy: 0.6933 - val_loss: 2.4572 - val_accuracy: 0.2101
# Epoch 7/200
# 10/10 [==============================] - 6s 571ms/step - loss: 0.8673 - accuracy: 0.7070 - val_loss: 2.5600 - val_accuracy: 0.1739
# Epoch 8/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.7923 - accuracy: 0.7409 - val_loss: 2.3179 - val_accuracy: 0.1884
# Epoch 9/200
# 10/10 [==============================] - 6s 571ms/step - loss: 0.7322 - accuracy: 0.7514 - val_loss: 2.3957 - val_accuracy: 0.2029
# Epoch 10/200
# 10/10 [==============================] - 6s 544ms/step - loss: 0.6790 - accuracy: 0.7748 - val_loss: 2.4621 - val_accuracy: 0.1957
# Epoch 11/200
# 10/10 [==============================] - 5s 549ms/step - loss: 0.6343 - accuracy: 0.7837 - val_loss: 2.2977 - val_accuracy: 0.2174
# Epoch 12/200
# 10/10 [==============================] - 6s 587ms/step - loss: 0.5876 - accuracy: 0.8136 - val_loss: 2.3689 - val_accuracy: 0.2101
# Epoch 13/200
# 10/10 [==============================] - 5s 547ms/step - loss: 0.5275 - accuracy: 0.8289 - val_loss: 2.2628 - val_accuracy: 0.2246
# Epoch 14/200
# 10/10 [==============================] - 6s 560ms/step - loss: 0.4756 - accuracy: 0.8636 - val_loss: 2.3126 - val_accuracy: 0.2174
# Epoch 15/200
# 10/10 [==============================] - 6s 549ms/step - loss: 0.4804 - accuracy: 0.8321 - val_loss: 2.2663 - val_accuracy: 0.2681
# Epoch 16/200
# 10/10 [==============================] - 6s 619ms/step - loss: 0.4653 - accuracy: 0.8483 - val_loss: 2.1901 - val_accuracy: 0.2464
# Epoch 17/200
# 10/10 [==============================] - 7s 657ms/step - loss: 0.4670 - accuracy: 0.8483 - val_loss: 2.0727 - val_accuracy: 0.2609
# Epoch 18/200
# 10/10 [==============================] - 6s 604ms/step - loss: 0.4048 - accuracy: 0.8749 - val_loss: 1.9905 - val_accuracy: 0.3188
# Epoch 19/200
# 10/10 [==============================] - 7s 744ms/step - loss: 0.3824 - accuracy: 0.8773 - val_loss: 2.0754 - val_accuracy: 0.2826
# Epoch 20/200
# 10/10 [==============================] - 6s 638ms/step - loss: 0.3600 - accuracy: 0.8741 - val_loss: 1.9422 - val_accuracy: 0.2899
# Epoch 21/200
# 10/10 [==============================] - 6s 551ms/step - loss: 0.3466 - accuracy: 0.8894 - val_loss: 1.9512 - val_accuracy: 0.2971
# Epoch 22/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.3275 - accuracy: 0.8967 - val_loss: 1.8526 - val_accuracy: 0.3696
# Epoch 23/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.3006 - accuracy: 0.9201 - val_loss: 1.8950 - val_accuracy: 0.3406
# Epoch 24/200
# 10/10 [==============================] - 6s 582ms/step - loss: 0.3000 - accuracy: 0.9120 - val_loss: 1.7281 - val_accuracy: 0.3913
# Epoch 25/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.2690 - accuracy: 0.9225 - val_loss: 1.8019 - val_accuracy: 0.3261
# Epoch 26/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.2861 - accuracy: 0.9096 - val_loss: 1.8109 - val_accuracy: 0.3623
# Epoch 27/200
# 10/10 [==============================] - 6s 569ms/step - loss: 0.2429 - accuracy: 0.9306 - val_loss: 1.6218 - val_accuracy: 0.3986
# Epoch 28/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.2243 - accuracy: 0.9370 - val_loss: 1.5823 - val_accuracy: 0.4275
# Epoch 29/200
# 10/10 [==============================] - 6s 563ms/step - loss: 0.2336 - accuracy: 0.9330 - val_loss: 1.4963 - val_accuracy: 0.4058
# Epoch 30/200
# 10/10 [==============================] - 6s 564ms/step - loss: 0.2160 - accuracy: 0.9427 - val_loss: 1.6726 - val_accuracy: 0.4203
# Epoch 31/200
# 10/10 [==============================] - 5s 542ms/step - loss: 0.2335 - accuracy: 0.9314 - val_loss: 1.4320 - val_accuracy: 0.4710
# Epoch 32/200
# 10/10 [==============================] - 6s 601ms/step - loss: 0.2199 - accuracy: 0.9338 - val_loss: 1.4703 - val_accuracy: 0.4710
# Epoch 33/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.2177 - accuracy: 0.9322 - val_loss: 1.4365 - val_accuracy: 0.5000
# Epoch 34/200
# 10/10 [==============================] - 6s 560ms/step - loss: 0.1971 - accuracy: 0.9419 - val_loss: 1.3391 - val_accuracy: 0.5217
# Epoch 35/200
# 10/10 [==============================] - 6s 580ms/step - loss: 0.2034 - accuracy: 0.9338 - val_loss: 1.3347 - val_accuracy: 0.5290
# Epoch 36/200
# 10/10 [==============================] - 5s 543ms/step - loss: 0.2059 - accuracy: 0.9306 - val_loss: 1.4036 - val_accuracy: 0.5507
# Epoch 37/200
# 10/10 [==============================] - 6s 609ms/step - loss: 0.1961 - accuracy: 0.9338 - val_loss: 1.3288 - val_accuracy: 0.5507
# Epoch 38/200
# 10/10 [==============================] - 5s 539ms/step - loss: 0.1670 - accuracy: 0.9580 - val_loss: 1.3508 - val_accuracy: 0.5362
# Epoch 39/200
# 10/10 [==============================] - 6s 597ms/step - loss: 0.1559 - accuracy: 0.9516 - val_loss: 1.1931 - val_accuracy: 0.5942
# Epoch 40/200
# 10/10 [==============================] - 6s 585ms/step - loss: 0.1493 - accuracy: 0.9596 - val_loss: 1.2870 - val_accuracy: 0.5580
# Epoch 41/200
# 10/10 [==============================] - 5s 537ms/step - loss: 0.1324 - accuracy: 0.9718 - val_loss: 1.1532 - val_accuracy: 0.5870
# Epoch 42/200
# 10/10 [==============================] - 6s 591ms/step - loss: 0.1335 - accuracy: 0.9750 - val_loss: 1.2121 - val_accuracy: 0.5942
# Epoch 43/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0
200
# 10/10 [==============================] - 5s 522ms/step - loss: 0.0522 - accuracy: 0.9944 - val_loss: 0.9109 - val_accuracy: 0.7464
# Epoch 70/200
# 10/10 [==============================] - 6s 584ms/step - loss: 0.0633 - accuracy: 0.9863 - val_loss: 0.8518 - val_accuracy: 0.7464
# Epoch 71/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.0572 - accuracy: 0.9863 - val_loss: 0.9511 - val_accuracy: 0.7174
# Epoch 72/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0473 - accuracy: 0.9952 - val_loss: 0.9358 - val_accuracy: 0.7464
# Epoch 73/200
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0541 - accuracy: 0.9879 - val_loss: 0.8638 - val_accuracy: 0.7681
# Epoch 74/200
# 10/10 [==============================] - 6s 599ms/step - loss: 0.0465 - accuracy: 0.9895 - val_loss: 0.9748 - val_accuracy: 0.7101
# Epoch 75/200
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0368 - accuracy: 0.9952 - val_loss: 0.9378 - val_accuracy: 0.7029
# Epoch 76/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0492 - accuracy: 0.9919 - val_loss: 0.9270 - val_accuracy: 0.6884
# Epoch 77/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0373 - accuracy: 0.9968 - val_loss: 1.0535 - val_accuracy: 0.7029
# Epoch 78/200
# 10/10 [==============================] - 6s 571ms/step - loss: 0.0509 - accuracy: 0.9871 - val_loss: 0.9443 - val_accuracy: 0.7319
# Epoch 79/200
# 10/10 [==============================] - 5s 530ms/step - loss: 0.0539 - accuracy: 0.9879 - val_loss: 0.8712 - val_accuracy: 0.7391
# Epoch 80/200
# 10/10 [==============================] - 6s 556ms/step - loss: 0.0474 - accuracy: 0.9911 - val_loss: 1.1390 - val_accuracy: 0.6957
# Epoch 81/200
# 10/10 [==============================] - 6s 548ms/step - loss: 0.0412 - accuracy: 0.9935 - val_loss: 0.9350 - val_accuracy: 0.7101
# Epoch 82/200
# 10/10 [==============================] - 5s 545ms/step - loss: 0.0389 - accuracy: 0.9935 - val_loss: 0.9930 - val_accuracy: 0.7101
# Epoch 83/200
# 10/10 [==============================] - 6s 605ms/step - loss: 0.0298 - accuracy: 0.9976 - val_loss: 0.9763 - val_accuracy: 0.7174
# Epoch 84/200
# 10/10 [==============================] - 5s 533ms/step - loss: 0.0435 - accuracy: 0.9895 - val_loss: 0.9495 - val_accuracy: 0.6884
# Epoch 85/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0497 - accuracy: 0.9855 - val_loss: 0.9623 - val_accuracy: 0.7174
# Epoch 86/200
# 10/10 [==============================] - 6s 550ms/step - loss: 0.0475 - accuracy: 0.9887 - val_loss: 1.1027 - val_accuracy: 0.7101
# Epoch 87/200
# 10/10 [==============================] - 5s 520ms/step - loss: 0.0385 - accuracy: 0.9919 - val_loss: 0.9399 - val_accuracy: 0.7319
# Epoch 88/200
# 10/10 [==============================] - 6s 561ms/step - loss: 0.0327 - accuracy: 0.9944 - val_loss: 0.9255 - val_accuracy: 0.7174
# Epoch 89/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.0262 - accuracy: 0.9968 - val_loss: 0.9631 - val_accuracy: 0.7246
# Epoch 90/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0287 - accuracy: 0.9984 - val_loss: 0.9522 - val_accuracy: 0.7246
# Epoch 91/200
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0181 - accuracy: 0.9992 - val_loss: 1.0283 - val_accuracy: 0.7246
# Epoch 92/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.0302 - accuracy: 0.9944 - val_loss: 0.9590 - val_accuracy: 0.7174
# Epoch 93/200
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0307 - accuracy: 0.9944 - val_loss: 0.9663 - val_accuracy: 0.7536
# Epoch 94/200
# 10/10 [==============================] - 6s 566ms/step - loss: 0.0254 - accuracy: 0.9960 - val_loss: 1.0377 - val_accuracy: 0.7246
# Epoch 95/200
# 10/10 [==============================] - 5s 513ms/step - loss: 0.0309 - accuracy: 0.9968 - val_loss: 1.0089 - val_accuracy: 0.7174
# Epoch 96/200
# 10/10 [==============================] - 6s 567ms/step - loss: 0.0314 - accuracy: 0.9960 - val_loss: 0.9973 - val_accuracy: 0.7174
# Epoch 97/200
# 10/10 [==============================] - 5s 519ms/step - loss: 0.0217 - accuracy: 0.9984 - val_loss: 1.0593 - val_accuracy: 0.7174
# Epoch 98/200
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0206 - accuracy: 0.9976 - val_loss: 1.0935 - val_accuracy: 0.7101
# Epoch 99/200
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0249 - accuracy: 0.9952 - val_loss: 1.0497 - val_accuracy: 0.7174
# 5/5 [==============================] - 1s 44ms/step
# Epoch 1/200
# 10/10 [==============================] - 13s 645ms/step - loss: 1.9494 - accuracy: 0.2542 - val_loss: 2.2213 - val_accuracy: 0.1739
# Epoch 2/200
# 10/10 [==============================] - 5s 518ms/step - loss: 1.5110 - accuracy: 0.4350 - val_loss: 2.3455 - val_accuracy: 0.1522
# Epoch 3/200
# 10/10 [==============================] - 5s 542ms/step - loss: 1.3049 - accuracy: 0.5157 - val_loss: 2.3825 - val_accuracy: 0.1594
# Epoch 4/200
# 10/10 [==============================] - 6s 553ms/step - loss: 1.1855 - accuracy: 0.5706 - val_loss: 2.3078 - val_accuracy: 0.1014
# Epoch 5/200
# 10/10 [==============================] - 5s 545ms/step - loss: 1.0860 - accuracy: 0.5868 - val_loss: 2.3102 - val_accuracy: 0.1739
# Epoch 6/200
# 10/10 [==============================] - 6s 614ms/step - loss: 0.9751 - accuracy: 0.6634 - val_loss: 2.3334 - val_accuracy: 0.1812
# Epoch 7/200
# 10/10 [==============================] - 5s 530ms/step - loss: 0.8849 - accuracy: 0.6852 - val_loss: 2.2545 - val_accuracy: 0.1522
# Epoch 8/200
# 10/10 [==============================] - 5s 539ms/step - loss: 0.8235 - accuracy: 0.7191 - val_loss: 2.2731 - val_accuracy: 0.1522
# Epoch 9/200
# 10/10 [==============================] - 6s 580ms/step - loss: 0.7560 - accuracy: 0.7450 - val_loss: 2.2992 - val_accuracy: 0.1522
# Epoch 10/200
# 10/10 [==============================] - 5s 529ms/step - loss: 0.7062 - accuracy: 0.7643 - val_loss: 2.3824 - val_accuracy: 0.1522
# Epoch 11/200
# 10/10 [==============================] - 6s 575ms/step - loss: 0.6576 - accuracy: 0.7797 - val_loss: 2.3578 - val_accuracy: 0.1522
# Epoch 12/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0.5992 - accuracy: 0.7829 - val_loss: 2.4510 - val_accuracy: 0.1522
# Epoch 13/200
# 10/10 [==============================] - 5s 530ms/step - loss: 0.5742 - accuracy: 0.8095 - val_loss: 2.3560 - val_accuracy: 0.1522
# Epoch 14/200
# 10/10 [==============================] - 6s 577ms/step - loss: 0.5446 - accuracy: 0.8232 - val_loss: 2.3968 - val_accuracy: 0.1594
# Epoch 15/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.5077 - accuracy: 0.8273 - val_loss: 2.2489 - val_accuracy: 0.1594
# Epoch 16/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.4697 - accuracy: 0.8467 - val_loss: 2.4648 - val_accuracy: 0.1522
# Epoch 17/200
# 10/10 [==============================] - 6s 559ms/step - loss: 0.4593 - accuracy: 0.8402 - val_loss: 2.3751 - val_accuracy: 0.1667
# Epoch 18/200
# 10/10 [==============================] - 5s 514ms/step - loss: 0.4561 - accuracy: 0.8418 - val_loss: 2.3320 - val_accuracy: 0.1739
# Epoch 19/200
# 10/10 [==============================] - 6s 559ms/step - loss: 0.4544 - accuracy: 0.8483 - val_loss: 2.2529 - val_accuracy: 0.1667
# Epoch 20/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.3929 - accuracy: 0.8604 - val_loss: 2.1004 - val_accuracy: 0.2681
# Epoch 21/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.3538 - accuracy: 0.8918 - val_loss: 2.1317 - val_accuracy: 0.2681
# Epoch 22/200
# 10/10 [==============================] - 6s 582ms/step - loss: 0.3276 - accuracy: 0.8991 - val_loss: 2.1078 - val_accuracy: 0.2681
# Epoch 23/200
# 10/10 [==============================] - 5s 530ms/step - loss: 0
200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0260 - accuracy: 0.9984 - val_loss: 0.9860 - val_accuracy: 0.7609
# Epoch 111/200
# 10/10 [==============================] - 5s 549ms/step - loss: 0.0187 - accuracy: 0.9976 - val_loss: 0.9971 - val_accuracy: 0.7754
# Epoch 112/200
# 10/10 [==============================] - 5s 546ms/step - loss: 0.0171 - accuracy: 0.9992 - val_loss: 1.0670 - val_accuracy: 0.7536
# Epoch 113/200
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0282 - accuracy: 0.9952 - val_loss: 0.9527 - val_accuracy: 0.7754
# Epoch 114/200
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0270 - accuracy: 0.9952 - val_loss: 1.0802 - val_accuracy: 0.7536
# Epoch 115/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0248 - accuracy: 0.9968 - val_loss: 1.0069 - val_accuracy: 0.7754
# Epoch 116/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0234 - accuracy: 0.9944 - val_loss: 1.1299 - val_accuracy: 0.7464
# Epoch 117/200
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0193 - accuracy: 0.9976 - val_loss: 1.0981 - val_accuracy: 0.7681
# Epoch 118/200
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0201 - accuracy: 0.9968 - val_loss: 1.0236 - val_accuracy: 0.7754
# Epoch 119/200
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0208 - accuracy: 0.9976 - val_loss: 1.1712 - val_accuracy: 0.7391
# Epoch 120/200
# 10/10 [==============================] - 6s 584ms/step - loss: 0.0264 - accuracy: 0.9976 - val_loss: 1.0970 - val_accuracy: 0.7391
# 5/5 [==============================] - 1s 42ms/step
# Epoch 1/200
# 10/10 [==============================] - 13s 599ms/step - loss: 1.8383 - accuracy: 0.3212 - val_loss: 2.1898 - val_accuracy: 0.1594
# Epoch 2/200
# 10/10 [==============================] - 6s 557ms/step - loss: 1.4418 - accuracy: 0.4818 - val_loss: 2.2723 - val_accuracy: 0.2029
# Epoch 3/200
# 10/10 [==============================] - 6s 561ms/step - loss: 1.2522 - accuracy: 0.5278 - val_loss: 2.4652 - val_accuracy: 0.1594
# Epoch 4/200
# 10/10 [==============================] - 5s 536ms/step - loss: 1.1129 - accuracy: 0.5851 - val_loss: 2.2594 - val_accuracy: 0.2029
# Epoch 5/200
# 10/10 [==============================] - 6s 608ms/step - loss: 1.0215 - accuracy: 0.6013 - val_loss: 2.2574 - val_accuracy: 0.1594
# Epoch 6/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.9510 - accuracy: 0.6513 - val_loss: 2.2711 - val_accuracy: 0.2029
# Epoch 7/200
# 10/10 [==============================] - 5s 538ms/step - loss: 0.8756 - accuracy: 0.6739 - val_loss: 2.3012 - val_accuracy: 0.2029
# Epoch 8/200
# 10/10 [==============================] - 6s 581ms/step - loss: 0.7936 - accuracy: 0.7175 - val_loss: 2.3338 - val_accuracy: 0.1739
# Epoch 9/200
# 10/10 [==============================] - 5s 548ms/step - loss: 0.7479 - accuracy: 0.7425 - val_loss: 2.3106 - val_accuracy: 0.1594
# Epoch 10/200
# 10/10 [==============================] - 6s 579ms/step - loss: 0.7447 - accuracy: 0.7320 - val_loss: 2.2740 - val_accuracy: 0.2101
# Epoch 11/200
# 10/10 [==============================] - 6s 549ms/step - loss: 0.7059 - accuracy: 0.7490 - val_loss: 2.3930 - val_accuracy: 0.2029
# Epoch 12/200
# 10/10 [==============================] - 5s 529ms/step - loss: 0.6568 - accuracy: 0.7667 - val_loss: 2.3205 - val_accuracy: 0.2029
# Epoch 13/200
# 10/10 [==============================] - 6s 578ms/step - loss: 0.5856 - accuracy: 0.8087 - val_loss: 2.1697 - val_accuracy: 0.2174
# Epoch 14/200
# 10/10 [==============================] - 5s 530ms/step - loss: 0.5794 - accuracy: 0.7966 - val_loss: 2.1182 - val_accuracy: 0.2174
# Epoch 15/200
# 10/10 [==============================] - 6s 559ms/step - loss: 0.5549 - accuracy: 0.7942 - val_loss: 2.0846 - val_accuracy: 0.2391
# Epoch 16/200
# 10/10 [==============================] - 6s 563ms/step - loss: 0.5017 - accuracy: 0.8289 - val_loss: 2.1150 - val_accuracy: 0.2246
# Epoch 17/200
# 10/10 [==============================] - 5s 523ms/step - loss: 0.4872 - accuracy: 0.8418 - val_loss: 2.1182 - val_accuracy: 0.2319
# Epoch 18/200
# 10/10 [==============================] - 6s 573ms/step - loss: 0.4392 - accuracy: 0.8644 - val_loss: 2.0808 - val_accuracy: 0.2319
# Epoch 19/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.4632 - accuracy: 0.8442 - val_loss: 1.9935 - val_accuracy: 0.2391
# Epoch 20/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0.4014 - accuracy: 0.8846 - val_loss: 2.0355 - val_accuracy: 0.2391
# Epoch 21/200
# 10/10 [==============================] - 6s 577ms/step - loss: 0.3940 - accuracy: 0.8765 - val_loss: 1.9507 - val_accuracy: 0.2754
# Epoch 22/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.3588 - accuracy: 0.8927 - val_loss: 2.0390 - val_accuracy: 0.2609
# Epoch 23/200
# 10/10 [==============================] - 6s 561ms/step - loss: 0.3657 - accuracy: 0.8838 - val_loss: 2.1221 - val_accuracy: 0.2609
# Epoch 24/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.3414 - accuracy: 0.9040 - val_loss: 1.9471 - val_accuracy: 0.2971
# Epoch 25/200
# 10/10 [==============================] - 5s 522ms/step - loss: 0.3358 - accuracy: 0.8959 - val_loss: 1.8442 - val_accuracy: 0.2899
# Epoch 26/200
# 10/10 [==============================] - 6s 571ms/step - loss: 0.3221 - accuracy: 0.8927 - val_loss: 1.8380 - val_accuracy: 0.3043
# Epoch 27/200
# 10/10 [==============================] - 5s 516ms/step - loss: 0.2893 - accuracy: 0.9209 - val_loss: 1.8622 - val_accuracy: 0.3333
# Epoch 28/200
# 10/10 [==============================] - 5s 525ms/step - loss: 0.2969 - accuracy: 0.9136 - val_loss: 1.4873 - val_accuracy: 0.3696
# Epoch 29/200
# 10/10 [==============================] - 6s 549ms/step - loss: 0.3085 - accuracy: 0.8983 - val_loss: 1.7869 - val_accuracy: 0.3406
# Epoch 30/200
# 10/10 [==============================] - 5s 515ms/step - loss: 0.2790 - accuracy: 0.9056 - val_loss: 1.8678 - val_accuracy: 0.3188
# Epoch 31/200
# 10/10 [==============================] - 5s 553ms/step - loss: 0.2711 - accuracy: 0.9209 - val_loss: 1.5018 - val_accuracy: 0.4058
# Epoch 32/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.2322 - accuracy: 0.9379 - val_loss: 1.6299 - val_accuracy: 0.3841
# Epoch 33/200
# 10/10 [==============================] - 5s 518ms/step - loss: 0.2256 - accuracy: 0.9322 - val_loss: 1.5116 - val_accuracy: 0.4275
# Epoch 34/200
# 10/10 [==============================] - 6s 576ms/step - loss: 0.2263 - accuracy: 0.9362 - val_loss: 1.5413 - val_accuracy: 0.4710
# Epoch 35/200
# 10/10 [==============================] - 5s 524ms/step - loss: 0.2162 - accuracy: 0.9451 - val_loss: 1.4010 - val_accuracy: 0.5072
# Epoch 36/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.1973 - accuracy: 0.9475 - val_loss: 1.5327 - val_accuracy: 0.4420
# Epoch 37/200
# 10/10 [==============================] - 6s 555ms/step - loss: 0.1779 - accuracy: 0.9492 - val_loss: 1.3078 - val_accuracy: 0.4783
# Epoch 38/200
# 10/10 [==============================] - 5s 519ms/step - loss: 0.1891 - accuracy: 0.9451 - val_loss: 1.4386 - val_accuracy: 0.5072
# Epoch 39/200
# 10/10 [==============================] - 6s 576ms/step - loss: 0.1913 - accuracy: 0.9483 - val_loss: 1.4105 - val_accuracy: 0.4638
# Epoch 40/200
# 10/10 [==============================] - 5s 540ms/step - loss: 0.1843 - accuracy: 0.9459 - val_loss: 1.1260 - val_accuracy: 0.5362
# Epoch 41/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.1989 - accuracy: 0.9403 - val_loss: 1.2455 - val_accuracy: 0.5652
# Epoch 42/200
# 10/10 [==============================] - 6s 567ms/step - loss: 0.1749 - accuracy: 0.9483 - val_loss: 1.2878 - val_accuracy: 0.5362
# Epoch 43/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.1836 - accuracy: 0.9427 - val_loss: 1.0363 - val_accuracy: 0.6014
# Epoch 44/200
# 10/10 [==============================] - 6s 552ms/step - loss: 0.1688 - accuracy: 0.9540 - val_loss: 0.9373 - val_accuracy: 0.5942
# Epoch 45/200
# 10/10 [==============================] - 6s 560ms/step - loss: 0.1622 - accuracy: 0.9588 - val_loss: 1.2260 - val_accuracy: 0.5652
# Epoch 46/200
# 10/10 [==============================] - 5s 523ms/step - loss: 0.1465 - accuracy: 0.9661 - val_loss: 0.9013 - val_accuracy: 0.6594
# Epoch 47/200
# 10/10 [==============================] - 6s 574ms/step - loss: 0.1372 - accuracy: 0.9685 - val_loss: 0.9582 - val_accuracy: 0.6304
# Epoch 48/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.1261 - accuracy: 0.9718 - val_loss: 0.9104 - val_accuracy: 0.6014
# Epoch 49/200
# 10/10 [==============================] - 5s 524ms/step - loss: 0.1422 - accuracy: 0.9677 - val_loss: 0.8657 - val_accuracy: 0.6812
# Epoch 50/200
# 10/10 [==============================] - 6s 567ms/step - loss: 0.1205 - accuracy: 0.9701 - val_loss: 0.8729 - val_accuracy: 0.6377
# Epoch 51/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.1241 - accuracy: 0.9709 - val_loss: 0.9586 - val_accuracy: 0.6594
# Epoch 52/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.1329 - accuracy: 0.9605 - val_loss: 0.8220 - val_accuracy: 0.6522
# Epoch 53/200
# 10/10 [==============================] - 6s 549ms/step - loss: 0.1029 - accuracy: 0.9766 - val_loss: 0.6988 - val_accuracy: 0.7246
# Epoch 54/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.0984 - accuracy: 0.9774 - val_loss: 0.7477 - val_accuracy: 0.6812
# Epoch 55/200
# 10/10 [==============================] - 6s 599ms/step - loss: 0.0961 - accuracy: 0.9798 - val_loss: 0.6792 - val_accuracy: 0.7101
# Epoch 56/200
# 10/10 [==============================] - 6s 561ms/step - loss: 0.1077 - accuracy: 0.9718 - val_loss: 0.6876 - val_accuracy: 0.7029
# Epoch 57/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0.1084 - accuracy: 0.9718 - val_loss: 0.7592 - val_accuracy: 0.7319
# Epoch 58/200
# 10/10 [==============================] - 6s 553ms/step - loss: 0.1156 - accuracy: 0.9709 - val_loss: 0.7327 - val_accuracy: 0.7319
# Epoch 59/200
# 10/10 [==============================] - 5s 524ms/step - loss: 0.1064 - accuracy: 0.9693 - val_loss: 0.6639 - val_accuracy: 0.7319
# Epoch 60/200
# 10/10 [==============================] - 6s 557ms/step - loss: 0.1052 - accuracy: 0.9693 - val_loss: 0.7006 - val_accuracy: 0.6739
# Epoch 61/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0884 - accuracy: 0.9782 - val_loss: 0.6456 - val_accuracy: 0.7319
# Epoch 62/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0813 - accuracy: 0.9814 - val_loss: 0.6509 - val_accuracy: 0.7464
# Epoch 63/200
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0826 - accuracy: 0.9847 - val_loss: 0.6299 - val_accuracy: 0.7754
# Epoch 64/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0708 - accuracy: 0.9879 - val_loss: 0.6934 - val_accuracy: 0.7246
# Epoch 65/200
# 10/10 [==============================] - 5s 545ms/step - loss: 0.0852 - accuracy: 0.9806 - val_loss: 0.6560 - val_accuracy: 0.7319
# Epoch 66/200
# 10/10 [==============================] - 6s 557ms/step - loss: 0.0710 - accuracy: 0.9855 - val_loss: 0.6900 - val_accuracy: 0.7536
# Epoch 67/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.0767 - accuracy: 0.9839 - val_loss: 0.6889 - val_accuracy: 0.7464
# Epoch 68/200
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0644 - accuracy: 0.9871 - val_loss: 0.6626 - val_accuracy: 0.7754
# Epoch 69/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0702 - accuracy: 0.9847 - val_loss: 0.7026 - val_accuracy: 0.7464
# Epoch 70/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0733 - accuracy: 0.9839 - val_loss: 0.6651 - val_accuracy: 0.7536
# Epoch 71/200
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0640 - accuracy: 0.9879 - val_loss: 0.7081 - val_accuracy: 0.7101
# Epoch 72/200
# 10/10 [==============================] - 5s 513ms/step - loss: 0.0630 - accuracy: 0.9895 - val_loss: 0.6990 - val_accuracy: 0.7391
# Epoch 73/200
# 10/10 [==============================] - 5s 542ms/step - loss: 0.0830 - accuracy: 0.9814 - val_loss: 0.7048 - val_accuracy: 0.7464
# Epoch 74/200
# 10/10 [==============================] - 6s 549ms/step - loss: 0.0623 - accuracy: 0.9887 - val_loss: 0.6943 - val_accuracy: 0.7464
# Epoch 75/200
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0573 - accuracy: 0.9895 - val_loss: 0.7387 - val_accuracy: 0.7319
# Epoch 76/200
# 10/10 [==============================] - 6s 571ms/step - loss: 0.0690 - accuracy: 0.9895 - val_loss: 0.7120 - val_accuracy: 0.7681
# Epoch 77/200
# 10/10 [==============================] - 5s 521ms/step - loss: 0.0569 - accuracy: 0.9927 - val_loss: 0.7205 - val_accuracy: 0.7174
# Epoch 78/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0487 - accuracy: 0.9944 - val_loss: 0.6984 - val_accuracy: 0.7464
# Epoch 79/200
# 10/10 [==============================] - 6s 567ms/step - loss: 0.0482 - accuracy: 0.9911 - val_loss: 0.7325 - val_accuracy: 0.7754
# Epoch 80/200
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0531 - accuracy: 0.9879 - val_loss: 0.6468 - val_accuracy: 0.7464
# Epoch 81/200
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0475 - accuracy: 0.9879 - val_loss: 0.6924 - val_accuracy: 0.7391
# Epoch 82/200
# 10/10 [==============================] - 6s 546ms/step - loss: 0.0570 - accuracy: 0.9895 - val_loss: 0.6844 - val_accuracy: 0.7609
# Epoch 83/200
# 10/10 [==============================] - 5s 520ms/step - loss: 0.0481 - accuracy: 0.9919 - val_loss: 0.7578 - val_accuracy: 0.7319
# Epoch 84/200
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0664 - accuracy: 0.9814 - val_loss: 0.6448 - val_accuracy: 0.7971
# Epoch 85/200
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0602 - accuracy: 0.9806 - val_loss: 0.7263 - val_accuracy: 0.7971
# Epoch 86/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0560 - accuracy: 0.9879 - val_loss: 0.7381 - val_accuracy: 0.7464
# Epoch 87/200
# 10/10 [==============================] - 6s 558ms/step - loss: 0.0457 - accuracy: 0.9935 - val_loss: 0.7776 - val_accuracy: 0.7536
# Epoch 88/200
# 10/10 [==============================] - 5s 520ms/step - loss: 0.0369 - accuracy: 0.9968 - val_loss: 0.7149 - val_accuracy: 0.7971
# Epoch 89/200
# 10/10 [==============================] - 6s 564ms/step - loss: 0.0344 - accuracy: 0.9944 - val_loss: 0.7493 - val_accuracy: 0.7609
# Epoch 90/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0377 - accuracy: 0.9935 - val_loss: 0.7717 - val_accuracy: 0.7464
# Epoch 91/200
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0355 - accuracy: 0.9976 - val_loss: 0.7797 - val_accuracy: 0.7536
# Epoch 92/200
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0336 - accuracy: 0.9992 - val_loss: 0.7156 - val_accuracy: 0.7536
# Epoch 93/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.0340 - accuracy: 0.9944 - val_loss: 0.6925 - val_accuracy: 0.7464
# Epoch 94/200
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0344 - accuracy: 0.9968 - val_loss: 0.7874 - val_accuracy: 0.7464
# Epoch 95/200
# 10/10 [==============================] - 6s 554ms/step - loss: 0.0375 - accuracy: 0.9919 - val_loss: 0.7620 - val_accuracy: 0.7681
# Epoch 96/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.
200
# 10/10 [==============================] - 6s 551ms/step - loss: 0.3022 - accuracy: 0.9024 - val_loss: 1.8613 - val_accuracy: 0.2847
# Epoch 30/200
# 10/10 [==============================] - 5s 525ms/step - loss: 0.2665 - accuracy: 0.9290 - val_loss: 1.6951 - val_accuracy: 0.3723
# Epoch 31/200
# 10/10 [==============================] - 6s 584ms/step - loss: 0.2590 - accuracy: 0.9242 - val_loss: 1.8203 - val_accuracy: 0.3358
# Epoch 32/200
# 10/10 [==============================] - 5s 539ms/step - loss: 0.2419 - accuracy: 0.9347 - val_loss: 1.6036 - val_accuracy: 0.4307
# Epoch 33/200
# 10/10 [==============================] - 6s 556ms/step - loss: 0.2640 - accuracy: 0.9153 - val_loss: 1.7273 - val_accuracy: 0.3723
# Epoch 34/200
# 10/10 [==============================] - 6s 561ms/step - loss: 0.2332 - accuracy: 0.9298 - val_loss: 1.6372 - val_accuracy: 0.4161
# Epoch 35/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.2332 - accuracy: 0.9177 - val_loss: 1.5909 - val_accuracy: 0.4307
# Epoch 36/200
# 10/10 [==============================] - 6s 581ms/step - loss: 0.2022 - accuracy: 0.9419 - val_loss: 1.5589 - val_accuracy: 0.4453
# Epoch 37/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.2012 - accuracy: 0.9387 - val_loss: 1.4234 - val_accuracy: 0.4745
# Epoch 38/200
# 10/10 [==============================] - 5s 540ms/step - loss: 0.1883 - accuracy: 0.9476 - val_loss: 1.4761 - val_accuracy: 0.4745
# Epoch 39/200
# 10/10 [==============================] - 6s 561ms/step - loss: 0.1862 - accuracy: 0.9500 - val_loss: 1.2747 - val_accuracy: 0.4964
# Epoch 40/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.1954 - accuracy: 0.9403 - val_loss: 1.2493 - val_accuracy: 0.5255
# Epoch 41/200
# 10/10 [==============================] - 6s 574ms/step - loss: 0.1907 - accuracy: 0.9468 - val_loss: 1.2060 - val_accuracy: 0.5620
# Epoch 42/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.1638 - accuracy: 0.9613 - val_loss: 1.2079 - val_accuracy: 0.5474
# Epoch 43/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.1520 - accuracy: 0.9629 - val_loss: 1.1775 - val_accuracy: 0.5547
# Epoch 44/200
# 10/10 [==============================] - 6s 574ms/step - loss: 0.1494 - accuracy: 0.9532 - val_loss: 1.0012 - val_accuracy: 0.6058
# Epoch 45/200
# 10/10 [==============================] - 5s 538ms/step - loss: 0.1601 - accuracy: 0.9581 - val_loss: 1.1556 - val_accuracy: 0.5620
# Epoch 46/200
# 10/10 [==============================] - 6s 558ms/step - loss: 0.1481 - accuracy: 0.9605 - val_loss: 0.9526 - val_accuracy: 0.5985
# Epoch 47/200
# 10/10 [==============================] - 6s 551ms/step - loss: 0.1455 - accuracy: 0.9637 - val_loss: 1.0020 - val_accuracy: 0.6058
# Epoch 48/200
# 10/10 [==============================] - 5s 536ms/step - loss: 0.1343 - accuracy: 0.9661 - val_loss: 1.0067 - val_accuracy: 0.6496
# Epoch 49/200
# 10/10 [==============================] - 6s 583ms/step - loss: 0.1482 - accuracy: 0.9565 - val_loss: 0.9733 - val_accuracy: 0.6350
# Epoch 50/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.1416 - accuracy: 0.9565 - val_loss: 0.9798 - val_accuracy: 0.6423
# Epoch 51/200
# 10/10 [==============================] - 5s 543ms/step - loss: 0.1211 - accuracy: 0.9718 - val_loss: 0.8406 - val_accuracy: 0.6715
# Epoch 52/200
# 10/10 [==============================] - 6s 567ms/step - loss: 0.1173 - accuracy: 0.9726 - val_loss: 0.9337 - val_accuracy: 0.6788
# Epoch 53/200
# 10/10 [==============================] - 5s 528ms/step - loss: 0.1188 - accuracy: 0.9710 - val_loss: 0.7851 - val_accuracy: 0.6861
# Epoch 54/200
# 10/10 [==============================] - 6s 578ms/step - loss: 0.1065 - accuracy: 0.9742 - val_loss: 0.7570 - val_accuracy: 0.6861
# Epoch 55/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0.0960 - accuracy: 0.9823 - val_loss: 0.7089 - val_accuracy: 0.7372
# Epoch 56/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0914 - accuracy: 0.9847 - val_loss: 0.6639 - val_accuracy: 0.7445
# Epoch 57/200
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0868 - accuracy: 0.9887 - val_loss: 0.7272 - val_accuracy: 0.7153
# Epoch 58/200
# 10/10 [==============================] - 6s 558ms/step - loss: 0.0759 - accuracy: 0.9879 - val_loss: 0.6374 - val_accuracy: 0.7445
# Epoch 59/200
# 10/10 [==============================] - 6s 563ms/step - loss: 0.0879 - accuracy: 0.9774 - val_loss: 0.7780 - val_accuracy: 0.7299
# Epoch 60/200
# 10/10 [==============================] - 5s 537ms/step - loss: 0.1018 - accuracy: 0.9742 - val_loss: 0.6088 - val_accuracy: 0.7591
# Epoch 61/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0891 - accuracy: 0.9798 - val_loss: 0.6311 - val_accuracy: 0.7445
# Epoch 62/200
# 10/10 [==============================] - 6s 582ms/step - loss: 0.0895 - accuracy: 0.9790 - val_loss: 0.6551 - val_accuracy: 0.7372
# Epoch 63/200
# 10/10 [==============================] - 5s 535ms/step - loss: 0.0909 - accuracy: 0.9766 - val_loss: 0.6749 - val_accuracy: 0.7372
# Epoch 64/200
# 10/10 [==============================] - 6s 555ms/step - loss: 0.0851 - accuracy: 0.9847 - val_loss: 0.6682 - val_accuracy: 0.7518
# Epoch 65/200
# 10/10 [==============================] - 6s 572ms/step - loss: 0.0677 - accuracy: 0.9895 - val_loss: 0.6275 - val_accuracy: 0.7810
# Epoch 66/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0623 - accuracy: 0.9935 - val_loss: 0.6370 - val_accuracy: 0.7445
# Epoch 67/200
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0647 - accuracy: 0.9879 - val_loss: 0.6395 - val_accuracy: 0.7664
# Epoch 68/200
# 10/10 [==============================] - 5s 538ms/step - loss: 0.0754 - accuracy: 0.9847 - val_loss: 0.6161 - val_accuracy: 0.7956
# Epoch 69/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0661 - accuracy: 0.9879 - val_loss: 0.6771 - val_accuracy: 0.7372
# Epoch 70/200
# 10/10 [==============================] - 6s 579ms/step - loss: 0.0711 - accuracy: 0.9863 - val_loss: 0.7149 - val_accuracy: 0.7372
# Epoch 71/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0660 - accuracy: 0.9895 - val_loss: 0.6613 - val_accuracy: 0.7591
# Epoch 72/200
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0585 - accuracy: 0.9911 - val_loss: 0.6876 - val_accuracy: 0.7591
# Epoch 73/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0525 - accuracy: 0.9927 - val_loss: 0.6368 - val_accuracy: 0.7810
# Epoch 74/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0561 - accuracy: 0.9879 - val_loss: 0.6323 - val_accuracy: 0.7445
# Epoch 75/200
# 10/10 [==============================] - 6s 604ms/step - loss: 0.0498 - accuracy: 0.9944 - val_loss: 0.6965 - val_accuracy: 0.7810
# Epoch 76/200
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0516 - accuracy: 0.9903 - val_loss: 0.6732 - val_accuracy: 0.7445
# Epoch 77/200
# 10/10 [==============================] - 6s 566ms/step - loss: 0.0493 - accuracy: 0.9960 - val_loss: 0.6772 - val_accuracy: 0.7372
# Epoch 78/200
# 10/10 [==============================] - 6s 556ms/step - loss: 0.0573 - accuracy: 0.9847 - val_loss: 0.7974 - val_accuracy: 0.7664
# Epoch 79/200
# 10/10 [==============================] - 5s 531ms/step - loss: 0.0597 - accuracy: 0.9823 - val_loss: 0.6381 - val_accuracy: 0.7664
# Epoch 80/200
# 10/10 [==============================] - 6s 584ms/step - loss: 0.0496 - accuracy: 0.9919 - val_loss: 0.7092 - val_accuracy: 0.7445
# Epoch 81/200
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0507 - accuracy: 0.9911 - val_loss: 0.6445 - val_accuracy: 0.7591
# Epoch 82/200
# 10/10 [==============================] - 6s 552ms/step - loss: 0.0450 - accuracy: 0.9911 - val_loss: 0.6542 - val_accuracy: 0.8029
# Epoch 83/200
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0522 - accuracy: 0.9879 - val_loss: 0.6441 - val_accuracy: 0.7737
# Epoch 84/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0394 - accuracy: 0.9968 - val_loss: 0.6651 - val_accuracy: 0.7737
# Epoch 85/200
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0522 - accuracy: 0.9903 - val_loss: 0.6860 - val_accuracy: 0.7810
# Epoch 86/200
# 10/10 [==============================] - 6s 546ms/step - loss: 0.0461 - accuracy: 0.9919 - val_loss: 0.7103 - val_accuracy: 0.7810
# Epoch 87/200
# 10/10 [==============================] - 5s 550ms/step - loss: 0.0532 - accuracy: 0.9855 - val_loss: 0.6707 - val_accuracy: 0.7737
# Epoch 88/200
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0488 - accuracy: 0.9879 - val_loss: 0.6757 - val_accuracy: 0.7737
# Epoch 89/200
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0397 - accuracy: 0.9944 - val_loss: 0.7439 - val_accuracy: 0.7737
# Epoch 90/200
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0436 - accuracy: 0.9903 - val_loss: 0.7584 - val_accuracy: 0.7445
# Epoch 91/200
# 10/10 [==============================] - 6s 551ms/step - loss: 0.0367 - accuracy: 0.9911 - val_loss: 0.7081 - val_accuracy: 0.7664
# Epoch 92/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0379 - accuracy: 0.9935 - val_loss: 0.6539 - val_accuracy: 0.8029
# Epoch 93/200
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0388 - accuracy: 0.9944 - val_loss: 0.8093 - val_accuracy: 0.7445
# Epoch 94/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0337 - accuracy: 0.9984 - val_loss: 0.7025 - val_accuracy: 0.7591
# Epoch 95/200
# 10/10 [==============================] - 6s 554ms/step - loss: 0.0334 - accuracy: 0.9960 - val_loss: 0.7233 - val_accuracy: 0.7956
# Epoch 96/200
# 10/10 [==============================] - 6s 557ms/step - loss: 0.0312 - accuracy: 0.9960 - val_loss: 0.7430 - val_accuracy: 0.7591
# Epoch 97/200
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0314 - accuracy: 0.9952 - val_loss: 0.7483 - val_accuracy: 0.7591
# Epoch 98/200
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0339 - accuracy: 0.9935 - val_loss: 0.7339 - val_accuracy: 0.7810
# Epoch 99/200
# 10/10 [==============================] - 5s 546ms/step - loss: 0.0285 - accuracy: 0.9968 - val_loss: 0.7740 - val_accuracy: 0.7518
# Epoch 100/200
# 10/10 [==============================] - 5s 548ms/step - loss: 0.0260 - accuracy: 0.9976 - val_loss: 0.7600 - val_accuracy: 0.7664
# Epoch 101/200
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0279 - accuracy: 0.9960 - val_loss: 0.7314 - val_accuracy: 0.7883
# Epoch 102/200
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0289 - accuracy: 0.9944 - val_loss: 0.7422 - val_accuracy: 0.7883
# Epoch 103/200
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0272 - accuracy: 0.9935 - val_loss: 0.7296 - val_accuracy: 0.8248
# Epoch 104/200
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0359 - accuracy: 0.9911 - val_loss: 0.7836 - val_accuracy: 0.7664
# Epoch 105/200
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0289 - accuracy: 0.9968 - val_loss: 0.7490 - val_accuracy: 0.7591
# Epoch 106/200
# 10/10 [==============================] - 6s 589ms/step - loss: 0.0273 - accuracy: 0.9960 - val_loss: 0.9090 - val_accuracy: 0.7153
# Epoch 107/200
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0295 - accuracy: 0.9952 - val_loss: 0.8064 - val_accuracy: 0.7810
# Epoch 108/200
# 10/10 [==============================] - 6s 559ms/step - loss: 0.0300 - accuracy: 0.9935 - val_loss: 0.7989 - val_accuracy: 0.7737
# 5/5 [==============================] - 1s 51ms/step
# Average Validation Accuracy: 0.7450809266899396
# Confusion Matrix - Fold 1 :
#  [[10  0  4  1  0  0  0  0  0]
#  [ 0 11  3  0  0  0  0  0  0]
#  [ 3  5  4  0  0  0  1  1  0]
#  [ 1  0  2 11  3  1  1  1  0]
#  [ 0  2  1  1 14  2  0  0  0]
#  [ 0  1  0  1  1  7  0  0  0]
#  [ 0  0  0  0  0  0 17  0  0]
#  [ 0  0  0  1  0  0  0 10  0]
#  [ 0  0  0  0  1  0  1  0 15]]
# Confusion Matrix - Fold 2 :
#  [[11  1  4  1  0  0  0  0  0]
#  [ 0 12  6  0  0  0  0  0  0]
#  [ 6  5  4  0  0  0  0  0  0]
#  [ 4  2  2 11  1  1  0  0  0]
#  [ 0  1  0  0  9  2  0  0  0]
#  [ 0  0  0  0  0 16  0  0  0]
#  [ 0  0  0  0  0  0 11  0  0]
#  [ 0  0  0  0  0  0  0 14  0]
#  [ 0  0  0  0  0  0  0  0 14]]
# Confusion Matrix - Fold 3 :
#  [[11  0  5  0  0  0  0  0  0]
#  [ 0 13  9  0  0  0  0  0  0]
#  [ 4  4 10  0  0  0  0  0  0]
#  [ 2  0  1  5  2  0  1  0  0]
#  [ 0  0  0  1 10  0  0  0  0]
#  [ 0  0  0  0  1  9  0  0  0]
#  [ 0  0  0  0  0  0 14  0  0]
#  [ 0  0  0  0  0  1  0 18  0]
#  [ 0  0  0  0  1  0  2  0 14]]
# Confusion Matrix - Fold 4 :
#  [[12  0  2  1  0  0  0  0  0]
#  [ 0 15  1  0  0  0  0  0  0]
#  [ 7  7  5  1  0  0  1  0  0]
#  [ 2  0  0 11  0  0  2  0  0]
#  [ 0  0  0  0  9  0  0  0  0]
#  [ 0  0  0  0  2 10  1  0  0]
#  [ 0  0  0  0  0  0 15  0  0]
#  [ 0  0  1  0  0  0  0 11  1]
#  [ 0  0  0  0  2  0  0  0 19]]
# Confusion Matrix - Fold 5 :
#  [[12  0  7  0  0  1  0  0  0]
#  [ 0  5  4  0  0  0  0  0  0]
#  [ 5  6  2  0  1  0  0  0  0]
#  [ 0  1  2  6  1  1  0  0  0]
#  [ 0  1  1  1 17  1  0  0  0]
#  [ 0  0  0  0  2 20  0  0  0]
#  [ 0  0  1  1  0  0 11  0  0]
#  [ 0  0  0  0  0  1  0 16  0]
#  [ 0  0  0  0  0  0  0  0 11]]
# Confusion Matrix - Fold 6 :
#  [[ 8  0  3  2  0  0  0  0  0]
#  [ 0  6  2  0  0  0  0  0  0]
#  [ 3  7  4  1  0  0  0  0  0]
#  [ 2  0  2 12  0  3  1  0  1]
#  [ 0  1  0  0 17  1  0  0  0]
#  [ 0  0  0  0  1 11  0  0  0]
#  [ 0  0  0  0  0  0 15  0  1]
#  [ 0  0  0  0  0  0  0 13  0]
#  [ 0  0  0  0  0  0  1  0 20]]
# Confusion Matrix - Fold 7 :
#  [[16  0  6  0  0  0  0  0  0]
#  [ 0 16  3  0  0  0  0  0  0]
#  [ 4  3  5  0  0  0  0  0  0]
#  [ 3  1  0  3  0  2  0  0  0]
#  [ 0  2  1  1 14  1  0  0  1]
#  [ 0  0  0  0  0 15  0  1  0]
#  [ 0  0  0  0  0  0 13  0  0]
#  [ 0  0  0  0  0  0  0 14  1]
#  [ 0  0  0  0  2  0  1  0  9]]
# Confusion Matrix - Fold 8 :
#  [[ 9  1  2  1  0  0  0  0  0]
#  [ 0 14  6  0  0  0  0  0  0]
#  [ 2  4  5  0  2  0  0  0  0]
#  [ 4  1  1  6  1  1  0  0  0]
#  [ 0  0  0  1 14  0  0  0  1]
#  [ 0  0  1  1  3 10  0  1  0]
#  [ 0  0  0  0  0  0 14  0  1]
#  [ 0  0  0  0  0  1  0 14  0]
#  [ 0  0  0  0  0  0  0  1 14]]
# Confusion Matrix - Fold 9 :
#  [[10  0  1  2  0  0  0  0  0]
#  [ 0 10  4  1  0  0  0  0  0]
#  [ 5  6  4  2  0  0  0  0  0]
#  [ 2  0  2  6  1  0  0  0  0]
#  [ 1  2  1  2 14  0  0  0  0]
#  [ 0  0  0  0  1 12  0  0  0]
#  [ 1  0  0  1  0  0 15  0  0]
#  [ 1  0  0  0  0  1  0 18  0]
#  [ 0  0  0  0  0  0  3  0  8]]
# Confusion Matrix - Fold 10 :
#  [[11  0  3  2  0  0  0  0  0]
#  [ 0 12  1  1  0  0  0  0  0]
#  [ 4  4  5  1  0  0  0  0  0]
#  [ 2  0  1  9  1  0  0  0  0]
#  [ 0  0  0  1  9  1  0  0  0]
#  [ 0  0  0  2  2 22  0  0  0]
#  [ 0  0  0  0  1  0 12  0  1]
#  [ 0  1  0  1  0  0  0 11  0]
#  [ 0  0  0  0  0  0  1  0 15]]
# 8/8 [==============================] - 0s 56ms/step - loss: 1.1976 - accuracy: 0.7325
# Test Loss: 1.1976392269134521
# Test Accuracy: 0.7325102686882019

# %% [markdown]
# ## Model performance graphs

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Get the weights of the individual branch models
branch_weights = []

for branch_model in branch_models:
    branch_weights.append(branch_model.get_weights())

# # Print the weights for each branch
# for i, branch_weight in enumerate(branch_weights):
#     print(f"Weights for Branch {i + 1}:", branch_weight)

# %%
# Get the weights of the main model
main_model_weights = model.get_weights()

# # Print the weights for each layer
# for layer_weights in main_model_weights:
#     print(layer_weights)

# %% [markdown]
# ![Screenshot 2024-02-14 at 11.57.13.png](data:image/png;base64,...)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# input_data = np.array(x_trains)

print("Evaluate on test data")
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test acc:", results)



# # Generate predictions (probabilities -- the output of the last layer)
# # on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(fft_x_tests, verbose=0)[:100]
# print("predictions shape:", predictions.shape)


#Predict
y_prediction = model.predict(X_test)

#Create confusion matrix and normalizes it over predicted (columns)
y_prediction = np.argmax(y_prediction, axis=1)
print(y_prediction)
Y_9B_test_proc = np.argmax(y_test, axis=1)
print(Y_9B_test_proc)
result = confusion_matrix(Y_9B_test_proc, y_prediction , normalize='pred')

# Compute F1 score
f1 = f1_score(Y_9B_test_proc, y_prediction, average='weighted')

print("F1 score:", f1)
# Out:
# Evaluate on test data
# 2/2 [==============================] - 0s 117ms/step - loss: 1.1976 - accuracy: 0.7325
# test loss, test acc: [1.1976393461227417, 0.7325102686882019]
# 8/8 [==============================] - 0s 44ms/step
# [3 1 0 5 6 5 7 3 3 3 6 6 5 4 8 3 2 1 1 7 7 6 6 1 6 2 7 4 8 3 2 1 2 2 6 8 3
#  2 6 2 8 2 6 3 4 4 6 0 5 3 6 0 6 3 2 1 2 7 1 7 8 2 1 6 0 8 7 4 0 8 7 0 8 3
#  1 6 0 8 6 7 6 2 3 4 6 2 5 6 0 4 4 7 0 6 5 6 0 2 7 6 0 8 7 4 5 5 5 4 1 3 4
#  0 3 4 3 7 6 5 0 1 0 2 4 3 7 3 5 4 3 4 0 6 7 6 6 4 8 2 6 7 6 3 1 7 2 7 2 1
#  6 2 7 2 1 2 6 7 0 5 0 2 4 5 4 6 6 0 8 7 8 2 0 5 1 0 5 7 3 0 2 1 8 5 8 5 4
#  0 3 1 1 1 1 5 8 8 1 1 1 2 7 2 1 0 6 7 3 4 3 2 1 6 0 4 2 3 2 8 7 1 2 8 3 6
#  6 6 6 6 8 7 3 0 7 7 3 7 0 7 1 8 6 3 1 7 2]
# [5 1 2 5 6 5 7 3 3 3 6 6 5 5 8 3 0 1 2 7 5 6 6 4 6 3 7 4 8 3 0 1 1 2 6 8 3
#  1 6 2 8 2 6 4 4 5 6 0 7 3 6 0 6 3 4 2 2 7 2 7 8 2 1 6 0 8 7 4 3 8 7 2 8 3
#  2 6 0 8 6 7 6 1 1 3 6 0 5 6 3 4 4 7 0 6 5 6 3 2 5 8 0 8 7 4 5 5 5 4 5 5 4
#  0 4 4 3 7 6 5 0 2 3 3 4 3 7 3 5 3 3 5 0 6 1 8 6 4 8 2 6 7 6 4 1 7 0 7 2 1
#  8 1 7 1 5 2 6 7 3 5 2 7 4 4 5 6 6 0 8 7 8 2 2 5 1 0 5 7 3 0 1 1 8 5 8 5 4
#  0 6 1 1 1 2 5 8 8 1 3 1 2 7 0 1 0 3 7 3 4 2 1 1 6 3 4 2 3 3 8 7 1 3 8 3 6
#  6 6 6 6 8 7 3 0 7 7 3 7 2 7 2 8 8 3 2 7 2]
# F1 score: 0.7350414554101773

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = result, display_labels = ['GR', 'BNKR', 'BNKL', 'SLPD', 'SLPU', 'STD', 'STU', 'CS', 'FE'])

cm_display.plot()
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(Y_9B_test_proc, y_prediction)

# %%
# 0 GR, 1 BNKR, 2 BNKL, 3 SLPD, 4 SLPU, 5 STD, 6 STU, 7 CS, 8 FE

# %%
# 0 GR, 1 SLPD, 2 SLPU, 3 STD, 4 STU, 5 CS, 6 FE
