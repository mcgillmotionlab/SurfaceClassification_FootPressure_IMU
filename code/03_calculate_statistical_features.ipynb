# %%
import pandas as pd
import numpy as np
import os
from scipy import integrate
from scipy.stats import entropy

# %%
# # all
# column_names = [
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Left_Temp', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z', 'Right_Temp', 'Right_Toes_raw',
#     'Right_Hallux_raw', 'Right_Met5_raw', 'Right_Met3_raw', 'Right_Met1_raw', 'Right_Arch_raw', 'Right_Heel_R_raw',
#     'Right_Heel_L_raw', 'Left_Toes_raw', 'Left_Hallux_raw', 'Left_Met5_raw', 'Left_Met3_raw', 'Left_Met1_raw',
#     'Left_Arch_raw', 'Left_Heel_R_raw', 'Left_Heel_L_raw', 'Right_Acc_x_raw', 'Right_Acc_y_raw', 'Right_Acc_z_raw',
#     'Right_Mag_x_raw', 'Right_Mag_y_raw', 'Right_Mag_z_raw', 'Right_Gyr_x_raw', 'Right_Gyr_y_raw', 'Right_Gyr_z_raw',
#     'Left_Acc_x_raw', 'Left_Acc_y_raw', 'Left_Acc_z_raw', 'Left_Mag_x_raw', 'Left_Mag_z_raw', 'Left_Gyr_x_raw',
#     'Left_Gyr_y_raw', 'Left_Gyr_z_raw', 'Left_Hallux_norm', 'Left_Toes_norm', 'Left_Met1_norm', 'Left_Met3_norm',
#     'Left_Met5_norm', 'Left_Arch_norm', 'Left_Heel_R_norm', 'Left_Heel_L_norm', 'Right_Hallux_norm', 'Right_Toes_norm',
#     'Right_Met1_norm', 'Right_Met3_norm', 'Right_Met5_norm', 'Right_Arch_norm', 'Right_Heel_L_norm', 'Right_Heel_R_norm',
#     'Left_Max_Pressure_norm', 'Right_Max_Pressure_norm', "orientation_Pelvis_q1","orientation_Pelvis_qi","orientation_Pelvis_qj","orientation_Pelvis_qk","orientation_L5_q1","orientation_L5_qi","orientation_L5_qj","orientation_L5_qk","orientation_L3_q1","orientation_L3_qi","orientation_L3_qj","orientation_L3_qk","orientation_T12_q1","orientation_T12_qi","orientation_T12_qj","orientation_T12_qk","orientation_T8_q1","orientation_T8_qi","orientation_T8_qj","orientation_T8_qk","orientation_Neck_q1","orientation_Neck_qi","orientation_Neck_qj","orientation_Neck_qk","orientation_Head_q1","orientation_Head_qi","orientation_Head_qj","orientation_Head_qk","orientation_RightShoulder_q1","orientation_RightShoulder_qi","orientation_RightShoulder_qj","orientation_RightShoulder_qk","orientation_RightUpperArm_q1","orientation_RightUpperArm_qi","orientation_RightUpperArm_qj","orientation_RightUpperArm_qk","orientation_RightForeArm_q1","orientation_RightForeArm_qi","orientation_RightForeArm_qj","orientation_RightForeArm_qk","orientation_RightHand_q1","orientation_RightHand_qi","orientation_RightHand_qj","orientation_RightHand_qk","orientation_LeftShoulder_q1","orientation_LeftShoulder_qi","orientation_LeftShoulder_qj","orientation_LeftShoulder_qk","orientation_LeftUpperArm_q1","orientation_LeftUpperArm_qi","orientation_LeftUpperArm_qj","orientation_LeftUpperArm_qk","orientation_LeftForeArm_q1","orientation_LeftForeArm_qi","orientation_LeftForeArm_qj","orientation_LeftForeArm_qk","orientation_LeftHand_q1","orientation_LeftHand_qi","orientation_LeftHand_qj","orientation_LeftHand_qk","orientation_RightUpperLeg_q1","orientation_RightUpperLeg_qi","orientation_RightUpperLeg_qj","orientation_RightUpperLeg_qk","orientation_RightLowerLeg_q1","orientation_RightLowerLeg_qi","orientation_RightLowerLeg_qj","orientation_RightLowerLeg_qk","orientation_RightFoot_q1","orientation_RightFoot_qi","orientation_RightFoot_qj","orientation_RightFoot_qk","orientation_RightToe_q1","orientation_RightToe_qi","orientation_RightToe_qj","orientation_RightToe_qk","orientation_LeftUpperLeg_q1","orientation_LeftUpperLeg_qi","orientation_LeftUpperLeg_qj","orientation_LeftUpperLeg_qk","orientation_LeftLowerLeg_q1","orientation_LeftLowerLeg_qi","orientation_LeftLowerLeg_qj","orientation_LeftLowerLeg_qk","orientation_LeftFoot_q1","orientation_LeftFoot_qi","orientation_LeftFoot_qj","orientation_LeftFoot_qk","orientation_LeftToe_q1","orientation_LeftToe_qi","orientation_LeftToe_qj","orientation_LeftToe_qk","position_Pelvis_x","position_Pelvis_y","position_Pelvis_z","position_L5_x","position_L5_y","position_L5_z","position_L3_x","position_L3_y","position_L3_z","position_T12_x","position_T12_y","position_T12_z","position_T8_x","position_T8_y","position_T8_z","position_Neck_x","position_Neck_y","position_Neck_z","position_Head_x","position_Head_y","position_Head_z","position_RightShoulder_x","position_RightShoulder_y","position_RightShoulder_z","position_RightUpperArm_x","position_RightUpperArm_y","position_RightUpperArm_z","position_RightForeArm_x","position_RightForeArm_y","position_RightForeArm_z","position_RightHand_x","position_RightHand_y","position_RightHand_z","position_LeftShoulder_x","position_LeftShoulder_y","position_LeftShoulder_z","position_LeftUpperArm_x","position_LeftUpperArm_y","position_LeftUpperArm_z","position_LeftForeArm_x","position_LeftForeArm_y","position_LeftForeArm_z","position_LeftHand_x","position_LeftHand_y","position_LeftHand_z","position_RightUpperLeg_x","position_RightUpperLeg_y","position_RightUpperLeg_z","position_RightLowerLeg_x","position_RightLowerLeg_y","position_RightLowerLeg_z","position_RightFoot_x","position_RightFoot_y","position_RightFoot_z","position_RightToe_x","position_RightToe_y","position_RightToe_z","position_LeftUpperLeg_x","position_LeftUpperLeg_y","position_LeftUpperLeg_z","position_LeftLowerLeg_x","position_LeftLowerLeg_y","position_LeftLowerLeg_z","position_LeftFoot_x","position_LeftFoot_y","position_LeftFoot_z","position_LeftToe_x","position_LeftToe_y","position_LeftToe_z","velocity_Pelvis_x","velocity_Pelvis_y","velocity_Pelvis_z","velocity_L5_x","velocity_L5_y","velocity_L5_z","velocity_L3_x","velocity_L3_y","velocity_L3_z","velocity_T12_x","velocity_T12_y","velocity_T12_z","velocity_T8_x","velocity_T8_y","velocity_T8_z","velocity_Neck_x","velocity_Neck_y","velocity_Neck_z","velocity_Head_x","velocity_Head_y","velocity_Head_z","velocity_RightShoulder_x","velocity_RightShoulder_y","velocity_RightShoulder_z","velocity_RightUpperArm_x","velocity_RightUpperArm_y","velocity_RightUpperArm_z","velocity_RightForeArm_x","velocity_RightForeArm_y","velocity_RightForeArm_z","velocity_RightHand_x","velocity_RightHand_y","velocity_RightHand_z","velocity_LeftShoulder_x","velocity_LeftShoulder_y","velocity_LeftShoulder_z","velocity_LeftUpperArm_x","velocity_LeftUpperArm_y","velocity_LeftUpperArm_z", "velocity_LeftForeArm_x","velocity_LeftForeArm_y","velocity_LeftForeArm_z","velocity_LeftHand_x","velocity_LeftHand_y","velocity_LeftHand_z","velocity_RightUpperLeg_x","velocity_RightUpperLeg_y","velocity_RightUpperLeg_z","velocity_RightLowerLeg_x","velocity_RightLowerLeg_y","velocity_RightLowerLeg_z","velocity_RightFoot_x","velocity_RightFoot_y","velocity_RightFoot_z","velocity_RightToe_x","velocity_RightToe_y","velocity_RightToe_z","velocity_LeftUpperLeg_x","velocity_LeftUpperLeg_y","velocity_LeftUpperLeg_z","velocity_LeftLowerLeg_x","velocity_LeftLowerLeg_y","velocity_LeftLowerLeg_z","velocity_LeftFoot_x","velocity_LeftFoot_y","velocity_LeftFoot_z","velocity_LeftToe_x","velocity_LeftToe_y","velocity_LeftToe_z","acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z","acceleration_L5_x","acceleration_L5_y","acceleration_L5_z","acceleration_L3_x","acceleration_L3_y","acceleration_L3_z","acceleration_T12_x","acceleration_T12_y","acceleration_T12_z","acceleration_T8_x","acceleration_T8_y","acceleration_T8_z","acceleration_Neck_x","acceleration_Neck_y","acceleration_Neck_z","acceleration_Head_x","acceleration_Head_y","acceleration_Head_z","acceleration_RightShoulder_x","acceleration_RightShoulder_y","acceleration_RightShoulder_z","acceleration_RightUpperArm_x","acceleration_RightUpperArm_y","acceleration_RightUpperArm_z","acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z","acceleration_RightHand_x","acceleration_RightHand_y","acceleration_RightHand_z","acceleration_LeftShoulder_x","acceleration_LeftShoulder_y","acceleration_LeftShoulder_z","acceleration_LeftUpperArm_x","acceleration_LeftUpperArm_y","acceleration_LeftUpperArm_z","acceleration_LeftForeArm_x","acceleration_LeftForeArm_y","acceleration_LeftForeArm_z","acceleration_LeftHand_x","acceleration_LeftHand_y","acceleration_LeftHand_z","acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z","acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z","acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z","acceleration_RightToe_x","acceleration_RightToe_y","acceleration_RightToe_z","acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z","acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z","acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z","acceleration_LeftToe_x","acceleration_LeftToe_y","acceleration_LeftToe_z","angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z","angularVelocity_L5_x","angularVelocity_L5_y","angularVelocity_L5_z","angularVelocity_L3_x","angularVelocity_L3_y","angularVelocity_L3_z","angularVelocity_T12_x","angularVelocity_T12_y","angularVelocity_T12_z","angularVelocity_T8_x","angularVelocity_T8_y","angularVelocity_T8_z","angularVelocity_Neck_x","angularVelocity_Neck_y","angularVelocity_Neck_z","angularVelocity_Head_x","angularVelocity_Head_y","angularVelocity_Head_z","angularVelocity_RightShoulder_x","angularVelocity_RightShoulder_y","angularVelocity_RightShoulder_z","angularVelocity_RightUpperArm_x","angularVelocity_RightUpperArm_y","angularVelocity_RightUpperArm_z","angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z","angularVelocity_RightHand_x","angularVelocity_RightHand_y","angularVelocity_RightHand_z","angularVelocity_LeftShoulder_x","angularVelocity_LeftShoulder_y","angularVelocity_LeftShoulder_z","angularVelocity_LeftUpperArm_x","angularVelocity_LeftUpperArm_y","angularVelocity_LeftUpperArm_z","angularVelocity_LeftForeArm_x","angularVelocity_LeftForeArm_y","angularVelocity_LeftForeArm_z","angularVelocity_LeftHand_x","angularVelocity_LeftHand_y","angularVelocity_LeftHand_z","angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z","angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z","angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z","angularVelocity_RightToe_x","angularVelocity_RightToe_y","angularVelocity_RightToe_z","angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z","angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z","angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z","angularVelocity_LeftToe_x","angularVelocity_LeftToe_y","angularVelocity_LeftToe_z","angularAcceleration_Pelvis_x","angularAcceleration_Pelvis_y","angularAcceleration_Pelvis_z","angularAcceleration_L5_x","angularAcceleration_L5_y","angularAcceleration_L5_z","angularAcceleration_L3_x","angularAcceleration_L3_y","angularAcceleration_L3_z","angularAcceleration_T12_x","angularAcceleration_T12_y","angularAcceleration_T12_z","angularAcceleration_T8_x","angularAcceleration_T8_y","angularAcceleration_T8_z","angularAcceleration_Neck_x","angularAcceleration_Neck_y","angularAcceleration_Neck_z","angularAcceleration_Head_x","angularAcceleration_Head_y","angularAcceleration_Head_z","angularAcceleration_RightShoulder_x","angularAcceleration_RightShoulder_y","angularAcceleration_RightShoulder_z","angularAcceleration_RightUpperArm_x","angularAcceleration_RightUpperArm_y","angularAcceleration_RightUpperArm_z","angularAcceleration_RightForeArm_x","angularAcceleration_RightForeArm_y","angularAcceleration_RightForeArm_z","angularAcceleration_RightHand_x","angularAcceleration_RightHand_y"
# , "angularAcceleration_RightHand_z","angularAcceleration_LeftShoulder_x","angularAcceleration_LeftShoulder_y","angularAcceleration_LeftShoulder_z","angularAcceleration_LeftUpperArm_x","angularAcceleration_LeftUpperArm_y","angularAcceleration_LeftUpperArm_z","angularAcceleration_LeftForeArm_x","angularAcceleration_LeftForeArm_y","angularAcceleration_LeftForeArm_z","angularAcceleration_LeftHand_x","angularAcceleration_LeftHand_y","angularAcceleration_LeftHand_z","angularAcceleration_RightUpperLeg_x","angularAcceleration_RightUpperLeg_y","angularAcceleration_RightUpperLeg_z","angularAcceleration_RightLowerLeg_x","angularAcceleration_RightLowerLeg_y","angularAcceleration_RightLowerLeg_z","angularAcceleration_RightFoot_x","angularAcceleration_RightFoot_y","angularAcceleration_RightFoot_z","angularAcceleration_RightToe_x","angularAcceleration_RightToe_y","angularAcceleration_RightToe_z","angularAcceleration_LeftUpperLeg_x","angularAcceleration_LeftUpperLeg_y","angularAcceleration_LeftUpperLeg_z","angularAcceleration_LeftLowerLeg_x","angularAcceleration_LeftLowerLeg_y","angularAcceleration_LeftLowerLeg_z","angularAcceleration_LeftFoot_x","angularAcceleration_LeftFoot_y","angularAcceleration_LeftFoot_z","angularAcceleration_LeftToe_x","angularAcceleration_LeftToe_y","angularAcceleration_LeftToe_z","sensorFreeAcceleration_Pelvis_x","sensorFreeAcceleration_Pelvis_y","sensorFreeAcceleration_Pelvis_z","sensorFreeAcceleration_T8_x","sensorFreeAcceleration_T8_y","sensorFreeAcceleration_T8_z","sensorFreeAcceleration_Head_x","sensorFreeAcceleration_Head_y","sensorFreeAcceleration_Head_z","sensorFreeAcceleration_RightShoulder_x","sensorFreeAcceleration_RightShoulder_y","sensorFreeAcceleration_RightShoulder_z","sensorFreeAcceleration_RightUpperArm_x","sensorFreeAcceleration_RightUpperArm_y","sensorFreeAcceleration_RightUpperArm_z","sensorFreeAcceleration_RightForeArm_x","sensorFreeAcceleration_RightForeArm_y","sensorFreeAcceleration_RightForeArm_z","sensorFreeAcceleration_RightHand_x","sensorFreeAcceleration_RightHand_y","sensorFreeAcceleration_RightHand_z","sensorFreeAcceleration_LeftShoulder_x","sensorFreeAcceleration_LeftShoulder_y","sensorFreeAcceleration_LeftShoulder_z","sensorFreeAcceleration_LeftUpperArm_x","sensorFreeAcceleration_LeftUpperArm_y","sensorFreeAcceleration_LeftUpperArm_z","sensorFreeAcceleration_LeftForeArm_x","sensorFreeAcceleration_LeftForeArm_y","sensorFreeAcceleration_LeftForeArm_z","sensorFreeAcceleration_LeftHand_x","sensorFreeAcceleration_LeftHand_y","sensorFreeAcceleration_LeftHand_z","sensorFreeAcceleration_RightUpperLeg_x","sensorFreeAcceleration_RightUpperLeg_y","sensorFreeAcceleration_RightUpperLeg_z","sensorFreeAcceleration_RightLowerLeg_x","sensorFreeAcceleration_RightLowerLeg_y","sensorFreeAcceleration_RightLowerLeg_z","sensorFreeAcceleration_RightFoot_x","sensorFreeAcceleration_RightFoot_y","sensorFreeAcceleration_RightFoot_z","sensorFreeAcceleration_LeftUpperLeg_x","sensorFreeAcceleration_LeftUpperLeg_y","sensorFreeAcceleration_LeftUpperLeg_z","sensorFreeAcceleration_LeftLowerLeg_x","sensorFreeAcceleration_LeftLowerLeg_y","sensorFreeAcceleration_LeftLowerLeg_z","sensorFreeAcceleration_LeftFoot_x","sensorFreeAcceleration_LeftFoot_y","sensorFreeAcceleration_LeftFoot_z","sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z","sensorMagneticField_T8_x","sensorMagneticField_T8_y","sensorMagneticField_T8_z","sensorMagneticField_Head_x","sensorMagneticField_Head_y","sensorMagneticField_Head_z","sensorMagneticField_RightShoulder_x","sensorMagneticField_RightShoulder_y","sensorMagneticField_RightShoulder_z","sensorMagneticField_RightUpperArm_x","sensorMagneticField_RightUpperArm_y","sensorMagneticField_RightUpperArm_z","sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z","sensorMagneticField_RightHand_x","sensorMagneticField_RightHand_y","sensorMagneticField_RightHand_z","sensorMagneticField_LeftShoulder_x","sensorMagneticField_LeftShoulder_y","sensorMagneticField_LeftShoulder_z","sensorMagneticField_LeftUpperArm_x","sensorMagneticField_LeftUpperArm_y","sensorMagneticField_LeftUpperArm_z","sensorMagneticField_LeftForeArm_x","sensorMagneticField_LeftForeArm_y","sensorMagneticField_LeftForeArm_z","sensorMagneticField_LeftHand_x","sensorMagneticField_LeftHand_y","sensorMagneticField_LeftHand_z","sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z","sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z","sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z","sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z","sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z","sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z","sensorOrientation_Pelvis_q1","sensorOrientation_Pelvis_qi","sensorOrientation_Pelvis_qj","sensorOrientation_Pelvis_qk","sensorOrientation_T8_q1","sensorOrientation_T8_qi","sensorOrientation_T8_qj","sensorOrientation_T8_qk","sensorOrientation_Head_q1","sensorOrientation_Head_qi","sensorOrientation_Head_qj","sensorOrientation_Head_qk","sensorOrientation_RightShoulder_q1","sensorOrientation_RightShoulder_qi","sensorOrientation_RightShoulder_qj","sensorOrientation_RightShoulder_qk","sensorOrientation_RightUpperArm_q1","sens
oot_qi","orientation_LeftFoot_qj","orientation_LeftFoot_qk","orientation_LeftToe_q1","orientation_LeftToe_qi","orientation_LeftToe_qj","orientation_LeftToe_qk","position_Pelvis_x","position_Pelvis_y","position_Pelvis_z","position_L5_x","position_L5_y","position_L5_z","position_L3_x","position_L3_y","position_L3_z","position_T12_x","position_T12_y","position_T12_z","position_T8_x","position_T8_y","position_T8_z","position_Neck_x","position_Neck_y","position_Neck_z","position_Head_x","position_Head_y","position_Head_z","position_RightShoulder_x","position_RightShoulder_y","position_RightShoulder_z","position_RightUpperArm_x","position_RightUpperArm_y","position_RightUpperArm_z","position_RightForeArm_x","position_RightForeArm_y","position_RightForeArm_z","position_RightHand_x","position_RightHand_y","position_RightHand_z","position_LeftShoulder_x","position_LeftShoulder_y","position_LeftShoulder_z","position_LeftUpperArm_x","position_LeftUpperArm_y","position_LeftUpperArm_z","position_LeftForeArm_x","position_LeftForeArm_y","position_LeftForeArm_z","position_LeftHand_x","position_LeftHand_y","position_LeftHand_z","position_RightUpperLeg_x","position_RightUpperLeg_y","position_RightUpperLeg_z","position_RightLowerLeg_x","position_RightLowerLeg_y","position_RightLowerLeg_z","position_RightFoot_x","position_RightFoot_y","position_RightFoot_z","position_RightToe_x","position_RightToe_y","position_RightToe_z","position_LeftUpperLeg_x","position_LeftUpperLeg_y","position_LeftUpperLeg_z","position_LeftLowerLeg_x","position_LeftLowerLeg_y","position_LeftLowerLeg_z","position_LeftFoot_x","position_LeftFoot_y","position_LeftFoot_z","position_LeftToe_x","position_LeftToe_y","position_LeftToe_z","velocity_Pelvis_x","velocity_Pelvis_y","velocity_Pelvis_z","velocity_L5_x","velocity_L5_y","velocity_L5_z","velocity_L3_x","velocity_L3_y","velocity_L3_z","velocity_T12_x","velocity_T12_y","velocity_T12_z","velocity_T8_x","velocity_T8_y","velocity_T8_z","velocity_Neck_x","velocity_Neck_y","velocity_Neck_z","velocity_Head_x","velocity_Head_y","velocity_Head_z","velocity_RightShoulder_x","velocity_RightShoulder_y","velocity_RightShoulder_z","velocity_RightUpperArm_x","velocity_RightUpperArm_y","velocity_RightUpperArm_z","velocity_RightForeArm_x","velocity_RightForeArm_y","velocity_RightForeArm_z","velocity_RightHand_x","velocity_RightHand_y","velocity_RightHand_z","velocity_LeftShoulder_x","velocity_LeftShoulder_y","velocity_LeftShoulder_z","velocity_LeftUpperArm_x","velocity_LeftUpperArm_y","velocity_LeftUpperArm_z", "velocity_LeftForeArm_x","velocity_LeftForeArm_y","velocity_LeftForeArm_z","velocity_LeftHand_x","velocity_LeftHand_y","velocity_LeftHand_z","velocity_RightUpperLeg_x","velocity_RightUpperLeg_y","velocity_RightUpperLeg_z","velocity_RightLowerLeg_x","velocity_RightLowerLeg_y","velocity_RightLowerLeg_z","velocity_RightFoot_x","velocity_RightFoot_y","velocity_RightFoot_z","velocity_RightToe_x","velocity_RightToe_y","velocity_RightToe_z","velocity_LeftUpperLeg_x","velocity_LeftUpperLeg_y","velocity_LeftUpperLeg_z","velocity_LeftLowerLeg_x","velocity_LeftLowerLeg_y","velocity_LeftLowerLeg_z","velocity_LeftFoot_x","velocity_LeftFoot_y","velocity_LeftFoot_z","velocity_LeftToe_x","velocity_LeftToe_y","velocity_LeftToe_z","acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_
celeration_Neck_x","angularAcceleration_Neck_y","angularAcceleration_Neck_z","angularAcceleration_Head_x","angularAcceleration_Head_y","angularAcceleration_Head_z","angularAcceleration_RightShoulder_x","angularAcceleration_RightShoulder_y","angularAcceleration_RightShoulder_z","angularAcceleration_RightUpperArm_x","angularAcceleration_RightUpperArm_y","angularAcceleration_RightUpperArm_z","angularAcceleration_RightForeArm_x","angularAcceleration_RightForeArm_y","angularAcceleration_RightForeArm_z","angularAcceleration_RightHand_x","angularAcceleration_RightHand_y"
# , "angularAcceleration_RightHand_z","angularAcceleration_LeftShoulder_x","angularAcceleration_LeftShoulder_y","angularAcceleration_LeftShoulder_z","angularAcceleration_LeftUpperArm_x","angularAcceleration_LeftUpperArm_y","angularAcceleration_LeftUpperArm_z","angularAcceleration_LeftForeArm_x","angularAcceleration_LeftForeArm_y","angularAcceleration_LeftForeArm_z","angularAcceleration_LeftHand_x","angularAcceleration_LeftHand_y","angularAcceleration_LeftHand_z","angularAcceleration_RightUpperLeg_x","angularAcceleration_RightUpperLeg_y","angularAcceleration_RightUpperLeg_z","angularAcceleration_RightLowerLeg_x","angularAcceleration_RightLowerLeg_y","angularAcceleration_RightLowerLeg_z","angularAcceleration_RightFoot_x","angularAcceleration_RightFoot_y","angularAcceleration_RightFoot_z","angularAcceleration_RightToe_x","angularAcceleration_RightToe_y","angularAcceleration_RightToe_z","angularAcceleration_LeftUpperLeg_x","angularAcceleration_LeftUpperLeg_y","angularAcceleration_LeftUpperLeg_z","angularAcceleration_LeftLowerLeg_x","angularAcceleration_LeftLowerLeg_y","angularAcceleration_LeftLowerLeg_z","angularAcceleration_LeftFoot_x","angularAcceleration_LeftFoot_y","angularAcceleration_LeftFoot_z","angularAcceleration_LeftToe_x","angularAcceleration_LeftToe_y","angularAcceleration_LeftToe_z","sensorFreeAcceleration_Pelvis_x","sensorFreeAcceleration_Pelvis_y","sensorFreeAcceleration_Pelvis_z","sensorFreeAcceleration_T8_x","sensorFreeAcceleration_T8_y","sensorFreeAcceleration_T8_z","sensorFreeAcceleration_Head_x","sensorFreeAcceleration_Head_y","sensorFreeAcceleration_Head_z","sensorFreeAcceleration_RightShoulder_x","sensorFreeAcceleration_RightShoulder_y","sensorFreeAcceleration_RightShoulder_z","sensorFreeAcceleration_RightUpperArm_x","sensorFreeAcceleration_RightUpperArm_y","sensorFreeAcceleration_RightUpperArm_z","sensorFreeAcceleration_RightForeArm_x","sensorFreeAcceleration_RightForeArm_y","sensorFreeAcceleration_RightForeArm_z","sensorFreeAcceleration_RightHand_x","sensorFreeAcceleration_RightHand_y","sensorFreeAcceleration_RightHand_z","sensorFreeAcceleration_LeftShoulder_x","sensorFreeAcceleration_LeftShoulder_y","sensorFreeAcceleration_LeftShoulder_z","sensorFreeAcceleration_LeftUpperArm_x","sensorFreeAcceleration_LeftUpperArm_y","sensorFreeAcceleration_LeftUpperArm_z","sensorFreeAcceleration_LeftForeArm_x","sensorFreeAcceleration_LeftForeArm_y","sensorFreeAcceleration_LeftForeArm_z","sensorFreeAcceleration_LeftHand_x","sensorFreeAcceleration_LeftHand_y","sensorFreeAcceleration_LeftHand_z","sensorFreeAcceleration_RightUpperLeg_x","sensorFreeAcceleration_RightUpperLeg_y","sensorFreeAcceleration_RightUpperLeg_z","sensorFreeAcceleration_RightLowerLeg_x","sensorFreeAcceleration_RightLowerLeg_y","sensorFreeAcceleration_RightLowerLeg_z","sensorFreeAcceleration_RightFoot_x","sensorFreeAcceleration_RightFoot_y","sensorFreeAcceleration_RightFoot_z","sensorFreeAcceleration_LeftUpperLeg_x","sensorFreeAcceleration_LeftUpperLeg_y","sensorFreeAcceleration_LeftUpperLeg_z","sensorFreeAcceleration_LeftLowerLeg_x","sensorFreeAcceleration_LeftLowerLeg_y","sensorFreeAcceleration_LeftLowerLeg_z","sensorFreeAcceleration_LeftFoot_x","sensorFreeAcceleration_LeftFoot_y","sensorFreeAcceleration_LeftFoot_z","sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z","sensorMagneticField_T8_x","sensorMagneticField_T8_y","sensorMagneticField_T8_z","sensorMagneticField_Head_x","sensorMagneticField_Head_y","sensorMagneticField_Head_z","sensorMagneticField_RightShoulder_x","sensorMagneticField_RightShoulder_y","sensorMagneticField_RightShoulder_z","sensorMagneticField_RightUpperArm_x","sensorMagneticField_RightUpperArm_y","sensorMagneticField_RightUpperArm_z","sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z","sensorMagneticField_RightHand_x","sensorMagneticField_RightHand_y","sensorMagneticField_RightHand_z","sensorMagneticField_LeftShoulder_x","sensorMagneticField_LeftShoulder_y","sensorMagneticField_LeftShoulder_z","sensorMagneticField_LeftUpperArm_x","sensorMagneticField_LeftUpperArm_y","sensorMagneticField_LeftUpperArm_z","sensorMagneticField_LeftForeArm_x","sensorMagneticField_LeftForeArm_y","sensorMagneticField_LeftForeArm_z","sensorMagneticField_LeftHand_x","sensorMagneticField_LeftHand_y","sensorMagneticField_LeftHand_z","sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z","sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z","sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z","sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z","sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z","sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z","sensorOrientation_Pelvis_q1","sensorOrientation_Pelvis_qi","sensorOrientation_Pelvis_qj","sensorOrientation_Pelvis_qk","sensorOrientation_T8_q1","sensorOrientation_T8_qi","sensorOrientation_T8_qj","sensorOrientation_T8_qk","sensorOrientation_Head_q1","sensorOrientation_Head_qi","sensorOrientation_Head_qj","sensorOrientation_Head_qk","sensorOrientation_RightShoulder_q1","sensorOrientation_RightShoulder_qi","sensorOrientation_RightShoulder_qj","sensorOrientation_RightShoulder_qk","sensorOrientation_RightUpperArm_q1","sensorOrientation_RightUpperArm_qi","sensorOrientation_RightUpperArm_qj","sensorOrientation_RightUpperArm_qk","sensorOrientation_RightForeArm_q1","sensorOrientation_RightForeArm_qi","sensorOrientation_RightForeArm_qj","sensorOrientation_RightForeArm_qk","sensorOrientation_RightHand_q1","sensorOrientation_RightHand_qi","sensorOrientation_RightHand_qj","sensorOrientation_RightHand_qk","sensorOrientation_LeftShoulder_q1","sensorOrientation_LeftShoulder_qi","sensorOrientation_LeftShoulder_qj","sensorOrientation_LeftShoulder_qk","sensorOrientation_LeftUpperArm_q1","sensorOrientation_LeftUpperArm_qi","sensorOrientation_LeftUpperArm_qj","sensorOrientation_LeftUpperArm_qk","sensorOrient
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Left_Temp', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z', 'Right_Temp', 'Right_Toes_raw',
#     'Right_Hallux_raw', 'Right_Met5_raw', 'Right_Met3_raw', 'Right_Met1_raw', 'Right_Arch_raw', 'Right_Heel_R_raw',
#     'Right_Heel_L_raw', 'Left_Toes_raw', 'Left_Hallux_raw', 'Left_Met5_raw', 'Left_Met3_raw', 'Left_Met1_raw',
#     'Left_Arch_raw', 'Left_Heel_R_raw', 'Left_Heel_L_raw', 'Right_Acc_x_raw', 'Right_Acc_y_raw', 'Right_Acc_z_raw',
#     'Right_Mag_x_raw', 'Right_Mag_y_raw', 'Right_Mag_z_raw', 'Right_Gyr_x_raw', 'Right_Gyr_y_raw', 'Right_Gyr_z_raw',
#     'Left_Acc_x_raw', 'Left_Acc_y_raw', 'Left_Acc_z_raw', 'Left_Mag_x_raw', 'Left_Mag_z_raw', 'Left_Gyr_x_raw',
#     'Left_Gyr_y_raw', 'Left_Gyr_z_raw', 'Left_Hallux_norm', 'Left_Toes_norm', 'Left_Met1_norm', 'Left_Met3_norm',
#     'Left_Met5_norm', 'Left_Arch_norm', 'Left_Heel_R_norm', 'Left_Heel_L_norm', 'Right_Hallux_norm', 'Right_Toes_norm',
#     'Right_Met1_norm', 'Right_Met3_norm', 'Right_Met5_norm', 'Right_Arch_norm', 'Right_Heel_L_norm', 'Right_Heel_R_norm',
#     'Left_Max_Pressure_norm', 'Right_Max_Pressure_norm', 'participant_id',  'walk_mode'
# ]

# # IMU luo
# column_names = [
# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
# "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
# "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
# "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
# "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
# "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
# "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
# "sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z",
# "sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z",
# "sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z",
# "sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z",
# 'participant_id',  'walk_mode'
# ]


# # IMU_right_forearm 
# column_names = [
# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
# 'participant_id',  'walk_mode'
# ]

# # IMU_left_forearm 
# column_names = [
# "acceleration_LeftForeArm_x","acceleration_LeftForeArm_y","acceleration_LeftForeArm_z",
# "angularVelocity_LeftForeArm_x","angularVelocity_LeftForeArm_y","angularVelocity_LeftForeArm_z",
# "sensorMagneticField_LeftForeArm_x","sensorMagneticField_LeftForeArm_y","sensorMagneticField_LeftForeArm_z",
# 'participant_id',  'walk_mode'
# ]

# # IMU_pelvis 
# column_names = [
# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# 'participant_id',  'walk_mode'
# ]

# # IMU_pelvis_right_forearm 
# column_names = [
# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# 'participant_id',  'walk_mode'
# ]


# # IMU_pelvis_right_forearm_insoles 
# column_names = [
# 'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
# 'Left_Heel_L', 'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
# 'Left_Mag_y', 'Left_Mag_z', 'Left_Temp', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
# 'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
# 'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z', 'Right_Temp', 'Right_Toes_raw',
# 'Right_Hallux_raw', 'Right_Met5_raw', 'Right_Met3_raw', 'Right_Met1_raw', 'Right_Arch_raw', 'Right_Heel_R_raw',
# 'Right_Heel_L_raw', 'Left_Toes_raw', 'Left_Hallux_raw', 'Left_Met5_raw', 'Left_Met3_raw', 'Left_Met1_raw',
# 'Left_Arch_raw', 'Left_Heel_R_raw', 'Left_Heel_L_raw', 'Right_Acc_x_raw', 'Right_Acc_y_raw', 'Right_Acc_z_raw',
# 'Right_Mag_x_raw', 'Right_Mag_y_raw', 'Right_Mag_z_raw', 'Right_Gyr_x_raw', 'Right_Gyr_y_raw', 'Right_Gyr_z_raw',
# 'Left_Acc_x_raw', 'Left_Acc_y_raw', 'Left_Acc_z_raw', 'Left_Mag_x_raw', 'Left_Mag_z_raw', 'Left_Gyr_x_raw',
# 'Left_Gyr_y_raw', 'Left_Gyr_z_raw', 'Left_Hallux_norm', 'Left_Toes_norm', 'Left_Met1_norm', 'Left_Met3_norm',
# 'Left_Met5_norm', 'Left_Arch_norm', 'Left_Heel_R_norm', 'Left_Heel_L_norm', 'Right_Hallux_norm', 'Right_Toes_norm',
# 'Right_Met1_norm', 'Right_Met3_norm', 'Right_Met5_norm', 'Right_Arch_norm', 'Right_Heel_L_norm', 'Right_Heel_R_norm',
# 'Left_Max_Pressure_norm', 'Right_Max_Pressure_norm',

# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",

# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# 'participant_id',  'walk_mode'
# ]

# # insoles imu  
# column_names = [
#     'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z', 'participant_id',  'walk_mode'
# ]

# # insoles pressure  
# column_names = [
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'participant_id',  'walk_mode'
# ]


# # insoles imu + pressure  
# column_names = [
#     'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z',
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R', 'participant_id',  'walk_mode'
# ]


# # xsens_all_locations
# column_names = [
# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "acceleration_L5_x","acceleration_L5_y","acceleration_L5_z",
# "acceleration_L3_x","acceleration_L3_y","acceleration_L3_z",
# "acceleration_T12_x","acceleration_T12_y","acceleration_T12_z",
# "acceleration_T8_x","acceleration_T8_y","acceleration_T8_z",
# "acceleration_Neck_x","acceleration_Neck_y","acceleration_Neck_z",
# "acceleration_Head_x","acceleration_Head_y","acceleration_Head_z",
# "acceleration_RightShoulder_x","acceleration_RightShoulder_y","acceleration_RightShoulder_z",
# "acceleration_RightUpperArm_x","acceleration_RightUpperArm_y","acceleration_RightUpperArm_z",
# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "acceleration_RightHand_x","acceleration_RightHand_y","acceleration_RightHand_z",
# "acceleration_LeftShoulder_x","acceleration_LeftShoulder_y","acceleration_LeftShoulder_z",
# "acceleration_LeftUpperArm_x","acceleration_LeftUpperArm_y","acceleration_LeftUpperArm_z",
# "acceleration_LeftForeArm_x","acceleration_LeftForeArm_y","acceleration_LeftForeArm_z",
# "acceleration_LeftHand_x","acceleration_LeftHand_y","acceleration_LeftHand_z",
# "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
# "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
# "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
# "acceleration_RightToe_x","acceleration_RightToe_y","acceleration_RightToe_z",
# "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
# "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
# "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",
# "acceleration_LeftToe_x","acceleration_LeftToe_y","acceleration_LeftToe_z",
# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "angularVelocity_L5_x","angularVelocity_L5_y","angularVelocity_L5_z",
# "angularVelocity_L3_x","angularVelocity_L3_y","angularVelocity_L3_z",
# "angularVelocity_T12_x","angularVelocity_T12_y","angularVelocity_T12_z",
# "angularVelocity_T8_x","angularVelocity_T8_y","angularVelocity_T8_z",
# "angularVelocity_Neck_x","angularVelocity_Neck_y","angularVelocity_Neck_z",
# "angularVelocity_Head_x","angularVelocity_Head_y","angularVelocity_Head_z",
# "angularVelocity_RightShoulder_x","angularVelocity_RightShoulder_y","angularVelocity_RightShoulder_z",
# "angularVelocity_RightUpperArm_x","angularVelocity_RightUpperArm_y","angularVelocity_RightUpperArm_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "angularVelocity_RightHand_x","angularVelocity_RightHand_y","angularVelocity_RightHand_z",
# "angularVelocity_LeftShoulder_x","angularVelocity_LeftShoulder_y","angularVelocity_LeftShoulder_z",
# "angularVelocity_LeftUpperArm_x","angularVelocity_LeftUpperArm_y","angularVelocity_LeftUpperArm_z",
# "angularVelocity_LeftForeArm_x","angularVelocity_LeftForeArm_y","angularVelocity_LeftForeArm_z",
# "angularVelocity_LeftHand_x","angularVelocity_LeftHand_y","angularVelocity_LeftHand_z",
# "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
# "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
# "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
# "angularVelocity_RightToe_x","angularVelocity_RightToe_y","angularVelocity_RightToe_z",
# "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
# "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
# "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",
# "angularVelocity_LeftToe_x","angularVelocity_LeftToe_y","angularVelocity_LeftToe_z",
# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# "sensorMagneticField_T8_x","sensorMagneticField_T8_y","sensorMagneticField_T8_z",
# "sensorMagneticField_Head_x","sensorMagneticField_Head_y","sensorMagneticField_Head_z",
# "sensorMagneticField_RightShoulder_x","sensorMagneticField_RightShoulder_y","sensorMagneticField_RightShoulder_z",
# "sensorMagneticField_RightUpperArm_x","sensorMagneticField_RightUpperArm_y","sensorMagneticField_RightUpperArm_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
# "sensorMagneticField_RightHand_x","sensorMagneticField_RightHand_y","sensorMagneticField_RightHand_z",
# "sensorMagneticField_LeftShoulder_x","sensorMagneticField_LeftShoulder_y","sensorMagneticField_LeftShoulder_z",
# "sensorMagneticField_LeftUpperArm_x","sensorMagneticField_LeftUpperArm_y","sensorMagneticField_LeftUpperArm_z",
# "sensorMagneticField_LeftForeArm_x","sensorMagneticField_LeftForeArm_y","sensorMagneticField_LeftForeArm_z",
# "sensorMagneticField_LeftHand_x","sensorMagneticField_LeftHand_y","sensorMagneticField_LeftHand_z",
# "sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z",
# "sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z",
# "sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z",
# "sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z",
# "sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z",
# "sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z",
# 'participant_id',  'walk_mode'
# ]


# # xsens_luo
# column_names = [
# "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
# "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
# "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
# "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
# "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
# "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
# "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
# "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",

# "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
# "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
# "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
# "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
# "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
# "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
# "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
# "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",

# "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
# "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
# "sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z",
# "sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z",
# "sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z",
# "sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z",
# "sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z",
# "sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z",

# 'participant_id',  'walk_mode'
# ]


# # insoles all + xsens all  
# column_names = [
#     'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z',
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R',

#     "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
#     "acceleration_L5_x","acceleration_L5_y","acceleration_L5_z",
#     "acceleration_L3_x","acceleration_L3_y","acceleration_L3_z",
#     "acceleration_T12_x","acceleration_T12_y","acceleration_T12_z",
#     "acceleration_T8_x","acceleration_T8_y","acceleration_T8_z",
#     "acceleration_Neck_x","acceleration_Neck_y","acceleration_Neck_z",
#     "acceleration_Head_x","acceleration_Head_y","acceleration_Head_z",
#     "acceleration_RightShoulder_x","acceleration_RightShoulder_y","acceleration_RightShoulder_z",
#     "acceleration_RightUpperArm_x","acceleration_RightUpperArm_y","acceleration_RightUpperArm_z",
#     "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
#     "acceleration_RightHand_x","acceleration_RightHand_y","acceleration_RightHand_z",
#     "acceleration_LeftShoulder_x","acceleration_LeftShoulder_y","acceleration_LeftShoulder_z",
#     "acceleration_LeftUpperArm_x","acceleration_LeftUpperArm_y","acceleration_LeftUpperArm_z",
#     "acceleration_LeftForeArm_x","acceleration_LeftForeArm_y","acceleration_LeftForeArm_z",
#     "acceleration_LeftHand_x","acceleration_LeftHand_y","acceleration_LeftHand_z",
#     "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
#     "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
#     "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
#     "acceleration_RightToe_x","acceleration_RightToe_y","acceleration_RightToe_z",
#     "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
#     "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
#     "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",
#     "acceleration_LeftToe_x","acceleration_LeftToe_y","acceleration_LeftToe_z",
#     "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
#     "angularVelocity_L5_x","angularVelocity_L5_y","angularVelocity_L5_z",
#     "angularVelocity_L3_x","angularVelocity_L3_y","angularVelocity_L3_z",
#     "angularVelocity_T12_x","angularVelocity_T12_y","angularVelocity_T12_z",
#     "angularVelocity_T8_x","angularVelocity_T8_y","angularVelocity_T8_z",
#     "angularVelocity_Neck_x","angularVelocity_Neck_y","angularVelocity_Neck_z",
#     "angularVelocity_Head_x","angularVelocity_Head_y","angularVelocity_Head_z",
#     "angularVelocity_RightShoulder_x","angularVelocity_RightShoulder_y","angularVelocity_RightShoulder_z",
#     "angularVelocity_RightUpperArm_x","angularVelocity_RightUpperArm_y","angularVelocity_RightUpperArm_z",
#     "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
#     "angularVelocity_RightHand_x","angularVelocity_RightHand_y","angularVelocity_RightHand_z",
#     "angularVelocity_LeftShoulder_x","angularVelocity_LeftShoulder_y","angularVelocity_LeftShoulder_z",
#     "angularVelocity_LeftUpperArm_x","angularVelocity_LeftUpperArm_y","angularVelocity_LeftUpperArm_z",
#     "angularVelocity_LeftForeArm_x","angularVelocity_LeftForeArm_y","angularVelocity_LeftForeArm_z",
#     "angularVelocity_LeftHand_x","angularVelocity_LeftHand_y","angularVelocity_LeftHand_z",
#     "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
#     "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
#     "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
#     "angularVelocity_RightToe_x","angularVelocity_RightToe_y","angularVelocity_RightToe_z",
#     "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
#     "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
#     "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",
#     "angularVelocity_LeftToe_x","angularVelocity_LeftToe_y","angularVelocity_LeftToe_z",
#     "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
#     "sensorMagneticField_T8_x","sensorMagneticField_T8_y","sensorMagneticField_T8_z",
#     "sensorMagneticField_Head_x","sensorMagneticField_Head_y","sensorMagneticField_Head_z",
#     "sensorMagneticField_RightShoulder_x","sensorMagneticField_RightShoulder_y","sensorMagneticField_RightShoulder_z",
#     "sensorMagneticField_RightUpperArm_x","sensorMagneticField_RightUpperArm_y","sensorMagneticField_RightUpperArm_z",
#     "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
#     "sensorMagneticField_RightHand_x","sensorMagneticField_RightHand_y","sensorMagneticField_RightHand_z",
#     "sensorMagneticField_LeftShoulder_x","sensorMagneticField_LeftShoulder_y","sensorMagneticField_LeftShoulder_z",
#     "sensorMagneticField_LeftUpperArm_x","sensorMagneticField_LeftUpperArm_y","sensorMagneticField_LeftUpperArm_z",
#     "sensorMagneticField_LeftForeArm_x","sensorMagneticField_LeftForeArm_y","sensorMagneticField_LeftForeArm_z",
#     "sensorMagneticField_LeftHand_x","sensorMagneticField_LeftHand_y","sensorMagneticField_LeftHand_z",
#     "sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z",
#     "sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z",
#     "sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z",
#     "sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z",
#     "sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z",
#     "sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z",
#     'participant_id',  'walk_mode'
# ]

# # insoles best + xsens best 
# column_names = [
#     'Left_Acc_x', 'Left_Acc_y', 'Left_Acc_z', 'Left_Gyr_x', 'Left_Gyr_y', 'Left_Gyr_z', 'Left_Mag_x',
#     'Left_Mag_y', 'Left_Mag_z', 'Right_Acc_x', 'Right_Acc_y', 'Right_Acc_z', 'Right_Gyr_x',
#     'Right_Gyr_y', 'Right_Gyr_z', 'Right_Mag_x', 'Right_Mag_y', 'Right_Mag_z',
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R',
    
#     "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
#     "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
#     "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
#     "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
#     "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
#     "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
#     "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
#     "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",

#     "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
#     "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
#     "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
#     "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
#     "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
#     "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
#     "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
#     "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",

#     "sensorMagneticField_Pelvis_x","sensorMagneticField_Pelvis_y","sensorMagneticField_Pelvis_z",
#     "sensorMagneticField_RightForeArm_x","sensorMagneticField_RightForeArm_y","sensorMagneticField_RightForeArm_z",
#     "sensorMagneticField_RightUpperLeg_x","sensorMagneticField_RightUpperLeg_y","sensorMagneticField_RightUpperLeg_z",
#     "sensorMagneticField_RightLowerLeg_x","sensorMagneticField_RightLowerLeg_y","sensorMagneticField_RightLowerLeg_z",
#     "sensorMagneticField_RightFoot_x","sensorMagneticField_RightFoot_y","sensorMagneticField_RightFoot_z",
#     "sensorMagneticField_LeftUpperLeg_x","sensorMagneticField_LeftUpperLeg_y","sensorMagneticField_LeftUpperLeg_z",
#     "sensorMagneticField_LeftLowerLeg_x","sensorMagneticField_LeftLowerLeg_y","sensorMagneticField_LeftLowerLeg_z",
#     "sensorMagneticField_LeftFoot_x","sensorMagneticField_LeftFoot_y","sensorMagneticField_LeftFoot_z",

#     'participant_id',  'walk_mode'

# ] 

# # insoles best + xsens best (no magnetometer, only pressure for insoles)
# column_names = [
#     'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
#     'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
#     'Right_Arch', 'Right_Heel_L', 'Right_Heel_R',
    
#     "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
#     "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
#     "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
#     "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
#     "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
#     "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
#     "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
#     "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",

#     "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
#     "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
#     "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
#     "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
#     "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
#     "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
#     "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
#     "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",

#     'participant_id',  'walk_mode', 'stepcount'

# ] 

# insoles best + xsens best (no magnetometer, only pressure for insoles) + orientation and elevation
column_names = [
    'Left_Hallux', 'Left_Toes', 'Left_Met1', 'Left_Met3', 'Left_Met5', 'Left_Arch', 'Left_Heel_R',
    'Left_Heel_L', 'Right_Hallux', 'Right_Toes', 'Right_Met1', 'Right_Met3', 'Right_Met5',
    'Right_Arch', 'Right_Heel_L', 'Right_Heel_R',
    
    "acceleration_Pelvis_x","acceleration_Pelvis_y","acceleration_Pelvis_z",
    "acceleration_RightForeArm_x","acceleration_RightForeArm_y","acceleration_RightForeArm_z",
    "acceleration_RightUpperLeg_x","acceleration_RightUpperLeg_y","acceleration_RightUpperLeg_z",
    "acceleration_RightLowerLeg_x","acceleration_RightLowerLeg_y","acceleration_RightLowerLeg_z",
    "acceleration_RightFoot_x","acceleration_RightFoot_y","acceleration_RightFoot_z",
    "acceleration_LeftUpperLeg_x","acceleration_LeftUpperLeg_y","acceleration_LeftUpperLeg_z",
    "acceleration_LeftLowerLeg_x","acceleration_LeftLowerLeg_y","acceleration_LeftLowerLeg_z",
    "acceleration_LeftFoot_x","acceleration_LeftFoot_y","acceleration_LeftFoot_z",

    "angularVelocity_Pelvis_x","angularVelocity_Pelvis_y","angularVelocity_Pelvis_z",
    "angularVelocity_RightForeArm_x","angularVelocity_RightForeArm_y","angularVelocity_RightForeArm_z",
    "angularVelocity_RightUpperLeg_x","angularVelocity_RightUpperLeg_y","angularVelocity_RightUpperLeg_z",
    "angularVelocity_RightLowerLeg_x","angularVelocity_RightLowerLeg_y","angularVelocity_RightLowerLeg_z",
    "angularVelocity_RightFoot_x","angularVelocity_RightFoot_y","angularVelocity_RightFoot_z",
    "angularVelocity_LeftUpperLeg_x","angularVelocity_LeftUpperLeg_y","angularVelocity_LeftUpperLeg_z",
    "angularVelocity_LeftLowerLeg_x","angularVelocity_LeftLowerLeg_y","angularVelocity_LeftLowerLeg_z",
    "angularVelocity_LeftFoot_x","angularVelocity_LeftFoot_y","angularVelocity_LeftFoot_z",

    # calculated from raw data
    "elevation", "orientation_x", "orientation_y", "orientation_z", "elevation_diff",


    'participant_id',  'walk_mode'
    # 'participant_id',  'walk_mode', 'stepcount'

] 

print(len(column_names))

cols_of_interest = len(column_names)-2
# cols_of_interest = len(column_names)-3
print(cols_of_interest)
# Out:
# 71
# 69

# %%
# This code uses a sliding window of 3 seconds with a step of 1.5 second (excluding the segments that have more than one class)

def calculate_statistical_features(folder_path):
    print("Working on", folder_path)
    df = pd.read_csv(os.path.join(folder_path, "merged.csv"))
    
    # Drop rows where the surface is either pavement_up or pavement_down
    df = df.loc[~df['walk_mode'].isin(['pavement_down', 'pavement_up'])]
    
    # Ensure we have the desired columns
    df = df[column_names]
    
    # Invariant columns in the dataset (not features)
    additional_columns = ['participant_id',  'walk_mode']
    
    count_any_na = df.isna().any(axis=1).sum()
    if count_any_na > 0:
        print(folder_path, "contains a NaN")
        df.fillna(0, inplace=True)
    
    # Initialize an empty DataFrame to store the final features
    final_features_df = pd.DataFrame()
    
    # Window and step sizes based on the refresh rate of 60Hz
    window_size = 2 * 60  # 3 seconds
    step_size = 1 * 60    # 1.5 seconds
    
    # Iterate through each class in the data
    unique_classes = df["walk_mode"].unique()

    for class_label in unique_classes:
        # Filter the DataFrame for the current class
        class_df = df[df["walk_mode"] == class_label].reset_index(drop=True)
        num_rows = len(class_df)

        # Apply sliding window
        for start in range(0, num_rows - window_size + 1, step_size):
            # Select the window of data
            window_df = class_df.iloc[start:start + window_size]

            # Check if the window contains only one unique class label
            if window_df["walk_mode"].nunique() > 1:
                continue  # Skip this window if more than one label is present

            # Create a dictionary to store features for this window
            window_features = {}

            try:
                for feature in df.columns:  
                    if feature not in additional_columns: # Skip non-feature columns
                        feature_values = window_df[feature]
                        window_features[feature + "_mean"] = feature_values.mean()
                        window_features[feature + "_min"] = feature_values.min()
                        window_features[feature + "_max"] = feature_values.max()
                        window_features[feature + "_std"] = feature_values.std()
                        window_features[feature + "_iqr"] = np.percentile(feature_values, 75) - np.percentile(feature_values, 25)
                        window_features[feature + "_mad"] = np.median(np.abs(feature_values - np.median(feature_values)))
                        window_features[feature + "_auc"] = integrate.simpson(feature_values)

                        # Entropy (Histogram-based method)
                        hist, bin_edges = np.histogram(feature_values, bins=10, density=True)
                        hist = hist[hist > 0]  # Remove zero entries to avoid log(0) in entropy
                        window_features[feature + "_entropy"] = entropy(hist)

                        # Frequency domain features
                        # Calculate the FFT
                        fft_values = np.fft.fft(feature_values)
                        dft_real = np.real(fft_values)
                        dft_imag = np.imag(fft_values)
                        dft_magnitude = np.abs(fft_values)

                        # Store the first five DFT coefficients
                        window_features[feature + "_dft1"] = dft_magnitude[1]  # Skip the DC component
                        window_features[feature + "_dft2"] = dft_magnitude[2]
                        window_features[feature + "_dft3"] = dft_magnitude[3]
                        window_features[feature + "_dft4"] = dft_magnitude[4]
                        window_features[feature + "_dft5"] = dft_magnitude[5]

                        # Weighted Mean Frequency Calculation
                        frequencies = np.fft.fftfreq(len(feature_values))
                        weighted_mean_frequency = np.sum(frequencies[1:6] * dft_magnitude[1:6]) / np.sum(dft_magnitude[1:6])
                        window_features[feature + "_weighted_mean_frequency"] = weighted_mean_frequency

                # Add additional columns to the window features
                for col in additional_columns:
                    window_features[col] = window_df[col].iloc[0]  # Assuming all values are the same in the window

                # Add class and window information
                window_features["walk_mode"] = class_label
                window_features["window_start"] = start
                window_features["window_end"] = start + window_size

                # Append the features to the final DataFrame
                final_features_df = pd.concat([final_features_df, pd.DataFrame([window_features])], ignore_index=True)

            except Exception as e:
                print(f"Error processing class {class_label} at window {start}-{start + window_size}: {e}")

    final_features_df.to_csv(os.path.join(folder_path, "stat_freq_features_xsens_best_insoles_best(sliding window).csv"), index=False)

# %%
# This function calculates statistical and freq features for segments of the same class

def calculate_statistical_features(folder_path):
    print("Working on", folder_path)
    df = pd.read_csv(os.path.join(folder_path, "merged.csv"))
    
    # Drop rows where the surface is either pavement_up or pavement_down
    df = df.loc[~df['walk_mode'].isin(['pavement_down', 'pavement_up'])]
    
    # Ensure we have the desired columns
    df = df[column_names]
    
    # Invariant columns in the dataset (not features)
    additional_columns = ['participant_id',  'walk_mode']
    
    count_any_na = df.isna().any(axis=1).sum()
    if count_any_na > 0:
        print(folder_path, "contains a NaN")
        df.fillna(0, inplace=True)
  
    # Initialize an empty DataFrame to store the final features
    final_features_df = pd.DataFrame()

    # Initialize variables to track the current segment
    current_class = None
    segment_rows = []

    def calculate_segment_features(segment_rows, class_label):
        segment_df = pd.DataFrame(segment_rows)
        segment_features = {}
        
        for feature in df.columns:
            if feature not in additional_columns:
                feature_values = segment_df[feature]
                segment_features[feature + "_mean"] = feature_values.mean()
                segment_features[feature + "_min"] = feature_values.min()
                segment_features[feature + "_max"] = feature_values.max()
                segment_features[feature + "_std"] = feature_values.std()
                segment_features[feature + "_iqr"] = np.percentile(feature_values, 75) - np.percentile(feature_values, 25)
                segment_features[feature + "_mad"] = np.median(np.abs(feature_values - np.median(feature_values)))
                segment_features[feature + "_auc"] = integrate.simpson(feature_values)

                # Entropy (Histogram-based method)
                hist, bin_edges = np.histogram(feature_values, bins=10, density=True)
                hist = hist[hist > 0]  # Remove zero entries to avoid log(0) in entropy
                segment_features[feature + "_entropy"] = entropy(hist)

                # Frequency domain features
                # Calculate the FFT
                fft_values = np.fft.fft(feature_values)
                dft_real = np.real(fft_values)
                dft_imag = np.imag(fft_values)
                dft_magnitude = np.abs(fft_values)

                # Store the first five DFT coefficients
                segment_features[feature + "_dft1"] = dft_magnitude[1]  # Skip the DC component
                segment_features[feature + "_dft2"] = dft_magnitude[2]
                segment_features[feature + "_dft3"] = dft_magnitude[3]
                segment_features[feature + "_dft4"] = dft_magnitude[4]
                segment_features[feature + "_dft5"] = dft_magnitude[5]

                # Weighted Mean Frequency Calculation
                frequencies = np.fft.fftfreq(len(feature_values))
                weighted_mean_frequency = np.sum(frequencies[1:6] * dft_magnitude[1:6]) / np.sum(dft_magnitude[1:6])
                segment_features[feature + "_weighted_mean_frequency"] = weighted_mean_frequency
        
        for col in additional_columns:
            segment_features[col] = segment_df[col].iloc[0]

        segment_features["walk_mode"] = class_label
        return segment_features

    for index, row in df.iterrows():
        if current_class is None:
            current_class = row["walk_mode"]
        
        if row["walk_mode"] == current_class:
            segment_rows.append(row)
        else: # This runs when encountering a different class
            final_features_df = pd.concat(
                [final_features_df, pd.DataFrame([calculate_segment_features(segment_rows, current_class)])], ignore_index=True
            )
            current_class = row["walk_mode"]
            segment_rows = [row]
    
    if segment_rows:
        final_features_df = pd.concat(
            [final_features_df, pd.DataFrame([calculate_segment_features(segment_rows, current_class)])], ignore_index=True
        )

    final_features_df.to_csv(os.path.join(folder_path, "statistical_features_xsens_best_insoles_best_no_magnetometer.csv"), index=False)

# %%
# statistical and frequency based features using a segmentation by stepcount

def calculate_statistical_features(folder_path):
    print("Working on", folder_path)
    df = pd.read_csv(os.path.join(folder_path, "merged_gait_count_annotations.csv"))
    
    # Drop rows where the surface is either pavement_up or pavement_down
    df = df.loc[~df['walk_mode'].isin(['pavement_down', 'pavement_up'])]
    
    # Ensure we have the desired columns
    df = df[column_names]
    
    # Invariant columns in the dataset (not features)
    additional_columns = ['participant_id',  'walk_mode', 'stepcount']
    
    count_any_na = df.isna().any(axis=1).sum()
    if count_any_na > 0:
        print(folder_path, "contains a NaN")
        df.fillna(0, inplace=True)

    # Initialize an empty DataFrame to store the final features
    final_features_df = pd.DataFrame()

    # Group by 'stepcount' and process each group
    for stepcount, group in df.groupby('stepcount'):
        unique_walk_modes = group['walk_mode'].unique()

        # If there is more than one unique 'walk_mode' in the batch, skip the batch
        if len(unique_walk_modes) > 1:
            # print(f"Skipping batch with stepcount {stepcount} due to multiple walk_modes.")
            continue

        # Extract the walk mode (since it's consistent in the batch)
        current_class = unique_walk_modes[0]

        # Initialize a dictionary to store features for this batch
        segment_features = {}

        # Calculate statistical features for each column except 'additional_columns'
        try:
            for feature in df.columns:
                if feature not in additional_columns:  # Skip non-feature columns
                    feature_values = group[feature]
                    # Statistical features
                    segment_features[feature + "_mean"] = feature_values.mean()
                    segment_features[feature + "_min"] = feature_values.min()
                    segment_features[feature + "_max"] = feature_values.max()
                    segment_features[feature + "_std"] = feature_values.std()
                    segment_features[feature + "_iqr"] = np.percentile(feature_values, 75) - np.percentile(feature_values, 25)
                    segment_features[feature + "_mad"] = np.median(np.abs(feature_values - np.median(feature_values)))
                    segment_features[feature + "_auc"] = integrate.simpson(feature_values)

                    # Entropy (Histogram-based method)
                    hist, bin_edges = np.histogram(feature_values, bins=10, density=True)
                    hist = hist[hist > 0]  # Remove zero entries to avoid log(0) in entropy
                    segment_features[feature + "_entropy"] = entropy(hist)

                    # Frequency domain features
                    # Calculate the FFT
                    fft_values = np.fft.fft(feature_values)
                    dft_real = np.real(fft_values)
                    dft_imag = np.imag(fft_values)
                    dft_magnitude = np.abs(fft_values)

                    # Store the first five DFT coefficients
                    segment_features[feature + "_dft1"] = dft_magnitude[1]  # Skip the DC component
                    segment_features[feature + "_dft2"] = dft_magnitude[2]
                    segment_features[feature + "_dft3"] = dft_magnitude[3]
                    segment_features[feature + "_dft4"] = dft_magnitude[4]
                    segment_features[feature + "_dft5"] = dft_magnitude[5]

                    # Weighted Mean Frequency Calculation
                    frequencies = np.fft.fftfreq(len(feature_values))
                    weighted_mean_frequency = np.sum(frequencies[1:6] * dft_magnitude[1:6]) / np.sum(dft_magnitude[1:6])
                    segment_features[feature + "_weighted_mean_frequency"] = weighted_mean_frequency

            # Add the additional columns (constant per group)
            for col in additional_columns:
                segment_features[col] = group[col].iloc[0]  # Assuming same value for the whole group

            # Add the class label (walk_mode)
            segment_features["walk_mode"] = current_class

            # Append the features of the batch to the final DataFrame
            final_features_df = pd.concat([final_features_df, pd.DataFrame([segment_features])], ignore_index=True)

        except Exception as e:
            print(f"Error processing batch with stepcount {stepcount}: {e}")

    final_features_df.to_csv(os.path.join(folder_path, "stat_freq_features_xsens_best_insoles_best(annotation_based_gait_detection).csv"), index=False)

# %%
dataset_path = "data_set"

print("Calculating statistical features...")
# Iterate through the directory structure
for course_folder in os.listdir(dataset_path):
    course_folder_path = os.path.join(dataset_path, course_folder)
    if os.path.isdir(course_folder_path):
        for subfolder in os.listdir(course_folder_path):
            subfolder_path = os.path.join(course_folder_path, subfolder)
            if os.path.isdir(subfolder_path):
                calculate_statistical_features(subfolder_path)
print("Statistical features calculated successfully")
# Out:
# Calculating statistical features...
# Working on data_set\courseA\id01
# Working on data_set\courseA\id02
# Working on data_set\courseA\id03
# Working on data_set\courseA\id04
# Working on data_set\courseA\id05
# Working on data_set\courseA\id07
# Working on data_set\courseA\id08
# Working on data_set\courseA\id10
# Working on data_set\courseA\id12
# Working on data_set\courseA\id13
# Working on data_set\courseA\id14
# Working on data_set\courseA\id15
# Working on data_set\courseA\id16
# Working on data_set\courseA\id17
# Working on data_set\courseA\id18
# Working on data_set\courseA\id19
# Working on data_set\courseA\id22
# Working on data_set\courseA\id23
# Working on data_set\courseA\id24
# Working on data_set\courseA\id25
# Working on data_set\courseB\id01
# Working on data_set\courseB\id02
# Working on data_set\courseB\id03
# Working on data_set\courseB\id04
# Working on data_set\courseB\id05
# Working on data_set\courseB\id07
# Working on data_set\courseB\id08
# ...
